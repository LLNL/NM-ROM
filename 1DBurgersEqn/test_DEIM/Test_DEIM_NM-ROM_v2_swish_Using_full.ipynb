# %%
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.animation as animation 
# %matplotlib inline
import time, sys
from scipy.sparse import spdiags
from scipy import sparse as sp
from scipy.sparse.linalg import spsolve
import pickle
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
# load FOM solution
u=pickle.load(open("./data/FOM.p",'rb'))

# %%
# load weights and bias
file_name_AE="./model/AE_v2_swish.p"

AE = pickle.load(open(file_name_AE,'rb'))

en_w1=AE['en_w1']
en_b1=AE['en_b1']
en_w2=AE['en_w2']
de_w1=AE['de_w1']
de_w2=AE['de_w2']
de_w1T=AE['de_w1T']
de_w2T=AE['de_w2T']
de_w2_sp=AE['de_w2_sp']
de_w2T_sp=AE['de_w2T_sp']

m, M2 = de_w2.shape
f = de_w1.shape[1]

# %%
def sigmoid_np(input):
    return (1.0/(1.0+np.exp(-input))).astype('float32')

def decoder_np_forward(x):
    z1 = de_w1.dot(x)
    s1 = sigmoid_np(z1)
    a1 = z1*s1
    y = de_w2.dot(a1)  
    return y

def decoder_np_forward_backward(x):
    z1 = de_w1.dot(x)
    s1 = sigmoid_np(z1)
    a1 = z1*s1
    y = de_w2.dot(a1)

    dout = de_w1T
    dout = (s1 + a1*(1-s1))*dout
    dydxT = dout.dot(de_w2T)   
    return y,dydxT.T

def decoder_sp_forward(x):
    z1 = de_w1.dot(x)
    s1 = sigmoid_np(z1)
    a1 = z1*s1
    y = sp.csr_matrix.dot(de_w2_sp,a1)
    return y

def decoder_sp_forward_backward(x):
    z1 = de_w1.dot(x)
    s1 = sigmoid_np(z1)
    a1 = z1*s1
    y = sp.csr_matrix.dot(de_w2_sp,a1)

    dout = de_w1T
    dout = (s1 + a1*(1-s1))*dout
    dydxT = sp.csr_matrix.dot(dout,de_w2T_sp)
    return y,dydxT.T

# %%
def DEIM(phi_f, nfeval=None):
    
    ninf=np.NINF
    n,m=np.shape(phi_f)
    if nfeval==None:
        nfeval=m
        
    if nfeval<m:
        print("ill-posed\n")
        print("set # sampling equal to # modes")
        nfeval=m
        
    div,mod=np.divmod(nfeval,m)
    
    I=np.eye(n)
    
    l=0
    ns=div+mod
    u=np.reshape(phi_f[:,l],(n,1))
    p=np.argsort(-np.abs(u),axis=0,kind='stable')[:ns]
#     p=np.argmax(np.abs(u)) # when ns=1
    ep=np.reshape(I[:,p],(n,ns))
    U=u
    P=ep

    ns=div
    for l in range(1,m):
        u=np.reshape(phi_f[:,l],(n,1))
        PT=np.transpose(P)
        c=np.linalg.lstsq(PT@U,PT@u,rcond=None)[0]
        r=np.abs(u-U@c)
        r[p]=ninf
        p=np.append(p,np.argsort(-r,axis=0,kind='stable')[:ns]) # ns!=1
        ep=np.reshape(I[:,p[-ns:]],(n,ns))
        U=np.concatenate((U,u),axis=1)
        P=np.concatenate((P,ep),axis=1)
        
    return p

# %%
def residual_lspg_hr(uwn_z,g,z0_ind,z1_ind,c):
    
    # g is subnet of g
    # Jg is subnet of Jg
    # z_union[z0_ind] gives z0, which is z
    # z_union[z1_ind] igves z1, which is z-1
    
    r = -uwn_z + g[z0_ind] + c*(g[z0_ind]**2 - g[z0_ind]*g[z1_ind])
    
    return r

def jacobian_lspg_hr(g,Jg,z0_ind,z1_ind,c):
    
    J = ((1.0 + c*(2*g[z0_ind] - g[z1_ind]))*Jg[z0_ind].T).T + (-c*g[z0_ind]*Jg[z1_ind].T).T
    
    return J

# %%
amp = 1.0
width = 1.0

convergence_threshold = 1.0e-5
maxk = 10

nx = 1001
dx = 2.0 / (nx - 1)
nt = 500
dt = 0.5 / nt  

c = dt/dx

x = np.linspace(0, 2, nx)

idxn1=np.zeros(nx-1,dtype='int')
idxn1[1:]=np.arange(nx-2)
idxn1[0]=nx-2

u0 = np.copy(u[0])
u_hat0=np.zeros(f,dtype='float32')

# %%
# load snapshot
snapshot_full=pickle.load(open('./data/snapshot_full.p','rb'))
DEIM_snapshot=snapshot_full[:,:-1]

# Do SVD
Ur,Sr,VrT=np.linalg.svd(DEIM_snapshot.T,full_matrices=False)
SVD={'Ur':Ur,'Sr':Sr,'VrT':VrT}
pickle.dump(SVD,open('./model/NMROM_residual_basis.p','wb'))
# SVD=pickle.load(open('./model/NMROM_residual_basis.p','rb'))
# Ur=SVD['Ur']
# plt.figure()
# plt.semilogy(Sr)
# plt.show()

# %%
DEIM_test_tstart=time.time()

# choose # of DEIM basis and DEIM samples
DEIM_min=30
DEIM_max=50

n_test=int((DEIM_max-DEIM_min)*(DEIM_max-DEIM_min+1)/2)
print('Total # of test: {}'.format(n_test))

# save test results: [DEIM_basis, DEIM_samples, Time_elapsed, Max_rel_err]
test_results=np.zeros((n_test,4))

test_count=0
for DEIM_basis in np.arange(DEIM_min,DEIM_max):
    for DEIM_samples in np.arange(DEIM_basis,DEIM_max):
        test_count+=1
        print()
        print('Test #{}'.format(test_count))
        print('-'*72)
        print('DEIM_basis: {}, DEIM_samples: {}'.format(DEIM_basis,DEIM_samples))
        
        try:
            # precompute
            phi_r=Ur[:,:DEIM_basis]
            z=DEIM(phi_r,DEIM_samples)
            ZT=np.eye(nx-1,dtype='float32')[z]
            Z=ZT.T
            precomp1=phi_r@np.linalg.pinv(ZT@phi_r)
            precomp=precomp1.T@precomp1

            # influential indices
            z_union=np.zeros((z.size,2),dtype='int')
            for i in range(z.size):
                if z[i]==0:
                    z_union[i,0]=0
                    z_union[i,1]=nx-2
                else:
                    z_union[i,0]=z[i]
                    z_union[i,1]=z[i]-1        
            z0=z_union[:,0]
            z1=z_union[:,1]

            z_union=np.unique(z_union.flatten())

            z_union0_ind=np.zeros(z0.size,dtype='int')
            z_union1_ind=np.zeros(z1.size,dtype='int')
            for i in range(z0.size):
                z_union0_ind[i]=np.nonzero(np.isin(z_union,z0[i]))[0]
                z_union1_ind[i]=np.nonzero(np.isin(z_union,z1[i]))[0]

            # Construct subnet
            class DecoderFC(nn.Module):

                def __init__(self,):
                    super(DecoderFC, self).__init__()
                    self.fc1 = nn.Linear(f,M2,bias=False)
                    self.fc1.weight = nn.Parameter(torch.ones(de_w1.shape))
            #         self.fc1.weight = nn.Parameter(torch.tensor(de_w1))

                    self.fc2 = nn.Linear(M2,m,bias=False)
                    self.fc2.weight = nn.Parameter(torch.ones(de_w2.shape))
            #         self.fc2.weight = nn.Parameter(torch.tensor(de_w2))

                def forward(self, x):
                    x = self.fc1(x)
                    x = self.fc2(x)
                    return x

            model = DecoderFC()

            x_in=torch.ones(f)
            y_out=model(x_in)

            p_hr=z_union

            upstream=torch.zeros_like(y_out)
            upstream[p_hr]=1.0

            y_out.backward(upstream)

            # masks for subnet
            w1_mask=model.fc1.weight.grad
            w2_mask=model.fc2.weight.grad

            # subnet sparse weight
            idx1=w1_mask.to_sparse()._indices()
            i1=idx1.numpy()[0]
            j1=idx1.numpy()[1]
            v1=de_w1[i1,j1]
            w1_sb_sp=sp.csr_matrix(sp.csr_matrix((v1,(i1,j1)),shape=w1_mask.shape).toarray())

            idx2=w2_mask.to_sparse()._indices()
            i2=idx2.numpy()[0]
            j2=idx2.numpy()[1]
            v2=de_w2[i2,j2]
            w2_sb_sp=sp.csr_matrix(sp.csr_matrix((v2,(i2,j2)),shape=w2_mask.shape).toarray())

            # subnet compressed weight
            i1,j1,v1=sp.find(w1_sb_sp)
            i1_unique,i1_inverse=np.unique(i1,return_inverse=True)
            i1_comp=np.arange(i1_unique.size)
            i1_comp=i1_comp[i1_inverse]
            j1_unique,j1_inverse=np.unique(j1,return_inverse=True)
            j1_comp=np.arange(j1_unique.size)
            j1_comp=j1_comp[j1_inverse]
            w1_sb_comp_sp=sp.csr_matrix((v1,(i1_comp,j1_comp)),shape=(i1_unique.size,j1_unique.size))

            i2,j2,v2=sp.find(w2_sb_sp)
            i2_unique,i2_inverse=np.unique(i2,return_inverse=True)
            i2_comp=np.arange(i2_unique.size)
            i2_comp=i2_comp[i2_inverse]
            j2_unique,j2_inverse=np.unique(j2,return_inverse=True)
            j2_comp=np.arange(j2_unique.size)
            j2_comp=j2_comp[j2_inverse]
            w2_sb_comp_sp=sp.csr_matrix((v2,(i2_comp,j2_comp)),shape=(i2_unique.size,j2_unique.size))

            w1_sb_comp_dense=w1_sb_comp_sp.toarray()
            w1_sb_comp_dense=w1_sb_comp_dense[j2_unique]
            w2_sb_comp_dense=w2_sb_comp_sp.toarray()

            w1_sb_comp_denseT=w1_sb_comp_dense.T
            w2_sb_comp_denseT=w2_sb_comp_dense.T

            # Using sparse matrix
            w2_sb_comp_sp=sp.csr_matrix(w2_sb_comp_dense,dtype='float32')
            w2_sb_comp_spT=sp.csr_matrix(w2_sb_comp_denseT,dtype='float32')

            def sigmoid_np(input):
                return (1.0/(1.0+np.exp(-input))).astype('float32')

            def decoder_sb_np_forward(x):
                z1 = w1_sb_comp_dense.dot(x)
                s1 = sigmoid_np(z1)
                a1 = z1*s1
                y = w2_sb_comp_dense.dot(a1)  
                return y

            def decoder_sb_np_forward_backward(x):
                z1 = w1_sb_comp_dense.dot(x)
                s1 = sigmoid_np(z1)
                a1 = z1*s1
                y = w2_sb_comp_dense.dot(a1) 

                dout = w1_sb_comp_denseT
                dout = (a1 + s1*(1-a1))*dout
                dydxT = dout.dot(w2_sb_comp_denseT)
                return y,dydxT.T

            def decoder_sb_sp_forward(x):
                z1 = w1_sb_comp_dense.dot(x)
                s1 = sigmoid_np(z1)
                a1 = z1*s1
                y = sp.csr_matrix.dot(w2_sb_comp_sp,a1)
                return y

            def decoder_sb_sp_forward_backward(x):
                z1 = w1_sb_comp_dense.dot(x)
                s1 = sigmoid_np(z1)
                a1 = z1*s1
                y = sp.csr_matrix.dot(w2_sb_comp_sp,a1)

                dout = w1_sb_comp_denseT
                dout = (a1 + s1*(1-a1))*dout
                dydxT = sp.csr_matrix.dot(dout,w2_sb_comp_spT)
                return y,dydxT.T

            # Run NM-ROM-DEIM
            t_total_rom_hr_start=time.time()

            u_rom_lspg_hr = np.zeros((nt+1,nx),dtype='float32')
            u_rom_lspg_hr[0] = u0.astype('float32')
            u_hat = np.zeros((nt+1,f),dtype='float32')
            u_hat[0] = u_hat0
            I_hat = np.eye(f,dtype='float32')
            for n in range(nt): 
            #     print("")
            #     print(n,"th time step:")

                u_hatw = u_hat[n].copy()

                uw, Jg = decoder_sb_sp_forward_backward(u_hatw)
                uw += u0[z_union]

                J_lspg = jacobian_lspg_hr(uw,Jg,z_union0_ind,z_union1_ind,c)
                J_lspgT = J_lspg.T

                r_lspg = residual_lspg_hr(u_rom_lspg_hr[n,z],uw,z_union0_ind,z_union1_ind,c)
                r = J_lspgT.dot(precomp.dot(r_lspg))

                for k in range(maxk):   
                    J = J_lspgT@precomp@J_lspg

                    du_hatw = np.linalg.solve(J,-r)

                    u_hatw = u_hatw + du_hatw

                    uw, Jg = decoder_sb_sp_forward_backward(u_hatw)
                    uw += u0[z_union]

                    J_lspg = jacobian_lspg_hr(uw,Jg,z_union0_ind,z_union1_ind,c)
                    J_lspgT = J_lspg.T

                    r_lspg = residual_lspg_hr(u_rom_lspg_hr[n,z],uw,z_union0_ind,z_union1_ind,c)
                    r = J_lspgT.dot(precomp.dot(r_lspg))

                    res = np.linalg.norm(r)
            #         print(k,"th Newton iteration", "res:", "{:.8e}".format(res))

                    if res < convergence_threshold:
                        u_hat[n+1] = u_hatw.copy()
                        u_rom_lspg_hr[n+1,:-1] = u0[:-1] + decoder_sp_forward(u_hat[n+1])
                        u_rom_lspg_hr[n+1,-1] = u_rom_lspg_hr[n+1,0]
                        break

                if res >= convergence_threshold:
#                     print("\n non converged after {}th iteration".format(maxk))
                    break

            #     u_hat[n+1] = u_hatw.copy()
            #     u_rom_lspg_hr[n+1,:-1] = u0[:-1] + decoder_sp_forward(u_hat[n+1])
            #     u_rom_lspg_hr[n+1,-1] = u_rom_lspg_hr[n+1,0]

            t_total_rom_hr=time.time()-t_total_rom_hr_start
            print()
            print("Time elapsed: {} sec".format(t_total_rom_hr))

            # Compute errors
            rel_err=np.linalg.norm(u-u_rom_lspg_hr,axis=1)/np.linalg.norm(u,axis=1)*100
            avg_rel_err=np.sqrt(np.sum(np.linalg.norm(u-u_rom_lspg_hr,ord=2,axis=1)**2))/np.sqrt(np.sum(np.linalg.norm(u,ord=2,axis=1)**2))*100
            max_rel_err = np.max(rel_err)         
            print()
            print("maximum relative error: {}%".format(max_rel_err))
            print('-'*72)      
            
            test_results[test_count-1]=[DEIM_basis,DEIM_samples,t_total_rom_hr,max_rel_err]                 
        except np.linalg.LinAlgError as err:
            if 'Singular matrix' in str(err):
                print()
                print('Error due to singular matrix')
                print('-'*72)
                
                test_results[test_count-1]=[DEIM_basis,DEIM_samples,0.0,np.inf]
            else:
                print("Unexpected error:", sys.exc_info()[0])
                raise
        except:
            print("Unexpected error:", sys.exc_info()[0])
            raise

DEIM_test_telapsed=time.time()-DEIM_test_tstart
print()
print('DEIM test time elapsed: {} sec'.format(DEIM_test_telapsed))
# Out:
# Total # of test: 210
#
# Test #1
# ------------------------------------------------------------------------
# DEIM_basis: 30, DEIM_samples: 30
#
# Time elapsed: 0.30700111389160156 sec
#
# maximum relative error: 100.0%
# ------------------------------------------------------------------------
#
# Test #2
# ------------------------------------------------------------------------
# DEIM_basis: 30, DEIM_samples: 31
#
# Time elapsed: 0.2886371612548828 sec
#
# maximum relative error: 100.0%
# ------------------------------------------------------------------------
#
# Test #3
# ------------------------------------------------------------------------
# DEIM_basis: 30, DEIM_samples: 32
#
# Time elapsed: 0.35683131217956543 sec
#
# maximum relative error: 100.0%
# ------------------------------------------------------------------------
#
# Test #4
# ------------------------------------------------------------------------
# DEIM_basis: 30, DEIM_samples: 33
#
# Time elapsed: 0.724576473236084 sec
#
# maximum relative error: 4.941567897796631%
# ------------------------------------------------------------------------
#
# Test #5
# ------------------------------------------------------------------------
# DEIM_basis: 30, DEIM_samples: 34
#
# Time elapsed: 0.09748983383178711 sec
#
# maximum relative error: 100.0%
# ------------------------------------------------------------------------
#
# Test #6
# ------------------------------------------------------------------------
# DEIM_basis: 30, DEIM_samples: 35
#
# Time elapsed: 0.787574291229248 sec
#
# maximum relative error: 4.042504787445068%
# ------------------------------------------------------------------------
#
# Test #7
# ------------------------------------------------------------------------
# DEIM_basis: 30, DEIM_samples: 36
#
# Time elapsed: 0.7797079086303711 sec
#
# maximum relative error: 4.233585834503174%
# ------------------------------------------------------------------------
#
# Test #8
# ------------------------------------------------------------------------
# DEIM_basis: 30, DEIM_samples: 37
#
# Time elapsed: 0.44166016578674316 sec
#
# maximum relative error: 100.0%
# ------------------------------------------------------------------------
#
# Test #9
# ------------------------------------------------------------------------
# DEIM_basis: 30, DEIM_samples: 38
#
# Time elapsed: 0.7657814025878906 sec
#
# maximum relative error: 4.221732139587402%
# ------------------------------------------------------------------------
#
# Test #10
# ------------------------------------------------------------------------
# DEIM_basis: 30, DEIM_samples: 39
#
# Time elapsed: 0.14105939865112305 sec
#
# maximum relative error: 100.0%
# ------------------------------------------------------------------------
#
# Test #11
# ------------------------------------------------------------------------
# DEIM_basis: 30, DEIM_samples: 40
#
# Time elapsed: 0.7881972789764404 sec
#
# maximum relative error: 2.5176188945770264%
# ------------------------------------------------------------------------
#
# Test #12
# ------------------------------------------------------------------------
# DEIM_basis: 30, DEIM_samples: 41
#
# Time elapsed: 0.7580606937408447 sec
#
# maximum relative error: 19.598339080810547%
# ------------------------------------------------------------------------
#
# Test #13
# ------------------------------------------------------------------------
# DEIM_basis: 30, DEIM_samples: 42
#
# Time elapsed: 0.6881227493286133 sec
#
# maximum relative error: 10.308209419250488%
# ------------------------------------------------------------------------
#
# Test #14
# ------------------------------------------------------------------------
# DEIM_basis: 30, DEIM_samples: 43
#
# Time elapsed: 0.7815241813659668 sec
#
# maximum relative error: 29.87692642211914%
# ------------------------------------------------------------------------
#
# Test #15
# ------------------------------------------------------------------------
# DEIM_basis: 30, DEIM_samples: 44
#
# Time elapsed: 0.7749543190002441 sec
#
# maximum relative error: 31.75034523010254%
# ------------------------------------------------------------------------
#
# Test #16
# ------------------------------------------------------------------------
# DEIM_basis: 30, DEIM_samples: 45
#
# Time elapsed: 0.7240593433380127 sec
#
# maximum relative error: 19.36395263671875%
# ------------------------------------------------------------------------
#
# Test #17
# ------------------------------------------------------------------------
# DEIM_basis: 30, DEIM_samples: 46
#
# Time elapsed: 0.6969211101531982 sec
#
# maximum relative error: 1.9724150896072388%
# ------------------------------------------------------------------------
#
# Test #18
# ------------------------------------------------------------------------
# DEIM_basis: 30, DEIM_samples: 47
#
# Time elapsed: 0.7163078784942627 sec
#
# maximum relative error: 2.25394606590271%
# ------------------------------------------------------------------------
#
# Test #19
# ------------------------------------------------------------------------
# DEIM_basis: 30, DEIM_samples: 48
#
# Time elapsed: 0.7103297710418701 sec
#
# maximum relative error: 6.1285223960876465%
# ------------------------------------------------------------------------
#
# Test #20
# ------------------------------------------------------------------------
# DEIM_basis: 30, DEIM_samples: 49
#
# Time elapsed: 0.809760570526123 sec
#
# maximum relative error: 20.04356575012207%
# ------------------------------------------------------------------------
#
# Test #21
# ------------------------------------------------------------------------
# DEIM_basis: 31, DEIM_samples: 31
#
# Time elapsed: 0.6934535503387451 sec
#
# maximum relative error: 4.596362113952637%
# ------------------------------------------------------------------------
#
# Test #22
# ------------------------------------------------------------------------
# DEIM_basis: 31, DEIM_samples: 32
#
# Time elapsed: 0.6837024688720703 sec
#
# maximum relative error: 5.220091819763184%
# ------------------------------------------------------------------------
#
# Test #23
# ------------------------------------------------------------------------
# DEIM_basis: 31, DEIM_samples: 33
#
# Time elapsed: 0.6948213577270508 sec
#
# maximum relative error: 4.548226833343506%
# ------------------------------------------------------------------------
#
# Test #24
# ------------------------------------------------------------------------
# DEIM_basis: 31, DEIM_samples: 34
#
# Time elapsed: 0.6792271137237549 sec
#
# maximum relative error: 5.567989349365234%
# ------------------------------------------------------------------------
#
# Test #25
# ------------------------------------------------------------------------
# DEIM_basis: 31, DEIM_samples: 35
#
# Time elapsed: 0.6835293769836426 sec
#
# maximum relative error: 5.198030948638916%
# ------------------------------------------------------------------------
#
# Test #26
# ------------------------------------------------------------------------
# DEIM_basis: 31, DEIM_samples: 36
#
# Time elapsed: 0.6778542995452881 sec
#
# maximum relative error: 4.22037410736084%
# ------------------------------------------------------------------------
#
# Test #27
# ------------------------------------------------------------------------
# DEIM_basis: 31, DEIM_samples: 37
#
# Time elapsed: 0.6818046569824219 sec
#
# maximum relative error: 4.190085411071777%
# ------------------------------------------------------------------------
#
# Test #28
# ------------------------------------------------------------------------
# DEIM_basis: 31, DEIM_samples: 38
#
# Time elapsed: 0.6861379146575928 sec
#
# maximum relative error: 4.470854759216309%
# ------------------------------------------------------------------------
#
# Test #29
# ------------------------------------------------------------------------
# DEIM_basis: 31, DEIM_samples: 39
#
# Time elapsed: 0.6869943141937256 sec
#
# maximum relative error: 4.412821292877197%
# ------------------------------------------------------------------------
#
# Test #30
# ------------------------------------------------------------------------
# DEIM_basis: 31, DEIM_samples: 40
#
# Time elapsed: 0.6983420848846436 sec
#
# maximum relative error: 4.0067596435546875%
# ------------------------------------------------------------------------
#
# Test #31
# ------------------------------------------------------------------------
# DEIM_basis: 31, DEIM_samples: 41
#
# Time elapsed: 0.6943609714508057 sec
#
# maximum relative error: 3.944694995880127%
# ------------------------------------------------------------------------
#
# Test #32
# ------------------------------------------------------------------------
# DEIM_basis: 31, DEIM_samples: 42
# Time elapsed: 0.6852874755859375 sec
#
# maximum relative error: 4.872066497802734%
# ------------------------------------------------------------------------
#
# Test #33
# ------------------------------------------------------------------------
# DEIM_basis: 31, DEIM_samples: 43
#
# Time elapsed: 0.6844303607940674 sec
#
# maximum relative error: 4.913651943206787%
# ------------------------------------------------------------------------
#
# Test #34
# ------------------------------------------------------------------------
# DEIM_basis: 31, DEIM_samples: 44
#
# Time elapsed: 0.6902987957000732 sec
#
# maximum relative error: 3.047365188598633%
# ------------------------------------------------------------------------
#
# Test #35
# ------------------------------------------------------------------------
# DEIM_basis: 31, DEIM_samples: 45
#
# Time elapsed: 0.693871021270752 sec
#
# maximum relative error: 1.3672534227371216%
# ------------------------------------------------------------------------
#
# Test #36
# ------------------------------------------------------------------------
# DEIM_basis: 31, DEIM_samples: 46
#
# Time elapsed: 0.6963832378387451 sec
#
# maximum relative error: 1.3419562578201294%
# ------------------------------------------------------------------------
#
# Test #37
# ------------------------------------------------------------------------
# DEIM_basis: 31, DEIM_samples: 47
#
# Time elapsed: 0.6268150806427002 sec
#
# maximum relative error: 1.0349102020263672%
# ------------------------------------------------------------------------
#
# Test #38
# ------------------------------------------------------------------------
# DEIM_basis: 31, DEIM_samples: 48
#
# Time elapsed: 0.49769043922424316 sec
#
# maximum relative error: 1.5611472129821777%
# ------------------------------------------------------------------------
#
# Test #39
# ------------------------------------------------------------------------
# DEIM_basis: 31, DEIM_samples: 49
#
# Time elapsed: 0.5067384243011475 sec
#
# maximum relative error: 6.419025421142578%
# ------------------------------------------------------------------------
#
# Test #40
# ------------------------------------------------------------------------
# DEIM_basis: 32, DEIM_samples: 32
#
# Time elapsed: 0.48021936416625977 sec
#
# maximum relative error: 3.2210853099823%
# ------------------------------------------------------------------------
#
# Test #41
# ------------------------------------------------------------------------
# DEIM_basis: 32, DEIM_samples: 33
#
# Time elapsed: 0.4873833656311035 sec
#
# maximum relative error: 4.228494167327881%
# ------------------------------------------------------------------------
#
# Test #42
# ------------------------------------------------------------------------
# DEIM_basis: 32, DEIM_samples: 34
#
# Time elapsed: 0.4828009605407715 sec
#
# maximum relative error: 2.476241111755371%
# ------------------------------------------------------------------------
#
# Test #43
# ------------------------------------------------------------------------
# DEIM_basis: 32, DEIM_samples: 35
#
# Time elapsed: 0.47849178314208984 sec
#
# maximum relative error: 4.18797492980957%
# ------------------------------------------------------------------------
#
# Test #44
# ------------------------------------------------------------------------
# DEIM_basis: 32, DEIM_samples: 36
#
# Time elapsed: 0.4857933521270752 sec
#
# maximum relative error: 3.9902145862579346%
# ------------------------------------------------------------------------
#
# Test #45
# ------------------------------------------------------------------------
# DEIM_basis: 32, DEIM_samples: 37
#
# Time elapsed: 0.4871327877044678 sec
#
# maximum relative error: 3.2727773189544678%
# ------------------------------------------------------------------------
#
# Test #46
# ------------------------------------------------------------------------
# DEIM_basis: 32, DEIM_samples: 38
#
# Time elapsed: 0.4850893020629883 sec
#
# maximum relative error: 3.447718858718872%
# ------------------------------------------------------------------------
#
# Test #47
# ------------------------------------------------------------------------
# DEIM_basis: 32, DEIM_samples: 39
#
# Time elapsed: 0.4862213134765625 sec
#
# maximum relative error: 3.787348508834839%
# ------------------------------------------------------------------------
#
# Test #48
# ------------------------------------------------------------------------
# DEIM_basis: 32, DEIM_samples: 40
#
# Time elapsed: 0.4835689067840576 sec
#
# maximum relative error: 3.794948101043701%
# ------------------------------------------------------------------------
#
# Test #49
# ------------------------------------------------------------------------
# DEIM_basis: 32, DEIM_samples: 41
#
# Time elapsed: 0.5480012893676758 sec
#
# maximum relative error: 3.5046045780181885%
# ------------------------------------------------------------------------
#
# Test #50
# ------------------------------------------------------------------------
# DEIM_basis: 32, DEIM_samples: 42
#
# Time elapsed: 0.49467968940734863 sec
#
# maximum relative error: 3.4500253200531006%
# ------------------------------------------------------------------------
#
# Test #51
# ------------------------------------------------------------------------
# DEIM_basis: 32, DEIM_samples: 43
#
# Time elapsed: 0.49224233627319336 sec
#
# maximum relative error: 5.049652099609375%
# ------------------------------------------------------------------------
#
# Test #52
# ------------------------------------------------------------------------
# DEIM_basis: 32, DEIM_samples: 44
#
# Time elapsed: 0.4894990921020508 sec
#
# maximum relative error: 4.673959255218506%
# ------------------------------------------------------------------------
#
# Test #53
# ------------------------------------------------------------------------
# DEIM_basis: 32, DEIM_samples: 45
#
# Time elapsed: 0.48856425285339355 sec
#
# maximum relative error: 2.834084987640381%
# ------------------------------------------------------------------------
#
# Test #54
# ------------------------------------------------------------------------
# DEIM_basis: 32, DEIM_samples: 46
#
# Time elapsed: 0.4958767890930176 sec
#
# maximum relative error: 1.2510402202606201%
# ------------------------------------------------------------------------
#
# Test #55
# ------------------------------------------------------------------------
# DEIM_basis: 32, DEIM_samples: 47
#
# Time elapsed: 0.49612903594970703 sec
#
# maximum relative error: 1.2267322540283203%
# ------------------------------------------------------------------------
#
# Test #56
# ------------------------------------------------------------------------
# DEIM_basis: 32, DEIM_samples: 48
#
# Time elapsed: 0.5000414848327637 sec
#
# maximum relative error: 1.3733142614364624%
# ------------------------------------------------------------------------
#
# Test #57
# ------------------------------------------------------------------------
# DEIM_basis: 32, DEIM_samples: 49
#
# Time elapsed: 0.49879884719848633 sec
#
# maximum relative error: 1.6678493022918701%
# ------------------------------------------------------------------------
#
# Test #58
# ------------------------------------------------------------------------
# DEIM_basis: 33, DEIM_samples: 33
#
# Time elapsed: 0.50166916847229 sec
#
# maximum relative error: 1.9691898822784424%
# ------------------------------------------------------------------------
#
# Test #59
# ------------------------------------------------------------------------
# DEIM_basis: 33, DEIM_samples: 34
#
# Time elapsed: 0.4920816421508789 sec
#
# maximum relative error: 3.4067940711975098%
# ------------------------------------------------------------------------
#
# Test #60
# ------------------------------------------------------------------------
# DEIM_basis: 33, DEIM_samples: 35
#
# Time elapsed: 0.4990518093109131 sec
#
# maximum relative error: 1.8082002401351929%
# ------------------------------------------------------------------------
#
# Test #61
# ------------------------------------------------------------------------
# DEIM_basis: 33, DEIM_samples: 36
#
# Time elapsed: 0.4905581474304199 sec
#
# maximum relative error: 3.359964370727539%
# ------------------------------------------------------------------------
#
# Test #62
# ------------------------------------------------------------------------
# DEIM_basis: 33, DEIM_samples: 37
#
# Time elapsed: 0.49402952194213867 sec
#
# maximum relative error: 3.2694430351257324%
# ------------------------------------------------------------------------
#
# Test #63
# ------------------------------------------------------------------------
# DEIM_basis: 33, DEIM_samples: 38
# Time elapsed: 0.49507999420166016 sec
#
# maximum relative error: 2.601562023162842%
# ------------------------------------------------------------------------
#
# Test #64
# ------------------------------------------------------------------------
# DEIM_basis: 33, DEIM_samples: 39
#
# Time elapsed: 0.49579954147338867 sec
#
# maximum relative error: 2.5322184562683105%
# ------------------------------------------------------------------------
#
# Test #65
# ------------------------------------------------------------------------
# DEIM_basis: 33, DEIM_samples: 40
#
# Time elapsed: 0.49818897247314453 sec
#
# maximum relative error: 2.918412446975708%
# ------------------------------------------------------------------------
#
# Test #66
# ------------------------------------------------------------------------
# DEIM_basis: 33, DEIM_samples: 41
#
# Time elapsed: 0.4959886074066162 sec
#
# maximum relative error: 3.2432703971862793%
# ------------------------------------------------------------------------
#
# Test #67
# ------------------------------------------------------------------------
# DEIM_basis: 33, DEIM_samples: 42
#
# Time elapsed: 0.5022971630096436 sec
#
# maximum relative error: 3.3092987537384033%
# ------------------------------------------------------------------------
#
# Test #68
# ------------------------------------------------------------------------
# DEIM_basis: 33, DEIM_samples: 43
#
# Time elapsed: 0.5038597583770752 sec
#
# maximum relative error: 2.9517109394073486%
# ------------------------------------------------------------------------
#
# Test #69
# ------------------------------------------------------------------------
# DEIM_basis: 33, DEIM_samples: 44
#
# Time elapsed: 0.5000529289245605 sec
#
# maximum relative error: 4.739431858062744%
# ------------------------------------------------------------------------
#
# Test #70
# ------------------------------------------------------------------------
# DEIM_basis: 33, DEIM_samples: 45
#
# Time elapsed: 0.4981963634490967 sec
#
# maximum relative error: 4.215969562530518%
# ------------------------------------------------------------------------
#
# Test #71
# ------------------------------------------------------------------------
# DEIM_basis: 33, DEIM_samples: 46
#
# Time elapsed: 0.5021026134490967 sec
#
# maximum relative error: 2.2156074047088623%
# ------------------------------------------------------------------------
#
# Test #72
# ------------------------------------------------------------------------
# DEIM_basis: 33, DEIM_samples: 47
#
# Time elapsed: 0.507155179977417 sec
#
# maximum relative error: 1.4738205671310425%
# ------------------------------------------------------------------------
#
# Test #73
# ------------------------------------------------------------------------
# DEIM_basis: 33, DEIM_samples: 48
#
# Time elapsed: 0.5034091472625732 sec
#
# maximum relative error: 1.4010202884674072%
# ------------------------------------------------------------------------
#
# Test #74
# ------------------------------------------------------------------------
# DEIM_basis: 33, DEIM_samples: 49
#
# Time elapsed: 0.5146846771240234 sec
#
# maximum relative error: 1.071000099182129%
# ------------------------------------------------------------------------
#
# Test #75
# ------------------------------------------------------------------------
# DEIM_basis: 34, DEIM_samples: 34
#
# Time elapsed: 0.4843764305114746 sec
#
# maximum relative error: 3.4653682708740234%
# ------------------------------------------------------------------------
#
# Test #76
# ------------------------------------------------------------------------
# DEIM_basis: 34, DEIM_samples: 35
#
# Time elapsed: 0.5092594623565674 sec
#
# maximum relative error: 4.839691162109375%
# ------------------------------------------------------------------------
#
# Test #77
# ------------------------------------------------------------------------
# DEIM_basis: 34, DEIM_samples: 36
#
# Time elapsed: 0.49056410789489746 sec
#
# maximum relative error: 2.520097255706787%
# ------------------------------------------------------------------------
#
# Test #78
# ------------------------------------------------------------------------
# DEIM_basis: 34, DEIM_samples: 37
#
# Time elapsed: 0.5091376304626465 sec
#
# maximum relative error: 4.276252269744873%
# ------------------------------------------------------------------------
#
# Test #79
# ------------------------------------------------------------------------
# DEIM_basis: 34, DEIM_samples: 38
#
# Time elapsed: 0.51106858253479 sec
#
# maximum relative error: 4.0874714851379395%
# ------------------------------------------------------------------------
#
# Test #80
# ------------------------------------------------------------------------
# DEIM_basis: 34, DEIM_samples: 39
#
# Time elapsed: 0.5052247047424316 sec
#
# maximum relative error: 3.596224546432495%
# ------------------------------------------------------------------------
#
# Test #81
# ------------------------------------------------------------------------
# DEIM_basis: 34, DEIM_samples: 40
#
# Time elapsed: 0.48172807693481445 sec
#
# maximum relative error: 4.347308158874512%
# ------------------------------------------------------------------------
#
# Test #82
# ------------------------------------------------------------------------
# DEIM_basis: 34, DEIM_samples: 41
#
# Time elapsed: 0.4855337142944336 sec
#
# maximum relative error: 4.982606887817383%
# ------------------------------------------------------------------------
#
# Test #83
# ------------------------------------------------------------------------
# DEIM_basis: 34, DEIM_samples: 42
#
# Time elapsed: 0.48229169845581055 sec
#
# maximum relative error: 4.634489059448242%
# ------------------------------------------------------------------------
#
# Test #84
# ------------------------------------------------------------------------
# DEIM_basis: 34, DEIM_samples: 43
#
# Time elapsed: 0.49019503593444824 sec
#
# maximum relative error: 3.909027576446533%
# ------------------------------------------------------------------------
#
# Test #85
# ------------------------------------------------------------------------
# DEIM_basis: 34, DEIM_samples: 44
#
# Time elapsed: 0.4895806312561035 sec
#
# maximum relative error: 4.167775630950928%
# ------------------------------------------------------------------------
#
# Test #86
# ------------------------------------------------------------------------
# DEIM_basis: 34, DEIM_samples: 45
#
# Time elapsed: 0.49684977531433105 sec
#
# maximum relative error: 6.256942272186279%
# ------------------------------------------------------------------------
#
# Test #87
# ------------------------------------------------------------------------
# DEIM_basis: 34, DEIM_samples: 46
#
# Time elapsed: 0.4953298568725586 sec
#
# maximum relative error: 6.444302082061768%
# ------------------------------------------------------------------------
#
# Test #88
# ------------------------------------------------------------------------
# DEIM_basis: 34, DEIM_samples: 47
#
# Time elapsed: 0.49702978134155273 sec
#
# maximum relative error: 1.9682904481887817%
# ------------------------------------------------------------------------
#
# Test #89
# ------------------------------------------------------------------------
# DEIM_basis: 34, DEIM_samples: 48
#
# Time elapsed: 0.4990355968475342 sec
#
# maximum relative error: 3.810271739959717%
# ------------------------------------------------------------------------
#
# Test #90
# ------------------------------------------------------------------------
# DEIM_basis: 34, DEIM_samples: 49
#
# Time elapsed: 0.5047364234924316 sec
#
# maximum relative error: 3.056248188018799%
# ------------------------------------------------------------------------
#
# Test #91
# ------------------------------------------------------------------------
# DEIM_basis: 35, DEIM_samples: 35
#
# Time elapsed: 0.5074787139892578 sec
#
# maximum relative error: 100.0%
# ------------------------------------------------------------------------
#
# Test #92
# ------------------------------------------------------------------------
# DEIM_basis: 35, DEIM_samples: 36
#
# Time elapsed: 0.519860029220581 sec
#
# maximum relative error: 100.0%
# ------------------------------------------------------------------------
#
# Test #93
# ------------------------------------------------------------------------
# DEIM_basis: 35, DEIM_samples: 37
#
# Time elapsed: 0.5024693012237549 sec
#
# maximum relative error: 2.415553569793701%
# ------------------------------------------------------------------------
#
# Test #94
# ------------------------------------------------------------------------
# DEIM_basis: 35, DEIM_samples: 38
# Time elapsed: 0.49958205223083496 sec
#
# maximum relative error: 100.0%
# ------------------------------------------------------------------------
#
# Test #95
# ------------------------------------------------------------------------
# DEIM_basis: 35, DEIM_samples: 39
#
# Time elapsed: 0.48711585998535156 sec
#
# maximum relative error: 100.0%
# ------------------------------------------------------------------------
#
# Test #96
# ------------------------------------------------------------------------
# DEIM_basis: 35, DEIM_samples: 40
#
# Time elapsed: 0.5858461856842041 sec
#
# maximum relative error: 100.0%
# ------------------------------------------------------------------------
#
# Test #97
# ------------------------------------------------------------------------
# DEIM_basis: 35, DEIM_samples: 41
#
# Time elapsed: 0.509737491607666 sec
#
# maximum relative error: 5.0984787940979%
# ------------------------------------------------------------------------
#
# Test #98
# ------------------------------------------------------------------------
# DEIM_basis: 35, DEIM_samples: 42
#
# Time elapsed: 0.5135293006896973 sec
#
# maximum relative error: 6.073410511016846%
# ------------------------------------------------------------------------
#
# Test #99
# ------------------------------------------------------------------------
# DEIM_basis: 35, DEIM_samples: 43
#
# Time elapsed: 0.5055696964263916 sec
#
# maximum relative error: 5.762213706970215%
# ------------------------------------------------------------------------
#
# Test #100
# ------------------------------------------------------------------------
# DEIM_basis: 35, DEIM_samples: 44
#
# Time elapsed: 0.512465238571167 sec
#
# maximum relative error: 3.6166276931762695%
# ------------------------------------------------------------------------
#
# Test #101
# ------------------------------------------------------------------------
# DEIM_basis: 35, DEIM_samples: 45
#
# Time elapsed: 0.5023207664489746 sec
#
# maximum relative error: 5.4625139236450195%
# ------------------------------------------------------------------------
#
# Test #102
# ------------------------------------------------------------------------
# DEIM_basis: 35, DEIM_samples: 46
#
# Time elapsed: 0.5075516700744629 sec
#
# maximum relative error: 4.83229398727417%
# ------------------------------------------------------------------------
#
# Test #103
# ------------------------------------------------------------------------
# DEIM_basis: 35, DEIM_samples: 47
#
# Time elapsed: 0.5103569030761719 sec
#
# maximum relative error: 5.393345832824707%
# ------------------------------------------------------------------------
#
# Test #104
# ------------------------------------------------------------------------
# DEIM_basis: 35, DEIM_samples: 48
#
# Time elapsed: 0.5028581619262695 sec
#
# maximum relative error: 5.845760822296143%
# ------------------------------------------------------------------------
#
# Test #105
# ------------------------------------------------------------------------
# DEIM_basis: 35, DEIM_samples: 49
#
# Time elapsed: 0.5126588344573975 sec
#
# maximum relative error: 3.0251660346984863%
# ------------------------------------------------------------------------
#
# Test #106
# ------------------------------------------------------------------------
# DEIM_basis: 36, DEIM_samples: 36
#
# Time elapsed: 0.4844367504119873 sec
#
# maximum relative error: 2.579709768295288%
# ------------------------------------------------------------------------
#
# Test #107
# ------------------------------------------------------------------------
# DEIM_basis: 36, DEIM_samples: 37
#
# Time elapsed: 0.49076223373413086 sec
#
# maximum relative error: 1.6884526014328003%
# ------------------------------------------------------------------------
#
# Test #108
# ------------------------------------------------------------------------
# DEIM_basis: 36, DEIM_samples: 38
#
# Time elapsed: 0.4860682487487793 sec
#
# maximum relative error: 1.6496477127075195%
# ------------------------------------------------------------------------
#
# Test #109
# ------------------------------------------------------------------------
# DEIM_basis: 36, DEIM_samples: 39
#
# Time elapsed: 0.49151158332824707 sec
#
# maximum relative error: 1.328122854232788%
# ------------------------------------------------------------------------
#
# Test #110
# ------------------------------------------------------------------------
# DEIM_basis: 36, DEIM_samples: 40
#
# Time elapsed: 0.4933509826660156 sec
#
# maximum relative error: 1.1775577068328857%
# ------------------------------------------------------------------------
#
# Test #111
# ------------------------------------------------------------------------
# DEIM_basis: 36, DEIM_samples: 41
#
# Time elapsed: 0.4978148937225342 sec
#
# maximum relative error: 2.1471920013427734%
# ------------------------------------------------------------------------
#
# Test #112
# ------------------------------------------------------------------------
# DEIM_basis: 36, DEIM_samples: 42
#
# Time elapsed: 0.4974935054779053 sec
#
# maximum relative error: 2.8798828125%
# ------------------------------------------------------------------------
#
# Test #113
# ------------------------------------------------------------------------
# DEIM_basis: 36, DEIM_samples: 43
#
# Time elapsed: 0.498837947845459 sec
#
# maximum relative error: 3.1316189765930176%
# ------------------------------------------------------------------------
#
# Test #114
# ------------------------------------------------------------------------
# DEIM_basis: 36, DEIM_samples: 44
#
# Time elapsed: 0.49885106086730957 sec
#
# maximum relative error: 3.6234230995178223%
# ------------------------------------------------------------------------
#
# Test #115
# ------------------------------------------------------------------------
# DEIM_basis: 36, DEIM_samples: 45
#
# Time elapsed: 0.4979531764984131 sec
#
# maximum relative error: 2.471179962158203%
# ------------------------------------------------------------------------
#
# Test #116
# ------------------------------------------------------------------------
# DEIM_basis: 36, DEIM_samples: 46
#
# Time elapsed: 0.4932403564453125 sec
#
# maximum relative error: 3.571141481399536%
# ------------------------------------------------------------------------
#
# Test #117
# ------------------------------------------------------------------------
# DEIM_basis: 36, DEIM_samples: 47
#
# Time elapsed: 0.5387773513793945 sec
#
# maximum relative error: 5.9075422286987305%
# ------------------------------------------------------------------------
#
# Test #118
# ------------------------------------------------------------------------
# DEIM_basis: 36, DEIM_samples: 48
#
# Time elapsed: 0.5228826999664307 sec
#
# maximum relative error: 5.555227756500244%
# ------------------------------------------------------------------------
#
# Test #119
# ------------------------------------------------------------------------
# DEIM_basis: 36, DEIM_samples: 49
#
# Time elapsed: 0.4653041362762451 sec
#
# maximum relative error: 100.0%
# ------------------------------------------------------------------------
#
# Test #120
# ------------------------------------------------------------------------
# DEIM_basis: 37, DEIM_samples: 37
#
# Time elapsed: 0.488048791885376 sec
#
# maximum relative error: 2.296008348464966%
# ------------------------------------------------------------------------
#
# Test #121
# ------------------------------------------------------------------------
# DEIM_basis: 37, DEIM_samples: 38
#
# Time elapsed: 0.4900033473968506 sec
#
# maximum relative error: 1.8584752082824707%
# ------------------------------------------------------------------------
#
# Test #122
# ------------------------------------------------------------------------
# DEIM_basis: 37, DEIM_samples: 39
#
# Time elapsed: 0.4907033443450928 sec
#
# maximum relative error: 1.3463095426559448%
# ------------------------------------------------------------------------
#
# Test #123
# ------------------------------------------------------------------------
# DEIM_basis: 37, DEIM_samples: 40
#
# Time elapsed: 0.48966407775878906 sec
#
# maximum relative error: 1.5788508653640747%
# ------------------------------------------------------------------------
#
# Test #124
# ------------------------------------------------------------------------
# DEIM_basis: 37, DEIM_samples: 41
#
# Time elapsed: 0.49189162254333496 sec
#
# maximum relative error: 1.4466521739959717%
# ------------------------------------------------------------------------
#
# Test #125
# ------------------------------------------------------------------------
# DEIM_basis: 37, DEIM_samples: 42
# Time elapsed: 0.49511098861694336 sec
#
# maximum relative error: 2.2583205699920654%
# ------------------------------------------------------------------------
#
# Test #126
# ------------------------------------------------------------------------
# DEIM_basis: 37, DEIM_samples: 43
#
# Time elapsed: 0.4987363815307617 sec
#
# maximum relative error: 3.073666572570801%
# ------------------------------------------------------------------------
#
# Test #127
# ------------------------------------------------------------------------
# DEIM_basis: 37, DEIM_samples: 44
#
# Time elapsed: 0.5023410320281982 sec
#
# maximum relative error: 3.4569509029388428%
# ------------------------------------------------------------------------
#
# Test #128
# ------------------------------------------------------------------------
# DEIM_basis: 37, DEIM_samples: 45
#
# Time elapsed: 0.500497579574585 sec
#
# maximum relative error: 4.108625411987305%
# ------------------------------------------------------------------------
#
# Test #129
# ------------------------------------------------------------------------
# DEIM_basis: 37, DEIM_samples: 46
#
# Time elapsed: 0.4987063407897949 sec
#
# maximum relative error: 2.496005058288574%
# ------------------------------------------------------------------------
#
# Test #130
# ------------------------------------------------------------------------
# DEIM_basis: 37, DEIM_samples: 47
#
# Time elapsed: 0.4993467330932617 sec
#
# maximum relative error: 3.8080766201019287%
# ------------------------------------------------------------------------
#
# Test #131
# ------------------------------------------------------------------------
# DEIM_basis: 37, DEIM_samples: 48
#
# Time elapsed: 0.5031428337097168 sec
#
# maximum relative error: 3.2183401584625244%
# ------------------------------------------------------------------------
#
# Test #132
# ------------------------------------------------------------------------
# DEIM_basis: 37, DEIM_samples: 49
#
# Time elapsed: 0.5021529197692871 sec
#
# maximum relative error: 3.6762335300445557%
# ------------------------------------------------------------------------
#
# Test #133
# ------------------------------------------------------------------------
# DEIM_basis: 38, DEIM_samples: 38
#
# Time elapsed: 0.5015482902526855 sec
#
# maximum relative error: 2.798968553543091%
# ------------------------------------------------------------------------
#
# Test #134
# ------------------------------------------------------------------------
# DEIM_basis: 38, DEIM_samples: 39
#
# Time elapsed: 0.49968957901000977 sec
#
# maximum relative error: 2.355726957321167%
# ------------------------------------------------------------------------
#
# Test #135
# ------------------------------------------------------------------------
# DEIM_basis: 38, DEIM_samples: 40
#
# Time elapsed: 0.49889588356018066 sec
#
# maximum relative error: 1.7236988544464111%
# ------------------------------------------------------------------------
#
# Test #136
# ------------------------------------------------------------------------
# DEIM_basis: 38, DEIM_samples: 41
#
# Time elapsed: 0.5040173530578613 sec
#
# maximum relative error: 1.5961525440216064%
# ------------------------------------------------------------------------
#
# Test #137
# ------------------------------------------------------------------------
# DEIM_basis: 38, DEIM_samples: 42
#
# Time elapsed: 0.5021951198577881 sec
#
# maximum relative error: 1.47321355342865%
# ------------------------------------------------------------------------
#
# Test #138
# ------------------------------------------------------------------------
# DEIM_basis: 38, DEIM_samples: 43
#
# Time elapsed: 0.5066413879394531 sec
#
# maximum relative error: 2.093332290649414%
# ------------------------------------------------------------------------
#
# Test #139
# ------------------------------------------------------------------------
# DEIM_basis: 38, DEIM_samples: 44
#
# Time elapsed: 0.51432204246521 sec
#
# maximum relative error: 3.5613927841186523%
# ------------------------------------------------------------------------
#
# Test #140
# ------------------------------------------------------------------------
# DEIM_basis: 38, DEIM_samples: 45
#
# Time elapsed: 0.5150482654571533 sec
#
# maximum relative error: 3.553258180618286%
# ------------------------------------------------------------------------
#
# Test #141
# ------------------------------------------------------------------------
# DEIM_basis: 38, DEIM_samples: 46
#
# Time elapsed: 0.5142922401428223 sec
#
# maximum relative error: 4.056822299957275%
# ------------------------------------------------------------------------
#
# Test #142
# ------------------------------------------------------------------------
# DEIM_basis: 38, DEIM_samples: 47
#
# Time elapsed: 0.507282018661499 sec
#
# maximum relative error: 2.9237301349639893%
# ------------------------------------------------------------------------
#
# Test #143
# ------------------------------------------------------------------------
# DEIM_basis: 38, DEIM_samples: 48
#
# Time elapsed: 0.5070304870605469 sec
#
# maximum relative error: 5.13697624206543%
# ------------------------------------------------------------------------
#
# Test #144
# ------------------------------------------------------------------------
# DEIM_basis: 38, DEIM_samples: 49
#
# Time elapsed: 0.5146455764770508 sec
#
# maximum relative error: 3.485532760620117%
# ------------------------------------------------------------------------
#
# Test #145
# ------------------------------------------------------------------------
# DEIM_basis: 39, DEIM_samples: 39
#
# Time elapsed: 0.3016982078552246 sec
#
# maximum relative error: 100.0%
# ------------------------------------------------------------------------
#
# Test #146
# ------------------------------------------------------------------------
# DEIM_basis: 39, DEIM_samples: 40
#
# Time elapsed: 0.5531659126281738 sec
#
# maximum relative error: 100.0%
# ------------------------------------------------------------------------
#
# Test #147
# ------------------------------------------------------------------------
# DEIM_basis: 39, DEIM_samples: 41
#
# Time elapsed: 0.44325780868530273 sec
#
# maximum relative error: 100.0%
# ------------------------------------------------------------------------
#
# Test #148
# ------------------------------------------------------------------------
# DEIM_basis: 39, DEIM_samples: 42
#
# Time elapsed: 0.473207950592041 sec
#
# maximum relative error: 100.0%
# ------------------------------------------------------------------------
#
# Test #149
# ------------------------------------------------------------------------
# DEIM_basis: 39, DEIM_samples: 43
#
# Time elapsed: 0.4607424736022949 sec
#
# maximum relative error: 100.0%
# ------------------------------------------------------------------------
#
# Test #150
# ------------------------------------------------------------------------
# DEIM_basis: 39, DEIM_samples: 44
#
# Time elapsed: 0.5059740543365479 sec
#
# maximum relative error: 100.0%
# ------------------------------------------------------------------------
#
# Test #151
# ------------------------------------------------------------------------
# DEIM_basis: 39, DEIM_samples: 45
#
# Time elapsed: 0.4686107635498047 sec
#
# maximum relative error: 100.0%
# ------------------------------------------------------------------------
#
# Test #152
# ------------------------------------------------------------------------
# DEIM_basis: 39, DEIM_samples: 46
#
# Time elapsed: 0.0035333633422851562 sec
#
# maximum relative error: 100.0%
# ------------------------------------------------------------------------
#
# Test #153
# ------------------------------------------------------------------------
# DEIM_basis: 39, DEIM_samples: 47
#
# Time elapsed: 0.5106618404388428 sec
#
# maximum relative error: 100.0%
# ------------------------------------------------------------------------
#
# Test #154
# ------------------------------------------------------------------------
# DEIM_basis: 39, DEIM_samples: 48
#
# Time elapsed: 0.5256412029266357 sec
#
# maximum relative error: 100.0%
# ------------------------------------------------------------------------
#
# Test #155
# ------------------------------------------------------------------------
# DEIM_basis: 39, DEIM_samples: 49
#
# Time elapsed: 0.5506370067596436 sec
#
# maximum relative error: 6.974434852600098%
# ------------------------------------------------------------------------
#
# Test #156
# ------------------------------------------------------------------------
# DEIM_basis: 40, DEIM_samples: 40
# Time elapsed: 0.5088889598846436 sec
#
# maximum relative error: 2.282317876815796%
# ------------------------------------------------------------------------
#
# Test #157
# ------------------------------------------------------------------------
# DEIM_basis: 40, DEIM_samples: 41
#
# Time elapsed: 0.5008265972137451 sec
#
# maximum relative error: 3.9762489795684814%
# ------------------------------------------------------------------------
#
# Test #158
# ------------------------------------------------------------------------
# DEIM_basis: 40, DEIM_samples: 42
#
# Time elapsed: 0.5076472759246826 sec
#
# maximum relative error: 1.23244047164917%
# ------------------------------------------------------------------------
#
# Test #159
# ------------------------------------------------------------------------
# DEIM_basis: 40, DEIM_samples: 43
#
# Time elapsed: 0.5060458183288574 sec
#
# maximum relative error: 4.1967453956604%
# ------------------------------------------------------------------------
#
# Test #160
# ------------------------------------------------------------------------
# DEIM_basis: 40, DEIM_samples: 44
#
# Time elapsed: 0.5031764507293701 sec
#
# maximum relative error: 4.160748481750488%
# ------------------------------------------------------------------------
#
# Test #161
# ------------------------------------------------------------------------
# DEIM_basis: 40, DEIM_samples: 45
#
# Time elapsed: 0.5035598278045654 sec
#
# maximum relative error: 3.297837495803833%
# ------------------------------------------------------------------------
#
# Test #162
# ------------------------------------------------------------------------
# DEIM_basis: 40, DEIM_samples: 46
#
# Time elapsed: 0.5085904598236084 sec
#
# maximum relative error: 4.03309965133667%
# ------------------------------------------------------------------------
#
# Test #163
# ------------------------------------------------------------------------
# DEIM_basis: 40, DEIM_samples: 47
#
# Time elapsed: 0.5137555599212646 sec
#
# maximum relative error: 4.739112377166748%
# ------------------------------------------------------------------------
#
# Test #164
# ------------------------------------------------------------------------
# DEIM_basis: 40, DEIM_samples: 48
#
# Time elapsed: 0.5023353099822998 sec
#
# maximum relative error: 5.77478551864624%
# ------------------------------------------------------------------------
#
# Test #165
# ------------------------------------------------------------------------
# DEIM_basis: 40, DEIM_samples: 49
#
# Time elapsed: 0.5084123611450195 sec
#
# maximum relative error: 3.454831123352051%
# ------------------------------------------------------------------------
#
# Test #166
# ------------------------------------------------------------------------
# DEIM_basis: 41, DEIM_samples: 41
#
# Time elapsed: 0.5161228179931641 sec
#
# maximum relative error: 1.942384958267212%
# ------------------------------------------------------------------------
#
# Test #167
# ------------------------------------------------------------------------
# DEIM_basis: 41, DEIM_samples: 42
#
# Time elapsed: 0.5072698593139648 sec
#
# maximum relative error: 4.054766654968262%
# ------------------------------------------------------------------------
#
# Test #168
# ------------------------------------------------------------------------
# DEIM_basis: 41, DEIM_samples: 43
#
# Time elapsed: 0.5170993804931641 sec
#
# maximum relative error: 1.3680243492126465%
# ------------------------------------------------------------------------
#
# Test #169
# ------------------------------------------------------------------------
# DEIM_basis: 41, DEIM_samples: 44
#
# Time elapsed: 0.505650520324707 sec
#
# maximum relative error: 4.00628137588501%
# ------------------------------------------------------------------------
#
# Test #170
# ------------------------------------------------------------------------
# DEIM_basis: 41, DEIM_samples: 45
#
# Time elapsed: 0.5040130615234375 sec
#
# maximum relative error: 4.124414920806885%
# ------------------------------------------------------------------------
#
# Test #171
# ------------------------------------------------------------------------
# DEIM_basis: 41, DEIM_samples: 46
#
# Time elapsed: 0.5064048767089844 sec
#
# maximum relative error: 3.760344982147217%
# ------------------------------------------------------------------------
#
# Test #172
# ------------------------------------------------------------------------
# DEIM_basis: 41, DEIM_samples: 47
#
# Time elapsed: 0.5100259780883789 sec
#
# maximum relative error: 4.371546268463135%
# ------------------------------------------------------------------------
#
# Test #173
# ------------------------------------------------------------------------
# DEIM_basis: 41, DEIM_samples: 48
#
# Time elapsed: 0.5130867958068848 sec
#
# maximum relative error: 5.199145317077637%
# ------------------------------------------------------------------------
#
# Test #174
# ------------------------------------------------------------------------
# DEIM_basis: 41, DEIM_samples: 49
#
# Time elapsed: 0.5088074207305908 sec
#
# maximum relative error: 5.663045406341553%
# ------------------------------------------------------------------------
#
# Test #175
# ------------------------------------------------------------------------
# DEIM_basis: 42, DEIM_samples: 42
#
# Time elapsed: 0.5035974979400635 sec
#
# maximum relative error: 2.2942214012145996%
# ------------------------------------------------------------------------
#
# Test #176
# ------------------------------------------------------------------------
# DEIM_basis: 42, DEIM_samples: 43
#
# Time elapsed: 0.5061213970184326 sec
#
# maximum relative error: 3.324899196624756%
# ------------------------------------------------------------------------
#
# Test #177
# ------------------------------------------------------------------------
# DEIM_basis: 42, DEIM_samples: 44
#
# Time elapsed: 0.5044546127319336 sec
#
# maximum relative error: 1.7232084274291992%
# ------------------------------------------------------------------------
#
# Test #178
# ------------------------------------------------------------------------
# DEIM_basis: 42, DEIM_samples: 45
#
# Time elapsed: 0.5059642791748047 sec
#
# maximum relative error: 3.6613762378692627%
# ------------------------------------------------------------------------
#
# Test #179
# ------------------------------------------------------------------------
# DEIM_basis: 42, DEIM_samples: 46
#
# Time elapsed: 0.5080585479736328 sec
#
# maximum relative error: 3.435269355773926%
# ------------------------------------------------------------------------
#
# Test #180
# ------------------------------------------------------------------------
# DEIM_basis: 42, DEIM_samples: 47
#
# Time elapsed: 0.5111138820648193 sec
#
# maximum relative error: 3.0516440868377686%
# ------------------------------------------------------------------------
#
# Test #181
# ------------------------------------------------------------------------
# DEIM_basis: 42, DEIM_samples: 48
#
# Time elapsed: 0.5082700252532959 sec
#
# maximum relative error: 6.393155574798584%
# ------------------------------------------------------------------------
#
# Test #182
# ------------------------------------------------------------------------
# DEIM_basis: 42, DEIM_samples: 49
#
# Time elapsed: 0.5127832889556885 sec
#
# maximum relative error: 7.282600402832031%
# ------------------------------------------------------------------------
#
# Test #183
# ------------------------------------------------------------------------
# DEIM_basis: 43, DEIM_samples: 43
#
# Time elapsed: 0.4649982452392578 sec
#
# maximum relative error: 100.0%
# ------------------------------------------------------------------------
#
# Test #184
# ------------------------------------------------------------------------
# DEIM_basis: 43, DEIM_samples: 44
#
# Time elapsed: 0.5549066066741943 sec
#
# maximum relative error: 100.0%
# ------------------------------------------------------------------------
#
# Test #185
# ------------------------------------------------------------------------
# DEIM_basis: 43, DEIM_samples: 45
#
# Time elapsed: 0.5244333744049072 sec
#
# maximum relative error: 100.0%
# ------------------------------------------------------------------------
#
# Test #186
# ------------------------------------------------------------------------
# DEIM_basis: 43, DEIM_samples: 46
#
# Time elapsed: 0.5592615604400635 sec
#
# maximum relative error: 100.0%
# ------------------------------------------------------------------------
#
# Test #187
# ------------------------------------------------------------------------
# DEIM_basis: 43, DEIM_samples: 47
# Time elapsed: 0.5149490833282471 sec
#
# maximum relative error: 100.0%
# ------------------------------------------------------------------------
#
# Test #188
# ------------------------------------------------------------------------
# DEIM_basis: 43, DEIM_samples: 48
#
# Time elapsed: 0.47174835205078125 sec
#
# maximum relative error: 100.0%
# ------------------------------------------------------------------------
#
# Test #189
# ------------------------------------------------------------------------
# DEIM_basis: 43, DEIM_samples: 49
#
# Time elapsed: 0.5135459899902344 sec
#
# maximum relative error: 100.0%
# ------------------------------------------------------------------------
#
# Test #190
# ------------------------------------------------------------------------
# DEIM_basis: 44, DEIM_samples: 44
#
# Time elapsed: 0.5448150634765625 sec
#
# maximum relative error: 3.1123874187469482%
# ------------------------------------------------------------------------
#
# Test #191
# ------------------------------------------------------------------------
# DEIM_basis: 44, DEIM_samples: 45
#
# Time elapsed: 0.5562498569488525 sec
#
# maximum relative error: 2.11189866065979%
# ------------------------------------------------------------------------
#
# Test #192
# ------------------------------------------------------------------------
# DEIM_basis: 44, DEIM_samples: 46
#
# Time elapsed: 0.5542738437652588 sec
#
# maximum relative error: 3.4272446632385254%
# ------------------------------------------------------------------------
#
# Test #193
# ------------------------------------------------------------------------
# DEIM_basis: 44, DEIM_samples: 47
#
# Time elapsed: 0.5533373355865479 sec
#
# maximum relative error: 2.288275957107544%
# ------------------------------------------------------------------------
#
# Test #194
# ------------------------------------------------------------------------
# DEIM_basis: 44, DEIM_samples: 48
#
# Time elapsed: 0.5502023696899414 sec
#
# maximum relative error: 2.110722541809082%
# ------------------------------------------------------------------------
#
# Test #195
# ------------------------------------------------------------------------
# DEIM_basis: 44, DEIM_samples: 49
#
# Time elapsed: 0.5553288459777832 sec
#
# maximum relative error: 1.9642248153686523%
# ------------------------------------------------------------------------
#
# Test #196
# ------------------------------------------------------------------------
# DEIM_basis: 45, DEIM_samples: 45
#
# Time elapsed: 0.24341344833374023 sec
#
# maximum relative error: 100.0%
# ------------------------------------------------------------------------
#
# Test #197
# ------------------------------------------------------------------------
# DEIM_basis: 45, DEIM_samples: 46
#
# Time elapsed: 0.18129444122314453 sec
#
# maximum relative error: 100.0%
# ------------------------------------------------------------------------
#
# Test #198
# ------------------------------------------------------------------------
# DEIM_basis: 45, DEIM_samples: 47
#
# Time elapsed: 0.0345001220703125 sec
#
# maximum relative error: 100.0%
# ------------------------------------------------------------------------
#
# Test #199
# ------------------------------------------------------------------------
# DEIM_basis: 45, DEIM_samples: 48
#
# Time elapsed: 0.003594636917114258 sec
#
# maximum relative error: 100.0%
# ------------------------------------------------------------------------
#
# Test #200
# ------------------------------------------------------------------------
# DEIM_basis: 45, DEIM_samples: 49
#
# Time elapsed: 0.5757462978363037 sec
#
# maximum relative error: 100.0%
# ------------------------------------------------------------------------
#
# Test #201
# ------------------------------------------------------------------------
# DEIM_basis: 46, DEIM_samples: 46
#
# Time elapsed: 0.5033705234527588 sec
#
# maximum relative error: 1.9028306007385254%
# ------------------------------------------------------------------------
#
# Test #202
# ------------------------------------------------------------------------
# DEIM_basis: 46, DEIM_samples: 47
#
# Time elapsed: 0.5021069049835205 sec
#
# maximum relative error: 1.5174518823623657%
# ------------------------------------------------------------------------
#
# Test #203
# ------------------------------------------------------------------------
# DEIM_basis: 46, DEIM_samples: 48
#
# Time elapsed: 0.5082414150238037 sec
#
# maximum relative error: 1.372115969657898%
# ------------------------------------------------------------------------
#
# Test #204
# ------------------------------------------------------------------------
# DEIM_basis: 46, DEIM_samples: 49
#
# Time elapsed: 0.5043647289276123 sec
#
# maximum relative error: 1.5600844621658325%
# ------------------------------------------------------------------------
#
# Test #205
# ------------------------------------------------------------------------
# DEIM_basis: 47, DEIM_samples: 47
#
# Time elapsed: 0.5283863544464111 sec
#
# maximum relative error: 3.636742115020752%
# ------------------------------------------------------------------------
#
# Test #206
# ------------------------------------------------------------------------
# DEIM_basis: 47, DEIM_samples: 48
#
# Time elapsed: 0.5255804061889648 sec
#
# maximum relative error: 1.7102824449539185%
# ------------------------------------------------------------------------
#
# Test #207
# ------------------------------------------------------------------------
# DEIM_basis: 47, DEIM_samples: 49
#
# Time elapsed: 0.5332188606262207 sec
#
# maximum relative error: 2.886612892150879%
# ------------------------------------------------------------------------
#
# Test #208
# ------------------------------------------------------------------------
# DEIM_basis: 48, DEIM_samples: 48
#
# Time elapsed: 0.539971113204956 sec
#
# maximum relative error: 2.8529469966888428%
# ------------------------------------------------------------------------
#
# Test #209
# ------------------------------------------------------------------------
# DEIM_basis: 48, DEIM_samples: 49
#
# Time elapsed: 0.5383760929107666 sec
#
# maximum relative error: 1.8526242971420288%
# ------------------------------------------------------------------------
#
# Test #210
# ------------------------------------------------------------------------
# DEIM_basis: 49, DEIM_samples: 49
#
# Time elapsed: 0.5231852531433105 sec
#
# maximum relative error: 2.607984781265259%
# ------------------------------------------------------------------------
#
# DEIM test time elapsed: 178.53956294059753 sec

# %%
print(test_results[np.argsort(test_results[:,-1])])
# Out:
# [[3.10000000e+01 4.70000000e+01 6.26815081e-01 1.03491020e+00]
#  [3.30000000e+01 4.90000000e+01 5.14684677e-01 1.07100010e+00]
#  [3.60000000e+01 4.00000000e+01 4.93350983e-01 1.17755771e+00]
#  [3.20000000e+01 4.70000000e+01 4.96129036e-01 1.22673225e+00]
#  [4.00000000e+01 4.20000000e+01 5.07647276e-01 1.23244047e+00]
#  [3.20000000e+01 4.60000000e+01 4.95876789e-01 1.25104022e+00]
#  [3.60000000e+01 3.90000000e+01 4.91511583e-01 1.32812285e+00]
#  [3.10000000e+01 4.60000000e+01 6.96383238e-01 1.34195626e+00]
#  [3.70000000e+01 3.90000000e+01 4.90703344e-01 1.34630954e+00]
#  [3.10000000e+01 4.50000000e+01 6.93871021e-01 1.36725342e+00]
#  [4.10000000e+01 4.30000000e+01 5.17099380e-01 1.36802435e+00]
#  [4.60000000e+01 4.80000000e+01 5.08241415e-01 1.37211597e+00]
#  [3.20000000e+01 4.80000000e+01 5.00041485e-01 1.37331426e+00]
#  [3.30000000e+01 4.80000000e+01 5.03409147e-01 1.40102029e+00]
#  [3.70000000e+01 4.10000000e+01 4.91891623e-01 1.44665217e+00]
#  [3.80000000e+01 4.20000000e+01 5.02195120e-01 1.47321355e+00]
#  [3.30000000e+01 4.70000000e+01 5.07155180e-01 1.47382057e+00]
#  [4.60000000e+01 4.70000000e+01 5.02106905e-01 1.51745188e+00]
#  [4.60000000e+01 4.90000000e+01 5.04364729e-01 1.56008446e+00]
#  [3.10000000e+01 4.80000000e+01 4.97690439e-01 1.56114721e+00]
#  [3.70000000e+01 4.00000000e+01 4.89664078e-01 1.57885087e+00]
#  [3.80000000e+01 4.10000000e+01 5.04017353e-01 1.59615254e+00]
#  [3.60000000e+01 3.80000000e+01 4.86068249e-01 1.64964771e+00]
#  [3.20000000e+01 4.90000000e+01 4.98798847e-01 1.66784930e+00]
#  [3.60000000e+01 3.70000000e+01 4.90762234e-01 1.68845260e+00]
#  [4.70000000e+01 4.80000000e+01 5.25580406e-01 1.71028244e+00]
#  [4.20000000e+01 4.40000000e+01 5.04454613e-01 1.72320843e+00]
#  [3.80000000e+01 4.00000000e+01 4.98895884e-01 1.72369885e+00]
#  [3.30000000e+01 3.50000000e+01 4.99051809e-01 1.80820024e+00]
#  [4.80000000e+01 4.90000000e+01 5.38376093e-01 1.85262430e+00]
#  [3.70000000e+01 3.80000000e+01 4.90003347e-01 1.85847521e+00]
#  [4.60000000e+01 4.60000000e+01 5.03370523e-01 1.90283060e+00]
#  [4.10000000e+01 4.10000000e+01 5.16122818e-01 1.94238496e+00]
#  [4.40000000e+01 4.90000000e+01 5.55328846e-01 1.96422482e+00]
#  [3.40000000e+01 4.70000000e+01 4.97029781e-01 1.96829045e+00]
#  [3.30000000e+01 3.30000000e+01 5.01669168e-01 1.96918988e+00]
#  [3.00000000e+01 4.60000000e+01 6.96921110e-01 1.97241509e+00]
#  [3.80000000e+01 4.30000000e+01 5.06641388e-01 2.09333229e+00]
#  [4.40000000e+01 4.80000000e+01 5.50202370e-01 2.11072254e+00]
#  [4.40000000e+01 4.50000000e+01 5.56249857e-01 2.11189866e+00]
#  [3.60000000e+01 4.10000000e+01 4.97814894e-01 2.14719200e+00]
#  [3.30000000e+01 4.60000000e+01 5.02102613e-01 2.21560740e+00]
#  [3.00000000e+01 4.70000000e+01 7.16307878e-01 2.25394607e+00]
#  [3.70000000e+01 4.20000000e+01 4.95110989e-01 2.25832057e+00]
#  [4.00000000e+01 4.00000000e+01 5.08888960e-01 2.28231788e+00]
#  [4.40000000e+01 4.70000000e+01 5.53337336e-01 2.28827596e+00]
#  [4.20000000e+01 4.20000000e+01 5.03597498e-01 2.29422140e+00]
#  [3.70000000e+01 3.70000000e+01 4.88048792e-01 2.29600835e+00]
#  [3.80000000e+01 3.90000000e+01 4.99689579e-01 2.35572696e+00]
#  [3.50000000e+01 3.70000000e+01 5.02469301e-01 2.41555357e+00]
#  [3.60000000e+01 4.50000000e+01 4.97953176e-01 2.47117996e+00]
#  [3.20000000e+01 3.40000000e+01 4.82800961e-01 2.47624111e+00]
#  [3.70000000e+01 4.60000000e+01 4.98706341e-01 2.49600506e+00]
#  [3.00000000e+01 4.00000000e+01 7.88197279e-01 2.51761889e+00]
#  [3.40000000e+01 3.60000000e+01 4.90564108e-01 2.52009726e+00]
#  [3.30000000e+01 3.90000000e+01 4.95799541e-01 2.53221846e+00]
#  [3.60000000e+01 3.60000000e+01 4.84436750e-01 2.57970977e+00]
#  [3.30000000e+01 3.80000000e+01 4.95079994e-01 2.60156202e+00]
#  [4.90000000e+01 4.90000000e+01 5.23185253e-01 2.60798478e+00]
#  [3.80000000e+01 3.80000000e+01 5.01548290e-01 2.79896855e+00]
#  [3.20000000e+01 4.50000000e+01 4.88564253e-01 2.83408499e+00]
#  [4.80000000e+01 4.80000000e+01 5.39971113e-01 2.85294700e+00]
#  [3.60000000e+01 4.20000000e+01 4.97493505e-01 2.87988281e+00]
#  [4.70000000e+01 4.90000000e+01 5.33218861e-01 2.88661289e+00]
#  [3.30000000e+01 4.00000000e+01 4.98188972e-01 2.91841245e+00]
#  [3.80000000e+01 4.70000000e+01 5.07282019e-01 2.92373013e+00]
#  [3.30000000e+01 4.30000000e+01 5.03859758e-01 2.95171094e+00]
#  [3.50000000e+01 4.90000000e+01 5.12658834e-01 3.02516603e+00]
#  [3.10000000e+01 4.40000000e+01 6.90298796e-01 3.04736519e+00]
#  [4.20000000e+01 4.70000000e+01 5.11113882e-01 3.05164409e+00]
#  [3.40000000e+01 4.90000000e+01 5.04736423e-01 3.05624819e+00]
#  [3.70000000e+01 4.30000000e+01 4.98736382e-01 3.07366657e+00]
#  [4.40000000e+01 4.40000000e+01 5.44815063e-01 3.11238742e+00]
#  [3.60000000e+01 4.30000000e+01 4.98837948e-01 3.13161898e+00]
#  [3.70000000e+01 4.80000000e+01 5.03142834e-01 3.21834016e+00]
#  [3.20000000e+01 3.20000000e+01 4.80219364e-01 3.22108531e+00]
#  [3.30000000e+01 4.10000000e+01 4.95988607e-01 3.24327040e+00]
#  [3.30000000e+01 3.70000000e+01 4.94029522e-01 3.26944304e+00]
#  [3.20000000e+01 3.70000000e+01 4.87132788e-01 3.27277732e+00]
#  [4.00000000e+01 4.50000000e+01 5.03559828e-01 3.29783750e+00]
#  [3.30000000e+01 4.20000000e+01 5.02297163e-01 3.30929875e+00]
#  [4.20000000e+01 4.30000000e+01 5.06121397e-01 3.32489920e+00]
#  [3.30000000e+01 3.60000000e+01 4.90558147e-01 3.35996437e+00]
#  [3.30000000e+01 3.40000000e+01 4.92081642e-01 3.40679407e+00]
#  [4.40000000e+01 4.60000000e+01 5.54273844e-01 3.42724466e+00]
#  [4.20000000e+01 4.60000000e+01 5.08058548e-01 3.43526936e+00]
#  [3.20000000e+01 3.80000000e+01 4.85089302e-01 3.44771886e+00]
#  [3.20000000e+01 4.20000000e+01 4.94679689e-01 3.45002532e+00]
#  [4.00000000e+01 4.90000000e+01 5.08412361e-01 3.45483112e+00]
#  [3.70000000e+01 4.40000000e+01 5.02341032e-01 3.45695090e+00]
#  [3.40000000e+01 3.40000000e+01 4.84376431e-01 3.46536827e+00]
#  [3.80000000e+01 4.90000000e+01 5.14645576e-01 3.48553276e+00]
#  [3.20000000e+01 4.10000000e+01 5.48001289e-01 3.50460458e+00]
#  [3.80000000e+01 4.50000000e+01 5.15048265e-01 3.55325818e+00]
#  [3.80000000e+01 4.40000000e+01 5.14322042e-01 3.56139278e+00]
#  [3.60000000e+01 4.60000000e+01 4.93240356e-01 3.57114148e+00]
#  [3.40000000e+01 3.90000000e+01 5.05224705e-01 3.59622455e+00]
#  [3.50000000e+01 4.40000000e+01 5.12465239e-01 3.61662769e+00]
#  [3.60000000e+01 4.40000000e+01 4.98851061e-01 3.62342310e+00]
#  [4.70000000e+01 4.70000000e+01 5.28386354e-01 3.63674212e+00]
#  [4.20000000e+01 4.50000000e+01 5.05964279e-01 3.66137624e+00]
#  [3.70000000e+01 4.90000000e+01 5.02152920e-01 3.67623353e+00]
#  [4.10000000e+01 4.60000000e+01 5.06404877e-01 3.76034498e+00]
#  [3.20000000e+01 3.90000000e+01 4.86221313e-01 3.78734851e+00]
#  [3.20000000e+01 4.00000000e+01 4.83568907e-01 3.79494810e+00]
#  [3.70000000e+01 4.70000000e+01 4.99346733e-01 3.80807662e+00]
#  [3.40000000e+01 4.80000000e+01 4.99035597e-01 3.81027174e+00]
#  [3.40000000e+01 4.30000000e+01 4.90195036e-01 3.90902758e+00]
#  [3.10000000e+01 4.10000000e+01 6.94360971e-01 3.94469500e+00]
#  [4.00000000e+01 4.10000000e+01 5.00826597e-01 3.97624898e+00]
#  [3.20000000e+01 3.60000000e+01 4.85793352e-01 3.99021459e+00]
#  [4.10000000e+01 4.40000000e+01 5.05650520e-01 4.00628138e+00]
#  [3.10000000e+01 4.00000000e+01 6.98342085e-01 4.00675964e+00]
#  [4.00000000e+01 4.60000000e+01 5.08590460e-01 4.03309965e+00]
#  [3.00000000e+01 3.50000000e+01 7.87574291e-01 4.04250479e+00]
#  [4.10000000e+01 4.20000000e+01 5.07269859e-01 4.05476665e+00]
#  [3.80000000e+01 4.60000000e+01 5.14292240e-01 4.05682230e+00]
#  [3.40000000e+01 3.80000000e+01 5.11068583e-01 4.08747149e+00]
#  [3.70000000e+01 4.50000000e+01 5.00497580e-01 4.10862541e+00]
#  [4.10000000e+01 4.50000000e+01 5.04013062e-01 4.12441492e+00]
#  [4.00000000e+01 4.40000000e+01 5.03176451e-01 4.16074848e+00]
#  [3.40000000e+01 4.40000000e+01 4.89580631e-01 4.16777563e+00]
#  [3.20000000e+01 3.50000000e+01 4.78491783e-01 4.18797493e+00]
#  [3.10000000e+01 3.70000000e+01 6.81804657e-01 4.19008541e+00]
#  [4.00000000e+01 4.30000000e+01 5.06045818e-01 4.19674540e+00]
#  [3.30000000e+01 4.50000000e+01 4.98196363e-01 4.21596956e+00]
#  [3.10000000e+01 3.60000000e+01 6.77854300e-01 4.22037411e+00]
#  [3.00000000e+01 3.80000000e+01 7.65781403e-01 4.22173214e+00]
#  [3.20000000e+01 3.30000000e+01 4.87383366e-01 4.22849417e+00]
#  [3.00000000e+01 3.60000000e+01 7.79707909e-01 4.23358583e+00]
#  [3.40000000e+01 3.70000000e+01 5.09137630e-01 4.27625227e+00]
#  [3.40000000e+01 4.00000000e+01 4.81728077e-01 4.34730816e+00]
#  [4.10000000e+01 4.70000000e+01 5.10025978e-01 4.37154627e+00]
#  [3.10000000e+01 3.90000000e+01 6.86994314e-01 4.41282129e+00]
#  [3.10000000e+01 3.80000000e+01 6.86137915e-01 4.47085476e+00]
#  [3.10000000e+01 3.30000000e+01 6.94821358e-01 4.54822683e+00]
#  [3.10000000e+01 3.10000000e+01 6.93453550e-01 4.59636211e+00]
#  [3.40000000e+01 4.20000000e+01 4.82291698e-01 4.63448906e+00]
#  [3.20000000e+01 4.40000000e+01 4.89499092e-01 4.67395926e+00]
#  [4.00000000e+01 4.70000000e+01 5.13755560e-01 4.73911238e+00]
#  [3.30000000e+01 4.40000000e+01 5.00052929e-01 4.73943186e+00]
#  [3.50000000e+01 4.60000000e+01 5.07551670e-01 4.83229399e+00]
#  [3.40000000e+01 3.50000000e+01 5.09259462e-01 4.83969116e+00]
#  [3.10000000e+01 4.20000000e+01 6.85287476e-01 4.87206650e+00]
#  [3.10000000e+01 4.30000000e+01 6.84430361e-01 4.91365194e+00]
#  [3.00000000e+01 3.30000000e+01 7.24576473e-01 4.94156790e+00]
#  [3.40000000e+01 4.10000000e+01 4.85533714e-01 4.98260689e+00]
#  [3.20000000e+01 4.30000000e+01 4.92242336e-01 5.04965210e+00]
#  [3.50000000e+01 4.10000000e+01 5.09737492e-01 5.09847879e+00]
#  [3.80000000e+01 4.80000000e+01 5.07030487e-01 5.13697624e+00]
#  [3.10000000e+01 3.50000000e+01 6.83529377e-01 5.19803095e+00]
#  [4.10000000e+01 4.80000000e+01 5.13086796e-01 5.19914532e+00]
#  [3.10000000e+01 3.20000000e+01 6.83702469e-01 5.22009182e+00]
#  [3.50000000e+01 4.70000000e+01 5.10356903e-01 5.39334583e+00]
#  [3.50000000e+01 4.50000000e+01 5.02320766e-01 5.46251392e+00]
#  [3.60000000e+01 4.80000000e+01 5.22882700e-01 5.55522776e+00]
#  [3.10000000e+01 3.40000000e+01 6.79227114e-01 5.56798935e+00]
#  [4.10000000e+01 4.90000000e+01 5.08807421e-01 5.66304541e+00]
#  [3.50000000e+01 4.30000000e+01 5.05569696e-01 5.76221371e+00]
#  [4.00000000e+01 4.80000000e+01 5.02335310e-01 5.77478552e+00]
#  [3.50000000e+01 4.80000000e+01 5.02858162e-01 5.84576082e+00]
#  [3.60000000e+01 4.70000000e+01 5.38777351e-01 5.90754223e+00]
#  [3.50000000e+01 4.20000000e+01 5.13529301e-01 6.07341051e+00]
#  [3.00000000e+01 4.80000000e+01 7.10329771e-01 6.12852240e+00]
#  [3.40000000e+01 4.50000000e+01 4.96849775e-01 6.25694227e+00]
#  [4.20000000e+01 4.80000000e+01 5.08270025e-01 6.39315557e+00]
#  [3.10000000e+01 4.90000000e+01 5.06738424e-01 6.41902542e+00]
#  [3.40000000e+01 4.60000000e+01 4.95329857e-01 6.44430208e+00]
#  [3.90000000e+01 4.90000000e+01 5.50637007e-01 6.97443485e+00]
#  [4.20000000e+01 4.90000000e+01 5.12783289e-01 7.28260040e+00]
#  [3.00000000e+01 4.20000000e+01 6.88122749e-01 1.03082094e+01]
#  [3.00000000e+01 4.50000000e+01 7.24059343e-01 1.93639526e+01]
#  [3.00000000e+01 4.10000000e+01 7.58060694e-01 1.95983391e+01]
#  [3.00000000e+01 4.90000000e+01 8.09760571e-01 2.00435658e+01]
#  [3.00000000e+01 4.30000000e+01 7.81524181e-01 2.98769264e+01]
#  [3.00000000e+01 4.40000000e+01 7.74954319e-01 3.17503452e+01]
#  [3.50000000e+01 3.50000000e+01 5.07478714e-01 1.00000000e+02]
#  [3.00000000e+01 3.10000000e+01 2.88637161e-01 1.00000000e+02]
#  [3.00000000e+01 3.90000000e+01 1.41059399e-01 1.00000000e+02]
#  [4.50000000e+01 4.90000000e+01 5.75746298e-01 1.00000000e+02]
#  [4.50000000e+01 4.50000000e+01 2.43413448e-01 1.00000000e+02]
#  [4.50000000e+01 4.60000000e+01 1.81294441e-01 1.00000000e+02]
#  [4.50000000e+01 4.70000000e+01 3.45001221e-02 1.00000000e+02]
#  [3.00000000e+01 3.20000000e+01 3.56831312e-01 1.00000000e+02]
#  [3.00000000e+01 3.40000000e+01 9.74898338e-02 1.00000000e+02]
#  [4.50000000e+01 4.80000000e+01 3.59463692e-03 1.00000000e+02]
#  [3.00000000e+01 3.70000000e+01 4.41660166e-01 1.00000000e+02]
#  [4.30000000e+01 4.90000000e+01 5.13545990e-01 1.00000000e+02]
#  [3.50000000e+01 4.00000000e+01 5.85846186e-01 1.00000000e+02]
#  [4.30000000e+01 4.70000000e+01 5.14949083e-01 1.00000000e+02]
#  [3.90000000e+01 3.90000000e+01 3.01698208e-01 1.00000000e+02]
#  [3.90000000e+01 4.00000000e+01 5.53165913e-01 1.00000000e+02]
#  [3.90000000e+01 4.10000000e+01 4.43257809e-01 1.00000000e+02]
#  [3.90000000e+01 4.20000000e+01 4.73207951e-01 1.00000000e+02]
#  [3.90000000e+01 4.30000000e+01 4.60742474e-01 1.00000000e+02]
#  [3.90000000e+01 4.40000000e+01 5.05974054e-01 1.00000000e+02]
#  [3.90000000e+01 4.50000000e+01 4.68610764e-01 1.00000000e+02]
#  [3.90000000e+01 4.60000000e+01 3.53336334e-03 1.00000000e+02]
#  [4.30000000e+01 4.80000000e+01 4.71748352e-01 1.00000000e+02]
#  [3.90000000e+01 4.70000000e+01 5.10661840e-01 1.00000000e+02]
#  [3.60000000e+01 4.90000000e+01 4.65304136e-01 1.00000000e+02]
#  [3.50000000e+01 3.90000000e+01 4.87115860e-01 1.00000000e+02]
#  [3.50000000e+01 3.80000000e+01 4.99582052e-01 1.00000000e+02]
#  [3.50000000e+01 3.60000000e+01 5.19860029e-01 1.00000000e+02]
#  [4.30000000e+01 4.30000000e+01 4.64998245e-01 1.00000000e+02]
#  [4.30000000e+01 4.40000000e+01 5.54906607e-01 1.00000000e+02]
#  [4.30000000e+01 4.50000000e+01 5.24433374e-01 1.00000000e+02]
#  [4.30000000e+01 4.60000000e+01 5.59261560e-01 1.00000000e+02]
#  [3.90000000e+01 4.80000000e+01 5.25641203e-01 1.00000000e+02]
#  [3.00000000e+01 3.00000000e+01 3.07001114e-01 1.00000000e+02]]

# %%
# choose # of DEIM basis and DEIM samples
DEIM_basis=int(test_results[np.argsort(test_results[:,-1])[0]][0])
DEIM_samples=int(test_results[np.argsort(test_results[:,-1])[0]][1])
print('# of residual basis: {}'.format(DEIM_basis))
print('# of residual sampes: {}'.format(DEIM_samples))

# precompute
phi_r=Ur[:,:DEIM_basis]
z=DEIM(phi_r,DEIM_samples)
ZT=np.eye(nx-1,dtype='float32')[z]
Z=ZT.T
precomp1=phi_r@np.linalg.pinv(ZT@phi_r)
precomp=precomp1.T@precomp1

# influential indices
z_union=np.zeros((z.size,2),dtype='int')
for i in range(z.size):
    if z[i]==0:
        z_union[i,0]=0
        z_union[i,1]=nx-2
    else:
        z_union[i,0]=z[i]
        z_union[i,1]=z[i]-1        
z0=z_union[:,0]
z1=z_union[:,1]

z_union=np.unique(z_union.flatten())

z_union0_ind=np.zeros(z0.size,dtype='int')
z_union1_ind=np.zeros(z1.size,dtype='int')
for i in range(z0.size):
    z_union0_ind[i]=np.nonzero(np.isin(z_union,z0[i]))[0]
    z_union1_ind[i]=np.nonzero(np.isin(z_union,z1[i]))[0]

# Construct subnet
class DecoderFC(nn.Module):

    def __init__(self,):
        super(DecoderFC, self).__init__()
        self.fc1 = nn.Linear(f,M2,bias=False)
        self.fc1.weight = nn.Parameter(torch.ones(de_w1.shape))
#         self.fc1.weight = nn.Parameter(torch.tensor(de_w1))

        self.fc2 = nn.Linear(M2,m,bias=False)
        self.fc2.weight = nn.Parameter(torch.ones(de_w2.shape))
#         self.fc2.weight = nn.Parameter(torch.tensor(de_w2))

    def forward(self, x):
        x = self.fc1(x)
        x = self.fc2(x)
        return x

model = DecoderFC()

x_in=torch.ones(f)
y_out=model(x_in)

p_hr=z_union

upstream=torch.zeros_like(y_out)
upstream[p_hr]=1.0

y_out.backward(upstream)

# masks for subnet
w1_mask=model.fc1.weight.grad
w2_mask=model.fc2.weight.grad

# subnet sparse weight
idx1=w1_mask.to_sparse()._indices()
i1=idx1.numpy()[0]
j1=idx1.numpy()[1]
v1=de_w1[i1,j1]
w1_sb_sp=sp.csr_matrix(sp.csr_matrix((v1,(i1,j1)),shape=w1_mask.shape).toarray())

idx2=w2_mask.to_sparse()._indices()
i2=idx2.numpy()[0]
j2=idx2.numpy()[1]
v2=de_w2[i2,j2]
w2_sb_sp=sp.csr_matrix(sp.csr_matrix((v2,(i2,j2)),shape=w2_mask.shape).toarray())

# subnet compressed weight
i1,j1,v1=sp.find(w1_sb_sp)
i1_unique,i1_inverse=np.unique(i1,return_inverse=True)
i1_comp=np.arange(i1_unique.size)
i1_comp=i1_comp[i1_inverse]
j1_unique,j1_inverse=np.unique(j1,return_inverse=True)
j1_comp=np.arange(j1_unique.size)
j1_comp=j1_comp[j1_inverse]
w1_sb_comp_sp=sp.csr_matrix((v1,(i1_comp,j1_comp)),shape=(i1_unique.size,j1_unique.size))

i2,j2,v2=sp.find(w2_sb_sp)
i2_unique,i2_inverse=np.unique(i2,return_inverse=True)
i2_comp=np.arange(i2_unique.size)
i2_comp=i2_comp[i2_inverse]
j2_unique,j2_inverse=np.unique(j2,return_inverse=True)
j2_comp=np.arange(j2_unique.size)
j2_comp=j2_comp[j2_inverse]
w2_sb_comp_sp=sp.csr_matrix((v2,(i2_comp,j2_comp)),shape=(i2_unique.size,j2_unique.size))

w1_sb_comp_dense=w1_sb_comp_sp.toarray()
w1_sb_comp_dense=w1_sb_comp_dense[j2_unique]
w2_sb_comp_dense=w2_sb_comp_sp.toarray()

w1_sb_comp_denseT=w1_sb_comp_dense.T
w2_sb_comp_denseT=w2_sb_comp_dense.T

# Using sparse matrix
w2_sb_comp_sp=sp.csr_matrix(w2_sb_comp_dense,dtype='float32')
w2_sb_comp_spT=sp.csr_matrix(w2_sb_comp_denseT,dtype='float32')

def sigmoid_np(input):
    return (1.0/(1.0+np.exp(-input))).astype('float32')

def decoder_sb_np_forward(x):
    z1 = w1_sb_comp_dense.dot(x)
    s1 = sigmoid_np(z1)
    a1 = z1*s1
    y = w2_sb_comp_dense.dot(a1)  
    return y

def decoder_sb_np_forward_backward(x):
    z1 = w1_sb_comp_dense.dot(x)
    s1 = sigmoid_np(z1)
    a1 = z1*s1
    y = w2_sb_comp_dense.dot(a1) 

    dout = w1_sb_comp_denseT
    dout = (a1 + s1*(1-a1))*dout
    dydxT = dout.dot(w2_sb_comp_denseT)
    return y,dydxT.T

def decoder_sb_sp_forward(x):
    z1 = w1_sb_comp_dense.dot(x)
    s1 = sigmoid_np(z1)
    a1 = z1*s1
    y = sp.csr_matrix.dot(w2_sb_comp_sp,a1)
    return y

def decoder_sb_sp_forward_backward(x):
    z1 = w1_sb_comp_dense.dot(x)
    s1 = sigmoid_np(z1)
    a1 = z1*s1
    y = sp.csr_matrix.dot(w2_sb_comp_sp,a1)

    dout = w1_sb_comp_denseT
    dout = (a1 + s1*(1-a1))*dout
    dydxT = sp.csr_matrix.dot(dout,w2_sb_comp_spT)
    return y,dydxT.T

# Run NM-ROM-DEIM
t_total_rom_hr_start=time.time()

u_rom_lspg_hr = np.zeros((nt+1,nx),dtype='float32')
u_rom_lspg_hr[0] = u0.astype('float32')
u_hat = np.zeros((nt+1,f),dtype='float32')
u_hat[0] = u_hat0
I_hat = np.eye(f,dtype='float32')
for n in range(nt): 
#     print("")
#     print(n,"th time step:")

    u_hatw = u_hat[n].copy()

    uw, Jg = decoder_sb_sp_forward_backward(u_hatw)
    uw += u0[z_union]

    J_lspg = jacobian_lspg_hr(uw,Jg,z_union0_ind,z_union1_ind,c)
    J_lspgT = J_lspg.T

    r_lspg = residual_lspg_hr(u_rom_lspg_hr[n,z],uw,z_union0_ind,z_union1_ind,c)
    r = J_lspgT.dot(precomp.dot(r_lspg))

    for k in range(maxk):   
        J = J_lspgT@precomp@J_lspg

        du_hatw = np.linalg.solve(J,-r)

        u_hatw = u_hatw + du_hatw

        uw, Jg = decoder_sb_sp_forward_backward(u_hatw)
        uw += u0[z_union]

        J_lspg = jacobian_lspg_hr(uw,Jg,z_union0_ind,z_union1_ind,c)
        J_lspgT = J_lspg.T

        r_lspg = residual_lspg_hr(u_rom_lspg_hr[n,z],uw,z_union0_ind,z_union1_ind,c)
        r = J_lspgT.dot(precomp.dot(r_lspg))

        res = np.linalg.norm(r)
#         print(k,"th Newton iteration", "res:", "{:.8e}".format(res))

        if res < convergence_threshold:
            u_hat[n+1] = u_hatw.copy()
            u_rom_lspg_hr[n+1,:-1] = u0[:-1] + decoder_sp_forward(u_hat[n+1])
            u_rom_lspg_hr[n+1,-1] = u_rom_lspg_hr[n+1,0]
            break

    if res >= convergence_threshold:
#                     print("\n non converged after {}th iteration".format(maxk))
        break

#     u_hat[n+1] = u_hatw.copy()
#     u_rom_lspg_hr[n+1,:-1] = u0[:-1] + decoder_sp_forward(u_hat[n+1])
#     u_rom_lspg_hr[n+1,-1] = u_rom_lspg_hr[n+1,0]

t_total_rom_hr=time.time()-t_total_rom_hr_start
print()
print("Time elapsed: {} sec".format(t_total_rom_hr))

# Compute errors
rel_err=np.linalg.norm(u-u_rom_lspg_hr,axis=1)/np.linalg.norm(u,axis=1)*100
avg_rel_err=np.sqrt(np.sum(np.linalg.norm(u-u_rom_lspg_hr,ord=2,axis=1)**2))/np.sqrt(np.sum(np.linalg.norm(u,ord=2,axis=1)**2))*100
max_rel_err = np.max(rel_err)     

plt.plot(dt*np.arange(nt+1),rel_err)
plt.xlabel('Time (sec)')
plt.ylabel('Relative Error (%)')
plt.show()

print("average relative error: {}%".format(avg_rel_err))
print()
print("maximum relative error: {}%".format(max_rel_err))
print('-'*72)
# Out:
# # of residual basis: 31
# # of residual sampes: 47
#
# Time elapsed: 0.49257373809814453 sec
# average relative error: 0.42329574935138226%
#
# maximum relative error: 1.0349102020263672%
# ------------------------------------------------------------------------
