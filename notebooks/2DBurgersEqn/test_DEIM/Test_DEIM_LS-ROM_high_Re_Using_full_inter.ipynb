# %%
import numpy as np
from scipy import sparse as sp
from scipy.sparse.linalg import spsolve
from matplotlib import pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
import time, sys
import pickle

# %%
# Choose either Re=1000 or Re=100
Re=10000

# %%
# choose # of DEIM basis file name
if Re==10000:
    file_name="./data/snapshot_full_high_Re.p"
    file_name_inter="./data/snapshot_full_inter_high_Re.p"
elif Re==100:
    file_name="./data/snapshot_full_low_Re.p"
    file_name_inter="./data/snapshot_full_inter_low_Re.p"
else:
    raise NameError('{} is given for Re, but it must be either 100 or 10000'.format(Re))

# %%
# load full order solution
if Re==10000:
    FOM_solution=pickle.load(open('./data/FOM_high_Re.p','rb'))
elif Re==100:
    FOM_solution=pickle.load(open('./data/FOM_loq_Re.p','rb'))
else:
    raise NameError('{} is given for Re, but it must be either 100 or 10000'.format(Re))
    
u_full=FOM_solution['u']
v_full=FOM_solution['v']

# %%
# Set parameters
if Re==10000:
    nx=60
    ny=60
    nt=1500
elif Re==100:
    nx=60
    ny=60
    nt=1500
else:
    raise NameError('{} is given for Re, but it must be either 100 or 10000'.format(Re))
    
nxy=(nx-2)*(ny-2)
dx=1/(nx-1)
dy=1/(ny-1)
dt=2/nt

I=sp.eye(nxy,format='csr')

# full indicies, free indicies, fixed indicies
[xv,yv]=np.meshgrid(np.linspace(0,1,nx),np.linspace(0,1,ny),indexing='xy')
x=xv.flatten()
y=yv.flatten()

multi_index_i,multi_index_j=np.meshgrid(np.arange(nx),np.arange(ny),indexing='xy')
full_multi_index=(multi_index_j.flatten(),multi_index_i.flatten())
free_multi_index=(multi_index_j[1:-1,1:-1].flatten(),multi_index_i[1:-1,1:-1].flatten())
x0_multi_index=(multi_index_j[1:-1,0].flatten(),multi_index_i[1:-1,0].flatten())
x1_multi_index=(multi_index_j[1:-1,-1].flatten(),multi_index_i[1:-1,-1].flatten())
y0_multi_index=(multi_index_j[0,1:-1].flatten(),multi_index_i[0,1:-1].flatten())
y1_multi_index=(multi_index_j[-1,1:-1].flatten(),multi_index_i[-1,1:-1].flatten())

dims=(ny,nx)
full_raveled_indicies=np.ravel_multi_index(full_multi_index,dims)
free_raveled_indicies=np.ravel_multi_index(free_multi_index,dims)
x0_raveled_indicies=np.ravel_multi_index(x0_multi_index,dims)
x1_raveled_indicies=np.ravel_multi_index(x1_multi_index,dims)
x01_raveled_indicies=np.concatenate((x0_raveled_indicies,x1_raveled_indicies))
y0_raveled_indicies=np.ravel_multi_index(y0_multi_index,dims)
y1_raveled_indicies=np.ravel_multi_index(y1_multi_index,dims)
y01_raveled_indicies=np.concatenate((y0_raveled_indicies,y1_raveled_indicies))
fixed_raveled_indicies=np.setdiff1d(full_raveled_indicies,free_raveled_indicies)

# boundary one-hot vector
x0_one_hot=np.eye(nx-2)[0]
y0_one_hot=np.eye(ny-2)[0]
x1_one_hot=np.eye(nx-2)[-1]
y1_one_hot=np.eye(ny-2)[-1]

# inner grid
inner_multi_index_i,inner_multi_index_j=np.meshgrid(np.arange(nx-2),np.arange(ny-2),indexing='xy')
inner_x_multi_index=(np.concatenate((inner_multi_index_j[:,0].flatten(),inner_multi_index_j[:,-1].flatten())),
                     np.concatenate((inner_multi_index_i[:,0].flatten(),inner_multi_index_i[:,-1].flatten())))
inner_y_multi_index=(np.concatenate((inner_multi_index_j[0,:].flatten(),inner_multi_index_j[-1,:].flatten())),
                     np.concatenate((inner_multi_index_i[0,:].flatten(),inner_multi_index_i[-1,:].flatten())))

inner_dims=(ny-2,nx-2)
inner_x_raveled_indicies=np.ravel_multi_index(inner_x_multi_index,inner_dims)
inner_y_raveled_indicies=np.ravel_multi_index(inner_y_multi_index,inner_dims)

# %%
# first order derivative
# central
Mb=sp.diags([np.ones(nx-2),-np.ones(nx-2)],[0,-1],(nx-2,nx-2))
M=sp.kron(sp.eye(ny-2),Mb,format="csr")

Ib=sp.eye(nx-2)
N=sp.kron(sp.diags([np.ones(ny-2),-np.ones(ny-2)],[0,-1],(ny-2,ny-2)),Ib,format="csr")

# laplacian operator
Dxb=sp.diags([-2*np.ones(nx-2),np.ones(nx-2),np.ones(nx-2)],[0,-1,1],(nx-2,nx-2))
Dx=sp.kron(sp.eye(ny-2),Dxb,format="csr")

Ib=sp.eye(nx-2)
Dy=sp.kron(sp.diags([-2*np.ones(ny-2),np.ones(ny-2),np.ones(ny-2)],[0,-1,1],(ny-2,ny-2)),Ib,format="csr")

# %%
# IC
u0=u_full[0]
v0=v_full[0]

# %%
# boundary for first order derivative term
Bdudx0_cur=np.kron(u0[x0_raveled_indicies],x0_one_hot)
Bdudy0_cur=np.kron(y0_one_hot,u0[y0_raveled_indicies])
Bdvdx0_cur=np.kron(v0[x0_raveled_indicies],x0_one_hot)
Bdvdy0_cur=np.kron(y0_one_hot,v0[y0_raveled_indicies])
Bdudx1_cur=np.kron(u0[x1_raveled_indicies],x1_one_hot)
Bdudy1_cur=np.kron(y1_one_hot,u0[y1_raveled_indicies])
Bdvdx1_cur=np.kron(v0[x1_raveled_indicies],x1_one_hot)
Bdvdy1_cur=np.kron(y1_one_hot,v0[y1_raveled_indicies])
    
# boundary for second order derivative term
bxu_cur=np.zeros(nxy)
byu_cur=np.zeros(nxy)
bxv_cur=np.zeros(nxy)
byv_cur=np.zeros(nxy)

bxu_cur[inner_x_raveled_indicies]=u0[x01_raveled_indicies]
byu_cur[inner_y_raveled_indicies]=u0[y01_raveled_indicies]
bxv_cur[inner_x_raveled_indicies]=v0[x01_raveled_indicies]
byv_cur[inner_y_raveled_indicies]=v0[y01_raveled_indicies]

# %%
if Re==10000:
    POD_basis=5
    file_name_POD="./model/POD_high_Re.p"
elif Re==100:
    POD_basis=5
    file_name_POD="./model/POD_low_Re.p"
else:
    raise NameError('{} is given for Re, but it must be either 100 or 10000'.format(Re))

POD = pickle.load(open(file_name_POD,'rb'))

phi_u = POD['u']
phi_v = POD['v']

phi_uT=phi_u.T
phi_vT=phi_v.T

phi_u_pinv=np.linalg.pinv(phi_u)
phi_v_pinv=np.linalg.pinv(phi_v)

u_ref = u0[free_raveled_indicies]
v_ref = v0[free_raveled_indicies]

I_hat=np.eye(POD_basis)

maxitr=10
tol=1e-8

# %%
Mu_ref=M.dot(u_ref)
Nu_ref=N.dot(u_ref)
Mv_ref=M.dot(v_ref)
Nv_ref=N.dot(v_ref)

Dxu_ref=Dx.dot(u_ref)
Dyu_ref=Dy.dot(u_ref)
Dxv_ref=Dx.dot(v_ref)
Dyv_ref=Dy.dot(v_ref)

Mphi_u=M.dot(phi_u)
Nphi_u=N.dot(phi_u)
Mphi_v=M.dot(phi_v)
Nphi_v=N.dot(phi_v)

Mphi_uT=Mphi_u.T
Nphi_uT=Nphi_u.T
Mphi_vT=Mphi_v.T
Nphi_vT=Nphi_v.T

Dxphi_u=Dx.dot(phi_u)
Dyphi_u=Dy.dot(phi_u)
Dxphi_v=Dx.dot(phi_v)
Dyphi_v=Dy.dot(phi_v)

# %%
au_cur=-1/dx*u_ref*(Mu_ref-Bdudx0_cur)-1/dy*v_ref*(Nu_ref-Bdudy0_cur) \
+1/(Re*dx**2)*(Dxu_ref+bxu_cur)+1/(Re*dy**2)*(Dyu_ref+byu_cur)
Bu_cur=-1/dx*(np.diag(u_ref).dot(Mphi_u)+np.diag(Mu_ref-Bdudx0_cur).dot(phi_u)) \
-1/dy*np.diag(v_ref).dot(Nphi_u) \
+1/(Re*dx**2)*Dxphi_u+1/(Re*dy**2)*Dyphi_u
Cu_cur=-1/dy*np.diag(Nu_ref-Bdudy0_cur).dot(phi_v)

av_cur=-1/dx*u_ref*(Mv_ref-Bdvdx0_cur)-1/dy*v_ref*(Nv_ref-Bdvdy0_cur) \
+1/(Re*dx**2)*(Dxv_ref+bxv_cur)+1/(Re*dy**2)*(Dyv_ref+byv_cur)
Bv_cur=-1/dx*np.diag(Mv_ref-Bdvdx0_cur).dot(phi_u)
Cv_cur=-1/dx*np.diag(u_ref).dot(Mphi_v) \
-1/dy*(np.diag(v_ref).dot(Nphi_v)+np.diag(Nv_ref-Bdvdy0_cur).dot(phi_v)) \
+1/(Re*dx**2)*Dxphi_v+1/(Re*dy**2)*Dyphi_v

# %%
a1_cur=-dt*au_cur
A2_cur=phi_u-dt*Bu_cur
A3_cur=-dt*Cu_cur
A2T_cur=A2_cur.T
A3T_cur=A3_cur.T

b1_cur=-dt*av_cur
B2_cur=-dt*Bv_cur
B3_cur=phi_v-dt*Cv_cur
B2T_cur=B2_cur.T
B3T_cur=B3_cur.T

A4_cur=-A2_cur.T.dot(phi_u)
A5_cur=-B2_cur.T.dot(phi_v)
a6_cur=A2_cur.T.dot(a1_cur)+B2_cur.T.dot(b1_cur)
A7_cur=A2_cur.T.dot(A2_cur)+B2_cur.T.dot(B2_cur)
A8_cur=A2_cur.T.dot(A3_cur)+B2_cur.T.dot(B3_cur)

B4_cur=-A3_cur.T.dot(phi_u)
B5_cur=-B3_cur.T.dot(phi_v)
b6_cur=A3_cur.T.dot(a1_cur)+B3_cur.T.dot(b1_cur)
B7_cur=A3_cur.T.dot(A2_cur)+B3_cur.T.dot(B2_cur)
B8_cur=A3_cur.T.dot(A3_cur)+B3_cur.T.dot(B3_cur)

# %%
def DEIM(phi_f, nfeval=None):
    
    ninf=np.NINF
    n,m=np.shape(phi_f)
    if nfeval==None:
        nfeval=m
        
    if nfeval<m:
        print("ill-posed\n")
        print("set # sampling equal to # modes")
        nfeval=m
        
    div,mod=np.divmod(nfeval,m)
    
    I=np.eye(n)
    
    l=0
    ns=div+mod
    u=np.reshape(phi_f[:,l],(n,1))
    p=np.argsort(-np.abs(u),axis=0,kind='stable')[:ns]
#     p=np.argmax(np.abs(u)) # when ns=1
    ep=np.reshape(I[:,p],(n,ns))
    U=u
    P=ep

    ns=div
    for l in range(1,m):
        u=np.reshape(phi_f[:,l],(n,1))
        PT=np.transpose(P)
        c=np.linalg.lstsq(PT@U,PT@u,rcond=None)[0]
        r=np.abs(u-U@c)
        r[p]=ninf
        p=np.append(p,np.argsort(-r,axis=0,kind='stable')[:ns]) # ns!=1
        ep=np.reshape(I[:,p[-ns:]],(n,ns))
        U=np.concatenate((U,u),axis=1)
        P=np.concatenate((P,ep),axis=1)
        
    return p

# %% [markdown]
# # Change # of basis and samples

# %%
# load sanpshots
# # snapshot: just full order solution
# snapshot = pickle.load(open(file_name,'rb'))
# snapshot_u_orig = snapshot['u']
# snapshot_v_orig = snapshot['v']

# ndata = snapshot_u_orig.shape[0]
# nset = round(ndata/(nt+1))
# data_ind = np.array([],dtype='int')
# for foo in range(nset):
#     data_ind = np.append(data_ind,np.arange(foo*(nt+1)+1,(foo+1)*(nt+1)))

# snapshot_theta_u=np.zeros((nset*nt,nxy))
# snapshot_theta_v=np.zeros((nset*nt,nxy))

# for foo in range(nset*nt):
#     k = data_ind[foo]
#     u_tilde=snapshot_u_orig[k,free_raveled_indicies]-u_ref
#     v_tilde=snapshot_v_orig[k,free_raveled_indicies]-v_ref
    
#     snapshot_theta_u[foo]=-1/dx*u_tilde*M.dot(u_tilde)-1/dy*v_tilde*N.dot(u_tilde)
#     snapshot_theta_v[foo]=-1/dx*u_tilde*M.dot(v_tilde)-1/dy*v_tilde*N.dot(v_tilde)

# snapshot: full order solution including intermediate values
snapshot = pickle.load(open(file_name_inter,'rb'))
snapshot_u_orig = snapshot['u']
snapshot_v_orig = snapshot['v']

ndata = snapshot_u_orig.shape[0]

snapshot_theta_u=np.zeros((ndata,nxy))
snapshot_theta_v=np.zeros((ndata,nxy))

for k in range(ndata):
    u_tilde=snapshot_u_orig[k]-u_ref
    v_tilde=snapshot_v_orig[k]-v_ref
    
    snapshot_theta_u[k]=-1/dx*u_tilde*M.dot(u_tilde)-1/dy*v_tilde*N.dot(u_tilde)
    snapshot_theta_v[k]=-1/dx*u_tilde*M.dot(v_tilde)-1/dy*v_tilde*N.dot(v_tilde)

# %%
# do svd decomposition
U_theta_u,S_theta_u,V_theta_uT=np.linalg.svd(snapshot_theta_u.T,full_matrices=False)
U_theta_v,S_theta_v,V_theta_vT=np.linalg.svd(snapshot_theta_v.T,full_matrices=False)

# %%
DEIM_test_tstart=time.time()

# choose # of DEIM basis and DEIM samples
DEIM_min=40
DEIM_max=60

n_test=int((DEIM_max-DEIM_min)*(DEIM_max-DEIM_min+1)/2)
print('Total # of test: {}'.format(n_test))

# save test results: [DEIM_basis, DEIM_samples, Time_elapsed, Max_rel_err]
test_results=np.zeros((n_test,4))

test_count=0
for DEIM_basis in np.arange(DEIM_min,DEIM_max):
    for DEIM_samples in np.arange(DEIM_basis,DEIM_max):
        test_count+=1
        print()
        print('Test #{}'.format(test_count))
        print('-'*72)
        print('DEIM_basis: {}, DEIM_samples: {}'.format(DEIM_basis,DEIM_samples))
        
        try:
            phi_theta_u=U_theta_u[:,:DEIM_basis]
            phi_theta_v=U_theta_v[:,:DEIM_basis]

            # precompute
            z_theta_u=DEIM(phi_theta_u,DEIM_samples)
            z_theta_v=DEIM(phi_theta_v,DEIM_samples)

            P_u=phi_theta_u.dot(np.linalg.pinv(phi_theta_u[z_theta_u]))
            P_v=phi_theta_v.dot(np.linalg.pinv(phi_theta_v[z_theta_v]))

            P_uT=P_u.T
            P_vT=P_v.T

            P_uTphi_u=P_uT.dot(phi_u)
            P_uTP_u=P_uT.dot(P_u)

            P_vTphi_v=P_vT.dot(phi_v)
            P_vTP_v=P_vT.dot(P_v)

            A2TP_u_cur=A2T_cur.dot(P_u)
            B2TP_v_cur=B2T_cur.dot(P_v)

            A3TP_u_cur=A3T_cur.dot(P_u)
            B3TP_v_cur=B3T_cur.dot(P_v)

            P_uTa1_cur=P_uT.dot(a1_cur)
            P_uTA2_cur=P_uT.dot(A2_cur)
            P_uTA3_cur=P_uT.dot(A3_cur)

            P_vTb1_cur=P_vT.dot(b1_cur)
            P_vTB2_cur=P_vT.dot(B2_cur)
            P_vTB3_cur=P_vT.dot(B3_cur)

            def ZTtheta_u(u_hat,v_hat):
                return -1/dx*phi_u[z_theta_u].dot(u_hat)*Mphi_u[z_theta_u].dot(u_hat)-1/dy*phi_v[z_theta_u].dot(v_hat)*Nphi_u[z_theta_u].dot(u_hat)

            def ZTtheta_v(u_hat,v_hat):
                return -1/dx*phi_u[z_theta_v].dot(u_hat)*Mphi_v[z_theta_v].dot(v_hat)-1/dy*phi_v[z_theta_v].dot(v_hat)*Nphi_v[z_theta_v].dot(v_hat)

            def dZTtheta_udu_hat(u_hat,v_hat):
                return -1/dx*(np.diag(Mphi_u[z_theta_u].dot(u_hat)).dot(phi_u[z_theta_u])+np.diag(phi_u[z_theta_u].dot(u_hat)).dot(Mphi_u[z_theta_u])) \
            -1/dy*(np.diag(phi_v[z_theta_u].dot(v_hat)).dot(Nphi_u[z_theta_u]))

            def dZTtheta_udv_hat(u_hat,v_hat):
                return -1/dy*(np.diag(Nphi_u[z_theta_u].dot(u_hat)).dot(phi_v[z_theta_u]))

            def dZTtheta_vdu_hat(u_hat,v_hat):
                return -1/dx*(np.diag(Mphi_v[z_theta_v].dot(v_hat)).dot(phi_u[z_theta_v]))

            def dZTtheta_vdv_hat(u_hat,v_hat):
                return -1/dx*(np.diag(phi_u[z_theta_v].dot(u_hat)).dot(Mphi_v[z_theta_v])) \
            -1/dy*(np.diag(Nphi_v[z_theta_v].dot(v_hat)).dot(phi_v[z_theta_v])+np.diag(phi_v[z_theta_v].dot(v_hat)).dot(Nphi_v[z_theta_v]))

            def dtheta_udu_hatTZ(u_hat,v_hat):
                return -1/dx*(Mphi_u[z_theta_u].dot(u_hat)*phi_uT[:,z_theta_u]+phi_u[z_theta_u].dot(u_hat)*Mphi_uT[:,z_theta_u]) \
            -1/dy*(phi_v[z_theta_u].dot(v_hat)*Nphi_uT[:,z_theta_u])

            def dtheta_udv_hatTZ(u_hat,v_hat):
                return -1/dy*(Nphi_u[z_theta_u].dot(u_hat)*phi_vT[:,z_theta_u])

            def dtheta_vdu_hatTZ(u_hat,v_hat):
                return -1/dx*(Mphi_v[z_theta_v].dot(v_hat)*phi_uT[:,z_theta_v])

            def dtheta_vdv_hatTZ(u_hat,v_hat):
                return -1/dx*(phi_u[z_theta_v].dot(u_hat)*Mphi_vT[:,z_theta_v]) \
            -1/dy*(Nphi_v[z_theta_v].dot(v_hat)*phi_vT[:,z_theta_v]+phi_v[z_theta_v].dot(v_hat)*Nphi_vT[:,z_theta_v])

            def r_hat_DEIM(u_hat,v_hat,u_hat_prev,v_hat_prev,A4_cur,A5_cur,a6_cur,A7_cur,A8_cur,B4_cur,B5_cur,b6_cur,B7_cur,B8_cur,\
                           A2TP_u_cur,A3TP_u_cur,B2TP_v_cur,B3TP_v_cur,\
                           P_uTa1_cur,P_uTA2_cur,P_uTA3_cur,P_vTb1_cur,P_vTB2_cur,P_vTB3_cur):

                r_u_hat=A4_cur.dot(u_hat_prev)+A5_cur.dot(v_hat_prev)+a6_cur+A7_cur.dot(u_hat)+A8_cur.dot(v_hat) \
                -dt*A2TP_u_cur.dot(ZTtheta_u(u_hat,v_hat))-dt*B2TP_v_cur.dot(ZTtheta_v(u_hat,v_hat)) \
                -dt*dtheta_udu_hatTZ(u_hat,v_hat).dot(-P_uTphi_u.dot(u_hat_prev)+P_uTa1_cur+P_uTA2_cur.dot(u_hat)+P_uTA3_cur.dot(v_hat)-dt*P_uTP_u.dot(ZTtheta_u(u_hat,v_hat))) \
                -dt*dtheta_vdu_hatTZ(u_hat,v_hat).dot(-P_vTphi_v.dot(v_hat_prev)+P_vTb1_cur+P_vTB2_cur.dot(u_hat)+P_vTB3_cur.dot(v_hat)-dt*P_vTP_v.dot(ZTtheta_v(u_hat,v_hat)))

                r_v_hat=B4_cur.dot(u_hat_prev)+B5_cur.dot(v_hat_prev)+b6_cur+B7_cur.dot(u_hat)+B8_cur.dot(v_hat) \
                -dt*A3TP_u_cur.dot(ZTtheta_u(u_hat,v_hat))-dt*B3TP_v_cur.dot(ZTtheta_v(u_hat,v_hat)) \
                -dt*dtheta_udv_hatTZ(u_hat,v_hat).dot(-P_uTphi_u.dot(u_hat_prev)+P_uTa1_cur+P_uTA2_cur.dot(u_hat)+P_uTA3_cur.dot(v_hat)-dt*P_uTP_u.dot(ZTtheta_u(u_hat,v_hat))) \
                -dt*dtheta_vdv_hatTZ(u_hat,v_hat).dot(-P_vTphi_v.dot(v_hat_prev)+P_vTb1_cur+P_vTB2_cur.dot(u_hat)+P_vTB3_cur.dot(v_hat)-dt*P_vTP_v.dot(ZTtheta_v(u_hat,v_hat)))

                return np.concatenate((r_u_hat,r_v_hat))

            def J_hat_DEIM(u_hat,v_hat,P_uTA2_cur,A2TP_u_cur,P_uTA3_cur,A3TP_u_cur,A7_cur,A8_cur,\
                           P_vTB2_cur,B2TP_v_cur,P_vTB3_cur,B3TP_v_cur,B7_cur,B8_cur):

                J_hat11=A7_cur-dt*A2TP_u_cur.dot(dZTtheta_udu_hat(u_hat,v_hat))-dt*B2TP_v_cur.dot(dZTtheta_vdu_hat(u_hat,v_hat)) \
                -dt*dtheta_udu_hatTZ(u_hat,v_hat).dot(P_uTA2_cur-dt*P_uTP_u.dot(dZTtheta_udu_hat(u_hat,v_hat))) \
                -dt*dtheta_vdu_hatTZ(u_hat,v_hat).dot(P_vTB2_cur-dt*P_vTP_v.dot(dZTtheta_vdu_hat(u_hat,v_hat)))

                J_hat12=A8_cur-dt*A2TP_u_cur.dot(dZTtheta_udv_hat(u_hat,v_hat))-dt*B2TP_v_cur.dot(dZTtheta_vdv_hat(u_hat,v_hat)) \
                -dt*dtheta_udu_hatTZ(u_hat,v_hat).dot(P_uTA3_cur-dt*P_uTP_u.dot(dZTtheta_udv_hat(u_hat,v_hat))) \
                -dt*dtheta_vdu_hatTZ(u_hat,v_hat).dot(P_vTB3_cur-dt*P_vTP_v.dot(dZTtheta_vdv_hat(u_hat,v_hat)))

                J_hat21=B7_cur-dt*A3TP_u_cur.dot(dZTtheta_udu_hat(u_hat,v_hat))-dt*B3TP_v_cur.dot(dZTtheta_vdu_hat(u_hat,v_hat)) \
                -dt*dtheta_udv_hatTZ(u_hat,v_hat).dot(P_uTA2_cur-dt*P_uTP_u.dot(dZTtheta_udu_hat(u_hat,v_hat))) \
                -dt*dtheta_vdv_hatTZ(u_hat,v_hat).dot(P_vTB2_cur-dt*P_vTP_v.dot(dZTtheta_vdu_hat(u_hat,v_hat)))

                J_hat22=B8_cur-dt*A3TP_u_cur.dot(dZTtheta_udv_hat(u_hat,v_hat))-dt*B3TP_v_cur.dot(dZTtheta_vdv_hat(u_hat,v_hat)) \
                -dt*dtheta_udv_hatTZ(u_hat,v_hat).dot(P_uTA3_cur-dt*P_uTP_u.dot(dZTtheta_udv_hat(u_hat,v_hat))) \
                -dt*dtheta_vdv_hatTZ(u_hat,v_hat).dot(P_vTB3_cur-dt*P_vTP_v.dot(dZTtheta_vdv_hat(u_hat,v_hat)))

                return np.block([[J_hat11,J_hat12],[J_hat21,J_hat22]])

            # run LS-ROM
            t_start_pg_DEIM=time.time()

            # solution
            u_rom_pg_DEIM=np.zeros((nt+1,ny*nx))
            v_rom_pg_DEIM=np.zeros((nt+1,ny*nx))
            u_reduced=np.zeros((nt+1,POD_basis))
            v_reduced=np.zeros((nt+1,POD_basis))

            # IC
            u_hat0=np.zeros(POD_basis)
            v_hat0=np.zeros(POD_basis)
            u_rom_pg_DEIM[0]=np.copy(u0)
            v_rom_pg_DEIM[0]=np.copy(v0)

            for k in range(nt):
            #     print("")
            #     print(k,"th time step:")

                u_hat_prev=np.copy(u_reduced[k])
                v_hat_prev=np.copy(v_reduced[k])

                u_hat=np.copy(u_reduced[k])
                v_hat=np.copy(v_reduced[k])

                residual_hat=r_hat_DEIM(u_hat,v_hat,u_hat_prev,v_hat_prev,A4_cur,A5_cur,a6_cur,A7_cur,A8_cur,B4_cur,B5_cur,b6_cur,B7_cur,B8_cur,\
                                        A2TP_u_cur,A3TP_u_cur,B2TP_v_cur,B3TP_v_cur,\
                                        P_uTa1_cur,P_uTA2_cur,P_uTA3_cur,P_vTb1_cur,P_vTB2_cur,P_vTB3_cur)

                for itr in range(maxitr):
                    Jacobian_hat=J_hat_DEIM(u_hat,v_hat,P_uTA2_cur,A2TP_u_cur,P_uTA3_cur,A3TP_u_cur,A7_cur,A8_cur,\
                                            P_vTB2_cur,B2TP_v_cur,P_vTB3_cur,B3TP_v_cur,B7_cur,B8_cur)

                    delta_reduced=np.linalg.solve(Jacobian_hat,-residual_hat)

                    u_hat+=delta_reduced[:POD_basis]
                    v_hat+=delta_reduced[POD_basis:]

                    residual_hat=r_hat_DEIM(u_hat,v_hat,u_hat_prev,v_hat_prev,A4_cur,A5_cur,a6_cur,A7_cur,A8_cur,B4_cur,B5_cur,b6_cur,B7_cur,B8_cur,\
                                            A2TP_u_cur,A3TP_u_cur,B2TP_v_cur,B3TP_v_cur,\
                                            P_uTa1_cur,P_uTA2_cur,P_uTA3_cur,P_vTb1_cur,P_vTB2_cur,P_vTB3_cur)

                    R=np.linalg.norm(residual_hat)
            #         print(itr,"th Newton iteration", "R:", R)

                    if R<tol:
                        u_reduced[k+1]=u_hat.copy()
                        v_reduced[k+1]=v_hat.copy()
                        u_rom_pg_DEIM[k+1,free_raveled_indicies]=u_ref+phi_u.dot(u_hat)
                        v_rom_pg_DEIM[k+1,free_raveled_indicies]=v_ref+phi_v.dot(v_hat)
                        # BC from exact solution
                        u_rom_pg_DEIM[k+1,fixed_raveled_indicies]=u0[fixed_raveled_indicies].copy()
                        v_rom_pg_DEIM[k+1,fixed_raveled_indicies]=v0[fixed_raveled_indicies].copy()
                        break

                if R>=tol:
                    print("\n non converged after {}th iteration".format(maxitr))
                    break  

            #     u_reduced[k+1]=u_hat.copy()
            #     v_reduced[k+1]=v_hat.copy()
            #     u_rom_g_DEIM[k+1,free_raveled_indicies]=u_ref+phi_u.dot(u_hat)
            #     v_rom_g_DEIM[k+1,free_raveled_indicies]=v_ref+phi_v.dot(v_hat)
            #     # BC from exact solution
            #     u_rom_g_DEIM[k+1,fixed_raveled_indicies]=u0[fixed_raveled_indicies].copy()
            #     v_rom_g_DEIM[k+1,fixed_raveled_indicies]=v0[fixed_raveled_indicies].copy()

            t_elapsed_pg_DEIM=time.time()-t_start_pg_DEIM
            print()
            print('Time elapsed: {} sec'.format(t_elapsed_pg_DEIM))

            # compute errors
            u_rel_err=np.linalg.norm(u_full-u_rom_pg_DEIM,ord=2,axis=1)/np.linalg.norm(u_full,ord=2,axis=1)*100
            v_rel_err=np.linalg.norm(v_full-v_rom_pg_DEIM,ord=2,axis=1)/np.linalg.norm(v_full,ord=2,axis=1)*100
            # plt.plot(dt*np.arange(nt+1),u_rel_err,dt*np.arange(nt+1),v_rel_err)
            # plt.xlabel('Time (sec)')
            # plt.ylabel('Relative Error (%)')
            # plt.legend(('u','v'))
            # plt.show()

            u_avg_rel_err=np.sqrt(np.sum(np.linalg.norm(u_full-u_rom_pg_DEIM,ord=2,axis=1)**2))/np.sqrt(np.sum(np.linalg.norm(u_full,ord=2,axis=1)**2))*100
            v_avg_rel_err=np.sqrt(np.sum(np.linalg.norm(v_full-v_rom_pg_DEIM,ord=2,axis=1)**2))/np.sqrt(np.sum(np.linalg.norm(v_full,ord=2,axis=1)**2))*100

            # print("average relative error of u: {}%".format(u_avg_rel_err))
            # print("average relative error of v: {}%".format(v_avg_rel_err))

            max_rel_err = np.max([u_rel_err,v_rel_err])
            print()
            print("maximum relative error: {}%".format(max_rel_err))
            print('-'*72)     

            test_results[test_count-1]=[DEIM_basis,DEIM_samples,t_elapsed_pg_DEIM,max_rel_err]      
        except np.linalg.LinAlgError as err:
            if 'Singular matrix' in str(err):
                print()
                print('Error due to singular matrix')
                print('-'*72)
                
                test_results[test_count-1]=[DEIM_basis,DEIM_samples,0.0,np.inf]
            else:
                print("Unexpected error:", sys.exc_info()[0])
                raise
        except:
            print("Unexpected error:", sys.exc_info()[0])
            raise

DEIM_test_telapsed=time.time()-DEIM_test_tstart
print()
print('DEIM test time elapsed: {} sec'.format(DEIM_test_telapsed))
# Out:
# Total # of test: 210
#
# Test #1
# ------------------------------------------------------------------------
# DEIM_basis: 40, DEIM_samples: 40
#
# Time elapsed: 5.545975208282471 sec
#
# maximum relative error: 61.022860051788555%
# ------------------------------------------------------------------------
#
# Test #2
# ------------------------------------------------------------------------
# DEIM_basis: 40, DEIM_samples: 41
#
# Time elapsed: 4.304561138153076 sec
#
# maximum relative error: 60.87054026502518%
# ------------------------------------------------------------------------
#
# Test #3
# ------------------------------------------------------------------------
# DEIM_basis: 40, DEIM_samples: 42
#
# Time elapsed: 5.427796840667725 sec
#
# maximum relative error: 60.84164852127426%
# ------------------------------------------------------------------------
#
# Test #4
# ------------------------------------------------------------------------
# DEIM_basis: 40, DEIM_samples: 43
#
# Time elapsed: 5.912221431732178 sec
#
# maximum relative error: 60.948614239926926%
# ------------------------------------------------------------------------
#
# Test #5
# ------------------------------------------------------------------------
# DEIM_basis: 40, DEIM_samples: 44
#
# Time elapsed: 5.089322090148926 sec
#
# maximum relative error: 60.92587800443747%
# ------------------------------------------------------------------------
#
# Test #6
# ------------------------------------------------------------------------
# DEIM_basis: 40, DEIM_samples: 45
#
# Time elapsed: 5.060629844665527 sec
#
# maximum relative error: 60.974291100703695%
# ------------------------------------------------------------------------
#
# Test #7
# ------------------------------------------------------------------------
# DEIM_basis: 40, DEIM_samples: 46
#
# Time elapsed: 4.34609842300415 sec
#
# maximum relative error: 61.062023425156575%
# ------------------------------------------------------------------------
#
# Test #8
# ------------------------------------------------------------------------
# DEIM_basis: 40, DEIM_samples: 47
#
# Time elapsed: 4.509204149246216 sec
#
# maximum relative error: 60.998445990683905%
# ------------------------------------------------------------------------
#
# Test #9
# ------------------------------------------------------------------------
# DEIM_basis: 40, DEIM_samples: 48
#
# Time elapsed: 4.387649297714233 sec
#
# maximum relative error: 60.953234081288485%
# ------------------------------------------------------------------------
#
# Test #10
# ------------------------------------------------------------------------
# DEIM_basis: 40, DEIM_samples: 49
#
# Time elapsed: 4.547171354293823 sec
#
# maximum relative error: 61.02364462429305%
# ------------------------------------------------------------------------
#
# Test #11
# ------------------------------------------------------------------------
# DEIM_basis: 40, DEIM_samples: 50
#
# Time elapsed: 5.783405065536499 sec
#
# maximum relative error: 61.09317995930781%
# ------------------------------------------------------------------------
#
# Test #12
# ------------------------------------------------------------------------
# DEIM_basis: 40, DEIM_samples: 51
#
# Time elapsed: 4.466289281845093 sec
#
# maximum relative error: 61.05306323922049%
# ------------------------------------------------------------------------
#
# Test #13
# ------------------------------------------------------------------------
# DEIM_basis: 40, DEIM_samples: 52
#
# Time elapsed: 4.7655932903289795 sec
#
# maximum relative error: 60.97963724920656%
# ------------------------------------------------------------------------
#
# Test #14
# ------------------------------------------------------------------------
# DEIM_basis: 40, DEIM_samples: 53
#
# Time elapsed: 5.759690999984741 sec
#
# maximum relative error: 1693.6369650014808%
# ------------------------------------------------------------------------
#
# Test #15
# ------------------------------------------------------------------------
# DEIM_basis: 40, DEIM_samples: 54
#
# Time elapsed: 5.650977849960327 sec
#
# maximum relative error: 2447.1934233444945%
# ------------------------------------------------------------------------
#
# Test #16
# ------------------------------------------------------------------------
# DEIM_basis: 40, DEIM_samples: 55
#
# Time elapsed: 5.03645133972168 sec
#
# maximum relative error: 1032.1709653063103%
# ------------------------------------------------------------------------
#
# Test #17
# ------------------------------------------------------------------------
# DEIM_basis: 40, DEIM_samples: 56
#
# Time elapsed: 8.548470258712769 sec
#
# maximum relative error: 4394.608246193219%
# ------------------------------------------------------------------------
#
# Test #18
# ------------------------------------------------------------------------
# DEIM_basis: 40, DEIM_samples: 57
#
# Time elapsed: 6.135067939758301 sec
#
# maximum relative error: 2126.7507719247014%
# ------------------------------------------------------------------------
#
# Test #19
# ------------------------------------------------------------------------
# DEIM_basis: 40, DEIM_samples: 58
#
# Time elapsed: 5.896642446517944 sec
#
# maximum relative error: 990.4837749920852%
# ------------------------------------------------------------------------
#
# Test #20
# ------------------------------------------------------------------------
# DEIM_basis: 40, DEIM_samples: 59
#
# Time elapsed: 6.15006160736084 sec
#
# maximum relative error: 1651.5306495299815%
# ------------------------------------------------------------------------
#
# Test #21
# ------------------------------------------------------------------------
# DEIM_basis: 41, DEIM_samples: 41
#
# Time elapsed: 5.939640522003174 sec
#
# maximum relative error: 57.692530421089685%
# ------------------------------------------------------------------------
#
# Test #22
# ------------------------------------------------------------------------
# DEIM_basis: 41, DEIM_samples: 42
#
# Time elapsed: 4.353065252304077 sec
#
# maximum relative error: 57.589306340034426%
# ------------------------------------------------------------------------
#
# Test #23
# ------------------------------------------------------------------------
# DEIM_basis: 41, DEIM_samples: 43
#
# Time elapsed: 4.789614200592041 sec
#
# maximum relative error: 57.57064368821493%
# ------------------------------------------------------------------------
#
# Test #24
# ------------------------------------------------------------------------
# DEIM_basis: 41, DEIM_samples: 44
#
# Time elapsed: 4.362131834030151 sec
#
# maximum relative error: 57.63662974516755%
# ------------------------------------------------------------------------
#
# Test #25
# ------------------------------------------------------------------------
# DEIM_basis: 41, DEIM_samples: 45
#
# Time elapsed: 4.636440753936768 sec
#
# maximum relative error: 57.61391912960768%
# ------------------------------------------------------------------------
#
# Test #26
# ------------------------------------------------------------------------
# DEIM_basis: 41, DEIM_samples: 46
#
# Time elapsed: 5.6522603034973145 sec
#
# maximum relative error: 57.66597816325785%
# ------------------------------------------------------------------------
#
# Test #27
# ------------------------------------------------------------------------
# DEIM_basis: 41, DEIM_samples: 47
#
# Time elapsed: 4.724555253982544 sec
#
# maximum relative error: 57.73847419762678%
# ------------------------------------------------------------------------
#
# Test #28
# ------------------------------------------------------------------------
# DEIM_basis: 41, DEIM_samples: 48
#
# Time elapsed: 4.5714006423950195 sec
#
# maximum relative error: 57.708185044083535%
# ------------------------------------------------------------------------
#
# Test #29
# ------------------------------------------------------------------------
# DEIM_basis: 41, DEIM_samples: 49
#
# Time elapsed: 5.683492183685303 sec
#
# maximum relative error: 57.66861526509231%
# ------------------------------------------------------------------------
#
# Test #30
# ------------------------------------------------------------------------
# DEIM_basis: 41, DEIM_samples: 50
#
# Time elapsed: 5.436368942260742 sec
#
# maximum relative error: 57.70527776828865%
# ------------------------------------------------------------------------
#
# Test #31
# ------------------------------------------------------------------------
# DEIM_basis: 41, DEIM_samples: 51
# Time elapsed: 4.590214729309082 sec
#
# maximum relative error: 57.74562792427817%
# ------------------------------------------------------------------------
#
# Test #32
# ------------------------------------------------------------------------
# DEIM_basis: 41, DEIM_samples: 52
#
# Time elapsed: 4.627532005310059 sec
#
# maximum relative error: 57.723300556509535%
# ------------------------------------------------------------------------
#
# Test #33
# ------------------------------------------------------------------------
# DEIM_basis: 41, DEIM_samples: 53
#
# Time elapsed: 4.485486030578613 sec
#
# maximum relative error: 57.70315042764784%
# ------------------------------------------------------------------------
#
# Test #34
# ------------------------------------------------------------------------
# DEIM_basis: 41, DEIM_samples: 54
#
# Time elapsed: 5.064367771148682 sec
#
# maximum relative error: 2539.219547475382%
# ------------------------------------------------------------------------
#
# Test #35
# ------------------------------------------------------------------------
# DEIM_basis: 41, DEIM_samples: 55
#
# Time elapsed: 5.211866140365601 sec
#
# maximum relative error: 4187.394590647586%
# ------------------------------------------------------------------------
#
# Test #36
# ------------------------------------------------------------------------
# DEIM_basis: 41, DEIM_samples: 56
#
# Time elapsed: 5.911953687667847 sec
#
# maximum relative error: 2218.7175941707956%
# ------------------------------------------------------------------------
#
# Test #37
# ------------------------------------------------------------------------
# DEIM_basis: 41, DEIM_samples: 57
#
# Time elapsed: 5.79387354850769 sec
#
# maximum relative error: 4771.094587106658%
# ------------------------------------------------------------------------
#
# Test #38
# ------------------------------------------------------------------------
# DEIM_basis: 41, DEIM_samples: 58
#
# Time elapsed: 5.879494667053223 sec
#
# maximum relative error: 3430.0541991904565%
# ------------------------------------------------------------------------
#
# Test #39
# ------------------------------------------------------------------------
# DEIM_basis: 41, DEIM_samples: 59
#
# Time elapsed: 5.8593058586120605 sec
#
# maximum relative error: 2388.894656283691%
# ------------------------------------------------------------------------
#
# Test #40
# ------------------------------------------------------------------------
# DEIM_basis: 42, DEIM_samples: 42
#
# Time elapsed: 5.152998208999634 sec
#
# maximum relative error: 56.64307959366634%
# ------------------------------------------------------------------------
#
# Test #41
# ------------------------------------------------------------------------
# DEIM_basis: 42, DEIM_samples: 43
#
# Time elapsed: 5.042585372924805 sec
#
# maximum relative error: 56.522759673780186%
# ------------------------------------------------------------------------
#
# Test #42
# ------------------------------------------------------------------------
# DEIM_basis: 42, DEIM_samples: 44
#
# Time elapsed: 7.183960914611816 sec
#
# maximum relative error: 56.502429552444056%
# ------------------------------------------------------------------------
#
# Test #43
# ------------------------------------------------------------------------
# DEIM_basis: 42, DEIM_samples: 45
#
# Time elapsed: 5.305217742919922 sec
#
# maximum relative error: 56.60898699137991%
# ------------------------------------------------------------------------
#
# Test #44
# ------------------------------------------------------------------------
# DEIM_basis: 42, DEIM_samples: 46
#
# Time elapsed: 4.441937685012817 sec
#
# maximum relative error: 56.592013871259084%
# ------------------------------------------------------------------------
#
# Test #45
# ------------------------------------------------------------------------
# DEIM_basis: 42, DEIM_samples: 47
#
# Time elapsed: 5.282529354095459 sec
#
# maximum relative error: 56.61202046857677%
# ------------------------------------------------------------------------
#
# Test #46
# ------------------------------------------------------------------------
# DEIM_basis: 42, DEIM_samples: 48
#
# Time elapsed: 5.264700889587402 sec
#
# maximum relative error: 56.6894881335569%
# ------------------------------------------------------------------------
#
# Test #47
# ------------------------------------------------------------------------
# DEIM_basis: 42, DEIM_samples: 49
#
# Time elapsed: 5.317176580429077 sec
#
# maximum relative error: 56.684634522197264%
# ------------------------------------------------------------------------
#
# Test #48
# ------------------------------------------------------------------------
# DEIM_basis: 42, DEIM_samples: 50
#
# Time elapsed: 5.5391082763671875 sec
#
# maximum relative error: 56.5918862707984%
# ------------------------------------------------------------------------
#
# Test #49
# ------------------------------------------------------------------------
# DEIM_basis: 42, DEIM_samples: 51
#
# Time elapsed: 6.093475580215454 sec
#
# maximum relative error: 56.63949495921955%
# ------------------------------------------------------------------------
#
# Test #50
# ------------------------------------------------------------------------
# DEIM_basis: 42, DEIM_samples: 52
#
# Time elapsed: 6.424981594085693 sec
#
# maximum relative error: 56.66936659486217%
# ------------------------------------------------------------------------
#
# Test #51
# ------------------------------------------------------------------------
# DEIM_basis: 42, DEIM_samples: 53
#
# Time elapsed: 4.704107761383057 sec
#
# maximum relative error: 56.67425189043635%
# ------------------------------------------------------------------------
#
# Test #52
# ------------------------------------------------------------------------
# DEIM_basis: 42, DEIM_samples: 54
#
# Time elapsed: 4.969267845153809 sec
#
# maximum relative error: 56.64154083933798%
# ------------------------------------------------------------------------
#
# Test #53
# ------------------------------------------------------------------------
# DEIM_basis: 42, DEIM_samples: 55
#
# Time elapsed: 6.174442768096924 sec
#
# maximum relative error: 4000.5583390148317%
# ------------------------------------------------------------------------
#
# Test #54
# ------------------------------------------------------------------------
# DEIM_basis: 42, DEIM_samples: 56
#
#  non converged after 10th iteration
#
# Time elapsed: 5.651432514190674 sec
#
# maximum relative error: 5052.260387991659%
# ------------------------------------------------------------------------
#
# Test #55
# ------------------------------------------------------------------------
# DEIM_basis: 42, DEIM_samples: 57
#
# Time elapsed: 5.01536750793457 sec
#
# maximum relative error: 2793.5403382427985%
# ------------------------------------------------------------------------
#
# Test #56
# ------------------------------------------------------------------------
# DEIM_basis: 42, DEIM_samples: 58
#
# Time elapsed: 7.17206597328186 sec
#
# maximum relative error: 5396.678909664529%
# ------------------------------------------------------------------------
#
# Test #57
# ------------------------------------------------------------------------
# DEIM_basis: 42, DEIM_samples: 59
#
# Time elapsed: 9.388736248016357 sec
#
# maximum relative error: 4481.178363764132%
# ------------------------------------------------------------------------
#
# Test #58
# ------------------------------------------------------------------------
# DEIM_basis: 43, DEIM_samples: 43
#
# Time elapsed: 4.29936146736145 sec
#
# maximum relative error: 56.81537113801516%
# ------------------------------------------------------------------------
#
# Test #59
# ------------------------------------------------------------------------
# DEIM_basis: 43, DEIM_samples: 44
#
# Time elapsed: 4.6825714111328125 sec
#
# maximum relative error: 56.642697420819%
# ------------------------------------------------------------------------
#
# Test #60
# ------------------------------------------------------------------------
# DEIM_basis: 43, DEIM_samples: 45
#
# Time elapsed: 4.478757858276367 sec
#
# maximum relative error: 56.59937967459238%
# ------------------------------------------------------------------------
#
# Test #61
# ------------------------------------------------------------------------
# DEIM_basis: 43, DEIM_samples: 46
#
# Time elapsed: 4.452935695648193 sec
#
# maximum relative error: 56.73191088153481%
# ------------------------------------------------------------------------
#
# Test #62
# ------------------------------------------------------------------------
# DEIM_basis: 43, DEIM_samples: 47
# Time elapsed: 4.527456760406494 sec
#
# maximum relative error: 56.729701985241796%
# ------------------------------------------------------------------------
#
# Test #63
# ------------------------------------------------------------------------
# DEIM_basis: 43, DEIM_samples: 48
#
# Time elapsed: 4.700232028961182 sec
#
# maximum relative error: 56.8068478592514%
# ------------------------------------------------------------------------
#
# Test #64
# ------------------------------------------------------------------------
# DEIM_basis: 43, DEIM_samples: 49
#
# Time elapsed: 4.415503740310669 sec
#
# maximum relative error: 56.90785920850055%
# ------------------------------------------------------------------------
#
# Test #65
# ------------------------------------------------------------------------
# DEIM_basis: 43, DEIM_samples: 50
#
# Time elapsed: 5.0761024951934814 sec
#
# maximum relative error: 56.8957105623069%
# ------------------------------------------------------------------------
#
# Test #66
# ------------------------------------------------------------------------
# DEIM_basis: 43, DEIM_samples: 51
#
# Time elapsed: 4.619235515594482 sec
#
# maximum relative error: 56.805983797594884%
# ------------------------------------------------------------------------
#
# Test #67
# ------------------------------------------------------------------------
# DEIM_basis: 43, DEIM_samples: 52
#
# Time elapsed: 4.823123216629028 sec
#
# maximum relative error: 56.84691785730175%
# ------------------------------------------------------------------------
#
# Test #68
# ------------------------------------------------------------------------
# DEIM_basis: 43, DEIM_samples: 53
#
# Time elapsed: 4.548018932342529 sec
#
# maximum relative error: 56.870384849449785%
# ------------------------------------------------------------------------
#
# Test #69
# ------------------------------------------------------------------------
# DEIM_basis: 43, DEIM_samples: 54
#
# Time elapsed: 7.960359573364258 sec
#
# maximum relative error: 56.87681538036733%
# ------------------------------------------------------------------------
#
# Test #70
# ------------------------------------------------------------------------
# DEIM_basis: 43, DEIM_samples: 55
#
# Time elapsed: 4.689308166503906 sec
#
# maximum relative error: 56.879718938925365%
# ------------------------------------------------------------------------
#
# Test #71
# ------------------------------------------------------------------------
# DEIM_basis: 43, DEIM_samples: 56
#
# Time elapsed: 5.2471277713775635 sec
#
# maximum relative error: 4655.077196448658%
# ------------------------------------------------------------------------
#
# Test #72
# ------------------------------------------------------------------------
# DEIM_basis: 43, DEIM_samples: 57
#
#  non converged after 10th iteration
#
# Time elapsed: 5.3263983726501465 sec
#
# maximum relative error: 4871.010180354208%
# ------------------------------------------------------------------------
#
# Test #73
# ------------------------------------------------------------------------
# DEIM_basis: 43, DEIM_samples: 58
#
# Time elapsed: 5.403892755508423 sec
#
# maximum relative error: 2520.1964972827845%
# ------------------------------------------------------------------------
#
# Test #74
# ------------------------------------------------------------------------
# DEIM_basis: 43, DEIM_samples: 59
#
# Time elapsed: 6.827298164367676 sec
#
# maximum relative error: 5167.2657900646345%
# ------------------------------------------------------------------------
#
# Test #75
# ------------------------------------------------------------------------
# DEIM_basis: 44, DEIM_samples: 44
#
# Time elapsed: 5.0148138999938965 sec
#
# maximum relative error: 56.24997648027005%
# ------------------------------------------------------------------------
#
# Test #76
# ------------------------------------------------------------------------
# DEIM_basis: 44, DEIM_samples: 45
#
# Time elapsed: 4.577662944793701 sec
#
# maximum relative error: 56.17511310492249%
# ------------------------------------------------------------------------
#
# Test #77
# ------------------------------------------------------------------------
# DEIM_basis: 44, DEIM_samples: 46
#
# Time elapsed: 5.472902059555054 sec
#
# maximum relative error: 56.16450749983436%
# ------------------------------------------------------------------------
#
# Test #78
# ------------------------------------------------------------------------
# DEIM_basis: 44, DEIM_samples: 47
#
# Time elapsed: 5.170652866363525 sec
#
# maximum relative error: 56.25958516312124%
# ------------------------------------------------------------------------
#
# Test #79
# ------------------------------------------------------------------------
# DEIM_basis: 44, DEIM_samples: 48
#
# Time elapsed: 4.435835599899292 sec
#
# maximum relative error: 56.24400377320369%
# ------------------------------------------------------------------------
#
# Test #80
# ------------------------------------------------------------------------
# DEIM_basis: 44, DEIM_samples: 49
#
# Time elapsed: 4.890365123748779 sec
#
# maximum relative error: 56.2472237394651%
# ------------------------------------------------------------------------
#
# Test #81
# ------------------------------------------------------------------------
# DEIM_basis: 44, DEIM_samples: 50
#
# Time elapsed: 5.359267711639404 sec
#
# maximum relative error: 56.304719888302124%
# ------------------------------------------------------------------------
#
# Test #82
# ------------------------------------------------------------------------
# DEIM_basis: 44, DEIM_samples: 51
#
# Time elapsed: 8.807719707489014 sec
#
# maximum relative error: 56.324097252550544%
# ------------------------------------------------------------------------
#
# Test #83
# ------------------------------------------------------------------------
# DEIM_basis: 44, DEIM_samples: 52
#
# Time elapsed: 5.279576778411865 sec
#
# maximum relative error: 56.25964742252874%
# ------------------------------------------------------------------------
#
# Test #84
# ------------------------------------------------------------------------
# DEIM_basis: 44, DEIM_samples: 53
#
# Time elapsed: 4.678775787353516 sec
#
# maximum relative error: 56.297840450243385%
# ------------------------------------------------------------------------
#
# Test #85
# ------------------------------------------------------------------------
# DEIM_basis: 44, DEIM_samples: 54
#
# Time elapsed: 5.827982425689697 sec
#
# maximum relative error: 56.34652683011634%
# ------------------------------------------------------------------------
#
# Test #86
# ------------------------------------------------------------------------
# DEIM_basis: 44, DEIM_samples: 55
#
# Time elapsed: 4.635154962539673 sec
#
# maximum relative error: 56.36116837001725%
# ------------------------------------------------------------------------
#
# Test #87
# ------------------------------------------------------------------------
# DEIM_basis: 44, DEIM_samples: 56
#
# Time elapsed: 4.752026319503784 sec
#
# maximum relative error: 56.32816129160958%
# ------------------------------------------------------------------------
#
# Test #88
# ------------------------------------------------------------------------
# DEIM_basis: 44, DEIM_samples: 57
#
# Time elapsed: 4.727775573730469 sec
#
# maximum relative error: 210.74358837653602%
# ------------------------------------------------------------------------
#
# Test #89
# ------------------------------------------------------------------------
# DEIM_basis: 44, DEIM_samples: 58
#
# Time elapsed: 4.626418828964233 sec
#
# maximum relative error: 167.32182561460954%
# ------------------------------------------------------------------------
#
# Test #90
# ------------------------------------------------------------------------
# DEIM_basis: 44, DEIM_samples: 59
#
# Time elapsed: 5.683109998703003 sec
#
# maximum relative error: 164.6090414523904%
# ------------------------------------------------------------------------
#
# Test #91
# ------------------------------------------------------------------------
# DEIM_basis: 45, DEIM_samples: 45
#
# Time elapsed: 4.403532266616821 sec
#
# maximum relative error: 56.387799885777525%
# ------------------------------------------------------------------------
#
# Test #92
# ------------------------------------------------------------------------
# DEIM_basis: 45, DEIM_samples: 46
#
# Time elapsed: 4.639366388320923 sec
#
# maximum relative error: 56.317531550236666%
# ------------------------------------------------------------------------
#
# Test #93
# ------------------------------------------------------------------------
# DEIM_basis: 45, DEIM_samples: 47
# Time elapsed: 4.453009605407715 sec
#
# maximum relative error: 56.30626677765688%
# ------------------------------------------------------------------------
#
# Test #94
# ------------------------------------------------------------------------
# DEIM_basis: 45, DEIM_samples: 48
#
# Time elapsed: 4.573010683059692 sec
#
# maximum relative error: 56.397455388185826%
# ------------------------------------------------------------------------
#
# Test #95
# ------------------------------------------------------------------------
# DEIM_basis: 45, DEIM_samples: 49
#
# Time elapsed: 4.382066011428833 sec
#
# maximum relative error: 56.38040145791686%
# ------------------------------------------------------------------------
#
# Test #96
# ------------------------------------------------------------------------
# DEIM_basis: 45, DEIM_samples: 50
#
# Time elapsed: 4.424712419509888 sec
#
# maximum relative error: 56.38649480480399%
# ------------------------------------------------------------------------
#
# Test #97
# ------------------------------------------------------------------------
# DEIM_basis: 45, DEIM_samples: 51
#
# Time elapsed: 4.4283974170684814 sec
#
# maximum relative error: 56.44209719652218%
# ------------------------------------------------------------------------
#
# Test #98
# ------------------------------------------------------------------------
# DEIM_basis: 45, DEIM_samples: 52
#
# Time elapsed: 5.857267618179321 sec
#
# maximum relative error: 56.456963487828816%
# ------------------------------------------------------------------------
#
# Test #99
# ------------------------------------------------------------------------
# DEIM_basis: 45, DEIM_samples: 53
#
# Time elapsed: 4.606964826583862 sec
#
# maximum relative error: 56.39516279540162%
# ------------------------------------------------------------------------
#
# Test #100
# ------------------------------------------------------------------------
# DEIM_basis: 45, DEIM_samples: 54
#
# Time elapsed: 11.207987546920776 sec
#
# maximum relative error: 56.434507780219555%
# ------------------------------------------------------------------------
#
# Test #101
# ------------------------------------------------------------------------
# DEIM_basis: 45, DEIM_samples: 55
#
# Time elapsed: 4.849179744720459 sec
#
# maximum relative error: 56.48575207650587%
# ------------------------------------------------------------------------
#
# Test #102
# ------------------------------------------------------------------------
# DEIM_basis: 45, DEIM_samples: 56
#
# Time elapsed: 5.750461578369141 sec
#
# maximum relative error: 56.50190149085647%
# ------------------------------------------------------------------------
#
# Test #103
# ------------------------------------------------------------------------
# DEIM_basis: 45, DEIM_samples: 57
#
# Time elapsed: 4.583917856216431 sec
#
# maximum relative error: 56.47563157561413%
# ------------------------------------------------------------------------
#
# Test #104
# ------------------------------------------------------------------------
# DEIM_basis: 45, DEIM_samples: 58
#
# Time elapsed: 4.7259581089019775 sec
#
# maximum relative error: 231.36835474006952%
# ------------------------------------------------------------------------
#
# Test #105
# ------------------------------------------------------------------------
# DEIM_basis: 45, DEIM_samples: 59
#
# Time elapsed: 4.716739177703857 sec
#
# maximum relative error: 171.24089859801364%
# ------------------------------------------------------------------------
#
# Test #106
# ------------------------------------------------------------------------
# DEIM_basis: 46, DEIM_samples: 46
#
# Time elapsed: 4.357799768447876 sec
#
# maximum relative error: 56.36532782453101%
# ------------------------------------------------------------------------
#
# Test #107
# ------------------------------------------------------------------------
# DEIM_basis: 46, DEIM_samples: 47
#
# Time elapsed: 4.493213415145874 sec
#
# maximum relative error: 56.27550760200247%
# ------------------------------------------------------------------------
#
# Test #108
# ------------------------------------------------------------------------
# DEIM_basis: 46, DEIM_samples: 48
#
# Time elapsed: 4.432993173599243 sec
#
# maximum relative error: 56.257876233820035%
# ------------------------------------------------------------------------
#
# Test #109
# ------------------------------------------------------------------------
# DEIM_basis: 46, DEIM_samples: 49
#
# Time elapsed: 4.3717405796051025 sec
#
# maximum relative error: 56.38523648740429%
# ------------------------------------------------------------------------
#
# Test #110
# ------------------------------------------------------------------------
# DEIM_basis: 46, DEIM_samples: 50
#
# Time elapsed: 4.554310083389282 sec
#
# maximum relative error: 56.37478730079296%
# ------------------------------------------------------------------------
#
# Test #111
# ------------------------------------------------------------------------
# DEIM_basis: 46, DEIM_samples: 51
#
# Time elapsed: 4.517491579055786 sec
#
# maximum relative error: 56.25520993272893%
# ------------------------------------------------------------------------
#
# Test #112
# ------------------------------------------------------------------------
# DEIM_basis: 46, DEIM_samples: 52
#
# Time elapsed: 4.5928285121917725 sec
#
# maximum relative error: 56.417971097073504%
# ------------------------------------------------------------------------
#
# Test #113
# ------------------------------------------------------------------------
# DEIM_basis: 46, DEIM_samples: 53
#
# Time elapsed: 4.6544036865234375 sec
#
# maximum relative error: 56.45190202209606%
# ------------------------------------------------------------------------
#
# Test #114
# ------------------------------------------------------------------------
# DEIM_basis: 46, DEIM_samples: 54
#
# Time elapsed: 4.638127326965332 sec
#
# maximum relative error: 56.25659418730603%
# ------------------------------------------------------------------------
#
# Test #115
# ------------------------------------------------------------------------
# DEIM_basis: 46, DEIM_samples: 55
#
# Time elapsed: 4.686204671859741 sec
#
# maximum relative error: 56.41159632146946%
# ------------------------------------------------------------------------
#
# Test #116
# ------------------------------------------------------------------------
# DEIM_basis: 46, DEIM_samples: 56
#
# Time elapsed: 4.501734495162964 sec
#
# maximum relative error: 56.42006871955193%
# ------------------------------------------------------------------------
#
# Test #117
# ------------------------------------------------------------------------
# DEIM_basis: 46, DEIM_samples: 57
#
# Time elapsed: 4.632447719573975 sec
#
# maximum relative error: 56.48030818021841%
# ------------------------------------------------------------------------
#
# Test #118
# ------------------------------------------------------------------------
# DEIM_basis: 46, DEIM_samples: 58
#
# Time elapsed: 5.723404169082642 sec
#
# maximum relative error: 56.42367591583534%
# ------------------------------------------------------------------------
#
# Test #119
# ------------------------------------------------------------------------
# DEIM_basis: 46, DEIM_samples: 59
#
# Time elapsed: 6.714858531951904 sec
#
# maximum relative error: 220.62705214627326%
# ------------------------------------------------------------------------
#
# Test #120
# ------------------------------------------------------------------------
# DEIM_basis: 47, DEIM_samples: 47
#
# Time elapsed: 4.7767393589019775 sec
#
# maximum relative error: 52.48390933187651%
# ------------------------------------------------------------------------
#
# Test #121
# ------------------------------------------------------------------------
# DEIM_basis: 47, DEIM_samples: 48
#
# Time elapsed: 5.783756494522095 sec
#
# maximum relative error: 52.387133820525065%
# ------------------------------------------------------------------------
#
# Test #122
# ------------------------------------------------------------------------
# DEIM_basis: 47, DEIM_samples: 49
#
# Time elapsed: 4.999738931655884 sec
#
# maximum relative error: 52.380022098953816%
# ------------------------------------------------------------------------
#
# Test #123
# ------------------------------------------------------------------------
# DEIM_basis: 47, DEIM_samples: 50
#
# Time elapsed: 4.666979074478149 sec
#
# maximum relative error: 52.46917147833165%
# ------------------------------------------------------------------------
#
# Test #124
# ------------------------------------------------------------------------
# DEIM_basis: 47, DEIM_samples: 51
# Time elapsed: 4.904744863510132 sec
#
# maximum relative error: 52.44003305155945%
# ------------------------------------------------------------------------
#
# Test #125
# ------------------------------------------------------------------------
# DEIM_basis: 47, DEIM_samples: 52
#
# Time elapsed: 4.531095504760742 sec
#
# maximum relative error: 52.31468929549924%
# ------------------------------------------------------------------------
#
# Test #126
# ------------------------------------------------------------------------
# DEIM_basis: 47, DEIM_samples: 53
#
# Time elapsed: 4.678524017333984 sec
#
# maximum relative error: 52.473864950888036%
# ------------------------------------------------------------------------
#
# Test #127
# ------------------------------------------------------------------------
# DEIM_basis: 47, DEIM_samples: 54
#
# Time elapsed: 4.562944412231445 sec
#
# maximum relative error: 52.44737550903484%
# ------------------------------------------------------------------------
#
# Test #128
# ------------------------------------------------------------------------
# DEIM_basis: 47, DEIM_samples: 55
#
# Time elapsed: 4.625694990158081 sec
#
# maximum relative error: 52.301042520475384%
# ------------------------------------------------------------------------
#
# Test #129
# ------------------------------------------------------------------------
# DEIM_basis: 47, DEIM_samples: 56
#
# Time elapsed: 4.478508710861206 sec
#
# maximum relative error: 52.385045182311075%
# ------------------------------------------------------------------------
#
# Test #130
# ------------------------------------------------------------------------
# DEIM_basis: 47, DEIM_samples: 57
#
# Time elapsed: 4.5920186042785645 sec
#
# maximum relative error: 52.46554904059144%
# ------------------------------------------------------------------------
#
# Test #131
# ------------------------------------------------------------------------
# DEIM_basis: 47, DEIM_samples: 58
#
# Time elapsed: 4.63563084602356 sec
#
# maximum relative error: 52.410100182464724%
# ------------------------------------------------------------------------
#
# Test #132
# ------------------------------------------------------------------------
# DEIM_basis: 47, DEIM_samples: 59
#
# Time elapsed: 4.9763524532318115 sec
#
# maximum relative error: 52.354191011394924%
# ------------------------------------------------------------------------
#
# Test #133
# ------------------------------------------------------------------------
# DEIM_basis: 48, DEIM_samples: 48
#
# Time elapsed: 4.379536151885986 sec
#
# maximum relative error: 53.656934480336496%
# ------------------------------------------------------------------------
#
# Test #134
# ------------------------------------------------------------------------
# DEIM_basis: 48, DEIM_samples: 49
#
# Time elapsed: 5.400278806686401 sec
#
# maximum relative error: 53.54779703072528%
# ------------------------------------------------------------------------
#
# Test #135
# ------------------------------------------------------------------------
# DEIM_basis: 48, DEIM_samples: 50
#
# Time elapsed: 5.043828010559082 sec
#
# maximum relative error: 53.54028608575393%
# ------------------------------------------------------------------------
#
# Test #136
# ------------------------------------------------------------------------
# DEIM_basis: 48, DEIM_samples: 51
#
# Time elapsed: 4.517009019851685 sec
#
# maximum relative error: 53.63439222746076%
# ------------------------------------------------------------------------
#
# Test #137
# ------------------------------------------------------------------------
# DEIM_basis: 48, DEIM_samples: 52
#
# Time elapsed: 7.267573595046997 sec
#
# maximum relative error: 53.61015259127563%
# ------------------------------------------------------------------------
#
# Test #138
# ------------------------------------------------------------------------
# DEIM_basis: 48, DEIM_samples: 53
#
# Time elapsed: 4.551486492156982 sec
#
# maximum relative error: 53.47988844800406%
# ------------------------------------------------------------------------
#
# Test #139
# ------------------------------------------------------------------------
# DEIM_basis: 48, DEIM_samples: 54
#
# Time elapsed: 4.906614542007446 sec
#
# maximum relative error: 53.6527648185942%
# ------------------------------------------------------------------------
#
# Test #140
# ------------------------------------------------------------------------
# DEIM_basis: 48, DEIM_samples: 55
#
# Time elapsed: 6.253586053848267 sec
#
# maximum relative error: 53.619672196171464%
# ------------------------------------------------------------------------
#
# Test #141
# ------------------------------------------------------------------------
# DEIM_basis: 48, DEIM_samples: 56
#
# Time elapsed: 4.488464117050171 sec
#
# maximum relative error: 53.47922703534752%
# ------------------------------------------------------------------------
#
# Test #142
# ------------------------------------------------------------------------
# DEIM_basis: 48, DEIM_samples: 57
#
# Time elapsed: 4.574531078338623 sec
#
# maximum relative error: 53.56581629897937%
# ------------------------------------------------------------------------
#
# Test #143
# ------------------------------------------------------------------------
# DEIM_basis: 48, DEIM_samples: 58
#
# Time elapsed: 4.669666051864624 sec
#
# maximum relative error: 53.65017758081323%
# ------------------------------------------------------------------------
#
# Test #144
# ------------------------------------------------------------------------
# DEIM_basis: 48, DEIM_samples: 59
#
# Time elapsed: 4.809089660644531 sec
#
# maximum relative error: 53.59850445523961%
# ------------------------------------------------------------------------
#
# Test #145
# ------------------------------------------------------------------------
# DEIM_basis: 49, DEIM_samples: 49
#
# Time elapsed: 4.601199388504028 sec
#
# maximum relative error: 52.64703655237808%
# ------------------------------------------------------------------------
#
# Test #146
# ------------------------------------------------------------------------
# DEIM_basis: 49, DEIM_samples: 50
#
# Time elapsed: 4.4044108390808105 sec
#
# maximum relative error: 52.54086433696915%
# ------------------------------------------------------------------------
#
# Test #147
# ------------------------------------------------------------------------
# DEIM_basis: 49, DEIM_samples: 51
#
# Time elapsed: 4.532308578491211 sec
#
# maximum relative error: 52.50986934986187%
# ------------------------------------------------------------------------
#
# Test #148
# ------------------------------------------------------------------------
# DEIM_basis: 49, DEIM_samples: 52
#
# Time elapsed: 5.138938665390015 sec
#
# maximum relative error: 52.597798911464096%
# ------------------------------------------------------------------------
#
# Test #149
# ------------------------------------------------------------------------
# DEIM_basis: 49, DEIM_samples: 53
#
# Time elapsed: 4.5474019050598145 sec
#
# maximum relative error: 52.60951920246462%
# ------------------------------------------------------------------------
#
# Test #150
# ------------------------------------------------------------------------
# DEIM_basis: 49, DEIM_samples: 54
#
# Time elapsed: 4.529605150222778 sec
#
# maximum relative error: 52.44797410020351%
# ------------------------------------------------------------------------
#
# Test #151
# ------------------------------------------------------------------------
# DEIM_basis: 49, DEIM_samples: 55
#
# Time elapsed: 5.276492595672607 sec
#
# maximum relative error: 52.640740497838145%
# ------------------------------------------------------------------------
#
# Test #152
# ------------------------------------------------------------------------
# DEIM_basis: 49, DEIM_samples: 56
#
# Time elapsed: 5.650392293930054 sec
#
# maximum relative error: 52.59070720605435%
# ------------------------------------------------------------------------
#
# Test #153
# ------------------------------------------------------------------------
# DEIM_basis: 49, DEIM_samples: 57
#
# Time elapsed: 4.530913591384888 sec
#
# maximum relative error: 52.47121917761359%
# ------------------------------------------------------------------------
#
# Test #154
# ------------------------------------------------------------------------
# DEIM_basis: 49, DEIM_samples: 58
#
# Time elapsed: 4.7585835456848145 sec
#
# maximum relative error: 52.559152317541844%
# ------------------------------------------------------------------------
#
# Test #155
# ------------------------------------------------------------------------
# DEIM_basis: 49, DEIM_samples: 59
# Time elapsed: 5.2053303718566895 sec
#
# maximum relative error: 52.63386264661744%
# ------------------------------------------------------------------------
#
# Test #156
# ------------------------------------------------------------------------
# DEIM_basis: 50, DEIM_samples: 50
#
# Time elapsed: 5.372535705566406 sec
#
# maximum relative error: 50.411221644505446%
# ------------------------------------------------------------------------
#
# Test #157
# ------------------------------------------------------------------------
# DEIM_basis: 50, DEIM_samples: 51
#
# Time elapsed: 4.680447101593018 sec
#
# maximum relative error: 50.32761646699618%
# ------------------------------------------------------------------------
#
# Test #158
# ------------------------------------------------------------------------
# DEIM_basis: 50, DEIM_samples: 52
#
# Time elapsed: 4.881616115570068 sec
#
# maximum relative error: 50.30537320081906%
# ------------------------------------------------------------------------
#
# Test #159
# ------------------------------------------------------------------------
# DEIM_basis: 50, DEIM_samples: 53
#
# Time elapsed: 4.686363935470581 sec
#
# maximum relative error: 50.37490081757483%
# ------------------------------------------------------------------------
#
# Test #160
# ------------------------------------------------------------------------
# DEIM_basis: 50, DEIM_samples: 54
#
# Time elapsed: 4.703537464141846 sec
#
# maximum relative error: 50.37720712265593%
# ------------------------------------------------------------------------
#
# Test #161
# ------------------------------------------------------------------------
# DEIM_basis: 50, DEIM_samples: 55
#
# Time elapsed: 6.026321887969971 sec
#
# maximum relative error: 50.21740369817748%
# ------------------------------------------------------------------------
#
# Test #162
# ------------------------------------------------------------------------
# DEIM_basis: 50, DEIM_samples: 56
#
# Time elapsed: 7.356714725494385 sec
#
# maximum relative error: 50.386577680378096%
# ------------------------------------------------------------------------
#
# Test #163
# ------------------------------------------------------------------------
# DEIM_basis: 50, DEIM_samples: 57
#
# Time elapsed: 5.361202001571655 sec
#
# maximum relative error: 50.33906248875578%
# ------------------------------------------------------------------------
#
# Test #164
# ------------------------------------------------------------------------
# DEIM_basis: 50, DEIM_samples: 58
#
# Time elapsed: 6.0258307456970215 sec
#
# maximum relative error: 50.233604362621605%
# ------------------------------------------------------------------------
#
# Test #165
# ------------------------------------------------------------------------
# DEIM_basis: 50, DEIM_samples: 59
#
# Time elapsed: 6.215458631515503 sec
#
# maximum relative error: 50.30732197251624%
# ------------------------------------------------------------------------
#
# Test #166
# ------------------------------------------------------------------------
# DEIM_basis: 51, DEIM_samples: 51
#
# Time elapsed: 5.999213218688965 sec
#
# maximum relative error: 51.58335674501108%
# ------------------------------------------------------------------------
#
# Test #167
# ------------------------------------------------------------------------
# DEIM_basis: 51, DEIM_samples: 52
#
# Time elapsed: 4.64553427696228 sec
#
# maximum relative error: 51.535719564596505%
# ------------------------------------------------------------------------
#
# Test #168
# ------------------------------------------------------------------------
# DEIM_basis: 51, DEIM_samples: 53
#
# Time elapsed: 4.523489475250244 sec
#
# maximum relative error: 51.509246072278124%
# ------------------------------------------------------------------------
#
# Test #169
# ------------------------------------------------------------------------
# DEIM_basis: 51, DEIM_samples: 54
#
# Time elapsed: 4.474735260009766 sec
#
# maximum relative error: 51.54386366252272%
# ------------------------------------------------------------------------
#
# Test #170
# ------------------------------------------------------------------------
# DEIM_basis: 51, DEIM_samples: 55
#
# Time elapsed: 5.678159475326538 sec
#
# maximum relative error: 51.59125132329307%
# ------------------------------------------------------------------------
#
# Test #171
# ------------------------------------------------------------------------
# DEIM_basis: 51, DEIM_samples: 56
#
# Time elapsed: 4.5708043575286865 sec
#
# maximum relative error: 51.4196466633359%
# ------------------------------------------------------------------------
#
# Test #172
# ------------------------------------------------------------------------
# DEIM_basis: 51, DEIM_samples: 57
#
# Time elapsed: 4.622607946395874 sec
#
# maximum relative error: 51.56322073661717%
# ------------------------------------------------------------------------
#
# Test #173
# ------------------------------------------------------------------------
# DEIM_basis: 51, DEIM_samples: 58
#
# Time elapsed: 5.05262303352356 sec
#
# maximum relative error: 51.52957665997088%
# ------------------------------------------------------------------------
#
# Test #174
# ------------------------------------------------------------------------
# DEIM_basis: 51, DEIM_samples: 59
#
# Time elapsed: 5.529132843017578 sec
#
# maximum relative error: 51.44281855213811%
# ------------------------------------------------------------------------
#
# Test #175
# ------------------------------------------------------------------------
# DEIM_basis: 52, DEIM_samples: 52
#
# Time elapsed: 4.559301137924194 sec
#
# maximum relative error: 51.92710718780066%
# ------------------------------------------------------------------------
#
# Test #176
# ------------------------------------------------------------------------
# DEIM_basis: 52, DEIM_samples: 53
#
# Time elapsed: 5.090386629104614 sec
#
# maximum relative error: 51.662358132555%
# ------------------------------------------------------------------------
#
# Test #177
# ------------------------------------------------------------------------
# DEIM_basis: 52, DEIM_samples: 54
#
# Time elapsed: 5.129522323608398 sec
#
# maximum relative error: 51.590384756643104%
# ------------------------------------------------------------------------
#
# Test #178
# ------------------------------------------------------------------------
# DEIM_basis: 52, DEIM_samples: 55
#
# Time elapsed: 5.283128499984741 sec
#
# maximum relative error: 51.81843440625664%
# ------------------------------------------------------------------------
#
# Test #179
# ------------------------------------------------------------------------
# DEIM_basis: 52, DEIM_samples: 56
#
# Time elapsed: 4.479550838470459 sec
#
# maximum relative error: 51.96767033426529%
# ------------------------------------------------------------------------
#
# Test #180
# ------------------------------------------------------------------------
# DEIM_basis: 52, DEIM_samples: 57
#
# Time elapsed: 4.574283838272095 sec
#
# maximum relative error: 51.25126949505905%
# ------------------------------------------------------------------------
#
# Test #181
# ------------------------------------------------------------------------
# DEIM_basis: 52, DEIM_samples: 58
#
# Time elapsed: 4.736161947250366 sec
#
# maximum relative error: 51.74251858794202%
# ------------------------------------------------------------------------
#
# Test #182
# ------------------------------------------------------------------------
# DEIM_basis: 52, DEIM_samples: 59
#
# Time elapsed: 5.278745889663696 sec
#
# maximum relative error: 51.62293994919629%
# ------------------------------------------------------------------------
#
# Test #183
# ------------------------------------------------------------------------
# DEIM_basis: 53, DEIM_samples: 53
#
# Time elapsed: 7.183061361312866 sec
#
# maximum relative error: 37.970783495136814%
# ------------------------------------------------------------------------
#
# Test #184
# ------------------------------------------------------------------------
# DEIM_basis: 53, DEIM_samples: 54
#
# Time elapsed: 4.660218000411987 sec
#
# maximum relative error: 37.97173246073113%
# ------------------------------------------------------------------------
#
# Test #185
# ------------------------------------------------------------------------
# DEIM_basis: 53, DEIM_samples: 55
#
# Time elapsed: 4.751198053359985 sec
#
# maximum relative error: 37.9644561970388%
# ------------------------------------------------------------------------
#
# Test #186
# ------------------------------------------------------------------------
# DEIM_basis: 53, DEIM_samples: 56
# Time elapsed: 5.054361581802368 sec
#
# maximum relative error: 37.95250081306269%
# ------------------------------------------------------------------------
#
# Test #187
# ------------------------------------------------------------------------
# DEIM_basis: 53, DEIM_samples: 57
#
# Time elapsed: 4.770152807235718 sec
#
# maximum relative error: 37.99046859281107%
# ------------------------------------------------------------------------
#
# Test #188
# ------------------------------------------------------------------------
# DEIM_basis: 53, DEIM_samples: 58
#
# Time elapsed: 5.019427299499512 sec
#
# maximum relative error: 37.726861018680516%
# ------------------------------------------------------------------------
#
# Test #189
# ------------------------------------------------------------------------
# DEIM_basis: 53, DEIM_samples: 59
#
# Time elapsed: 4.858828783035278 sec
#
# maximum relative error: 37.83891135410476%
# ------------------------------------------------------------------------
#
# Test #190
# ------------------------------------------------------------------------
# DEIM_basis: 54, DEIM_samples: 54
#
# Time elapsed: 5.591398239135742 sec
#
# maximum relative error: 39.073017483541655%
# ------------------------------------------------------------------------
#
# Test #191
# ------------------------------------------------------------------------
# DEIM_basis: 54, DEIM_samples: 55
#
# Time elapsed: 4.603529691696167 sec
#
# maximum relative error: 39.04399785914224%
# ------------------------------------------------------------------------
#
# Test #192
# ------------------------------------------------------------------------
# DEIM_basis: 54, DEIM_samples: 56
#
# Time elapsed: 6.056745529174805 sec
#
# maximum relative error: 39.01141351932304%
# ------------------------------------------------------------------------
#
# Test #193
# ------------------------------------------------------------------------
# DEIM_basis: 54, DEIM_samples: 57
#
# Time elapsed: 4.680200099945068 sec
#
# maximum relative error: 39.045269910649274%
# ------------------------------------------------------------------------
#
# Test #194
# ------------------------------------------------------------------------
# DEIM_basis: 54, DEIM_samples: 58
#
# Time elapsed: 5.39681601524353 sec
#
# maximum relative error: 39.06932851409547%
# ------------------------------------------------------------------------
#
# Test #195
# ------------------------------------------------------------------------
# DEIM_basis: 54, DEIM_samples: 59
#
# Time elapsed: 7.744959831237793 sec
#
# maximum relative error: 38.88086317499324%
# ------------------------------------------------------------------------
#
# Test #196
# ------------------------------------------------------------------------
# DEIM_basis: 55, DEIM_samples: 55
#
# Time elapsed: 6.691088438034058 sec
#
# maximum relative error: 44.41921327636375%
# ------------------------------------------------------------------------
#
# Test #197
# ------------------------------------------------------------------------
# DEIM_basis: 55, DEIM_samples: 56
#
# Time elapsed: 6.034029006958008 sec
#
# maximum relative error: 44.32696238403647%
# ------------------------------------------------------------------------
#
# Test #198
# ------------------------------------------------------------------------
# DEIM_basis: 55, DEIM_samples: 57
#
# Time elapsed: 4.578496694564819 sec
#
# maximum relative error: 44.331730365597984%
# ------------------------------------------------------------------------
#
# Test #199
# ------------------------------------------------------------------------
# DEIM_basis: 55, DEIM_samples: 58
#
# Time elapsed: 4.6797356605529785 sec
#
# maximum relative error: 44.32818680904966%
# ------------------------------------------------------------------------
#
# Test #200
# ------------------------------------------------------------------------
# DEIM_basis: 55, DEIM_samples: 59
#
# Time elapsed: 5.750694751739502 sec
#
# maximum relative error: 44.32546548596478%
# ------------------------------------------------------------------------
#
# Test #201
# ------------------------------------------------------------------------
# DEIM_basis: 56, DEIM_samples: 56
#
# Time elapsed: 6.1249542236328125 sec
#
# maximum relative error: 48.256185495924896%
# ------------------------------------------------------------------------
#
# Test #202
# ------------------------------------------------------------------------
# DEIM_basis: 56, DEIM_samples: 57
#
# Time elapsed: 4.503367900848389 sec
#
# maximum relative error: 48.15758124149286%
# ------------------------------------------------------------------------
#
# Test #203
# ------------------------------------------------------------------------
# DEIM_basis: 56, DEIM_samples: 58
#
# Time elapsed: 4.660081148147583 sec
#
# maximum relative error: 48.09425237058871%
# ------------------------------------------------------------------------
#
# Test #204
# ------------------------------------------------------------------------
# DEIM_basis: 56, DEIM_samples: 59
#
# Time elapsed: 4.669032573699951 sec
#
# maximum relative error: 48.187734642780825%
# ------------------------------------------------------------------------
#
# Test #205
# ------------------------------------------------------------------------
# DEIM_basis: 57, DEIM_samples: 57
#
# Time elapsed: 4.660736322402954 sec
#
# maximum relative error: 43.664661354660545%
# ------------------------------------------------------------------------
#
# Test #206
# ------------------------------------------------------------------------
# DEIM_basis: 57, DEIM_samples: 58
#
# Time elapsed: 5.869906187057495 sec
#
# maximum relative error: 43.643762221528185%
# ------------------------------------------------------------------------
#
# Test #207
# ------------------------------------------------------------------------
# DEIM_basis: 57, DEIM_samples: 59
#
# Time elapsed: 5.4522223472595215 sec
#
# maximum relative error: 43.64067571862826%
# ------------------------------------------------------------------------
#
# Test #208
# ------------------------------------------------------------------------
# DEIM_basis: 58, DEIM_samples: 58
#
# Time elapsed: 4.616865634918213 sec
#
# maximum relative error: 43.49762764738242%
# ------------------------------------------------------------------------
#
# Test #209
# ------------------------------------------------------------------------
# DEIM_basis: 58, DEIM_samples: 59
#
# Time elapsed: 4.807370901107788 sec
#
# maximum relative error: 43.44581684327788%
# ------------------------------------------------------------------------
#
# Test #210
# ------------------------------------------------------------------------
# DEIM_basis: 59, DEIM_samples: 59
#
# Time elapsed: 5.25669527053833 sec
#
# maximum relative error: 34.377501067874014%
# ------------------------------------------------------------------------
#
# DEIM test time elapsed: 1146.1990025043488 sec

# %%
print(test_results[np.argsort(test_results[:,-1])])
# Out:
# [[5.90000000e+01 5.90000000e+01 5.25669527e+00 3.43775011e+01]
#  [5.30000000e+01 5.80000000e+01 5.01942730e+00 3.77268610e+01]
#  [5.30000000e+01 5.90000000e+01 4.85882878e+00 3.78389114e+01]
#  [5.30000000e+01 5.60000000e+01 5.05436158e+00 3.79525008e+01]
#  [5.30000000e+01 5.50000000e+01 4.75119805e+00 3.79644562e+01]
#  [5.30000000e+01 5.30000000e+01 7.18306136e+00 3.79707835e+01]
#  [5.30000000e+01 5.40000000e+01 4.66021800e+00 3.79717325e+01]
#  [5.30000000e+01 5.70000000e+01 4.77015281e+00 3.79904686e+01]
#  [5.40000000e+01 5.90000000e+01 7.74495983e+00 3.88808632e+01]
#  [5.40000000e+01 5.60000000e+01 6.05674553e+00 3.90114135e+01]
#  [5.40000000e+01 5.50000000e+01 4.60352969e+00 3.90439979e+01]
#  [5.40000000e+01 5.70000000e+01 4.68020010e+00 3.90452699e+01]
#  [5.40000000e+01 5.80000000e+01 5.39681602e+00 3.90693285e+01]
#  [5.40000000e+01 5.40000000e+01 5.59139824e+00 3.90730175e+01]
#  [5.80000000e+01 5.90000000e+01 4.80737090e+00 4.34458168e+01]
#  [5.80000000e+01 5.80000000e+01 4.61686563e+00 4.34976276e+01]
#  [5.70000000e+01 5.90000000e+01 5.45222235e+00 4.36406757e+01]
#  [5.70000000e+01 5.80000000e+01 5.86990619e+00 4.36437622e+01]
#  [5.70000000e+01 5.70000000e+01 4.66073632e+00 4.36646614e+01]
#  [5.50000000e+01 5.90000000e+01 5.75069475e+00 4.43254655e+01]
#  [5.50000000e+01 5.60000000e+01 6.03402901e+00 4.43269624e+01]
#  [5.50000000e+01 5.80000000e+01 4.67973566e+00 4.43281868e+01]
#  [5.50000000e+01 5.70000000e+01 4.57849669e+00 4.43317304e+01]
#  [5.50000000e+01 5.50000000e+01 6.69108844e+00 4.44192133e+01]
#  [5.60000000e+01 5.80000000e+01 4.66008115e+00 4.80942524e+01]
#  [5.60000000e+01 5.70000000e+01 4.50336790e+00 4.81575812e+01]
#  [5.60000000e+01 5.90000000e+01 4.66903257e+00 4.81877346e+01]
#  [5.60000000e+01 5.60000000e+01 6.12495422e+00 4.82561855e+01]
#  [5.00000000e+01 5.50000000e+01 6.02632189e+00 5.02174037e+01]
#  [5.00000000e+01 5.80000000e+01 6.02583075e+00 5.02336044e+01]
#  [5.00000000e+01 5.20000000e+01 4.88161612e+00 5.03053732e+01]
#  [5.00000000e+01 5.90000000e+01 6.21545863e+00 5.03073220e+01]
#  [5.00000000e+01 5.10000000e+01 4.68044710e+00 5.03276165e+01]
#  [5.00000000e+01 5.70000000e+01 5.36120200e+00 5.03390625e+01]
#  [5.00000000e+01 5.30000000e+01 4.68636394e+00 5.03749008e+01]
#  [5.00000000e+01 5.40000000e+01 4.70353746e+00 5.03772071e+01]
#  [5.00000000e+01 5.60000000e+01 7.35671473e+00 5.03865777e+01]
#  [5.00000000e+01 5.00000000e+01 5.37253571e+00 5.04112216e+01]
#  [5.20000000e+01 5.70000000e+01 4.57428384e+00 5.12512695e+01]
#  [5.10000000e+01 5.60000000e+01 4.57080436e+00 5.14196467e+01]
#  [5.10000000e+01 5.90000000e+01 5.52913284e+00 5.14428186e+01]
#  [5.10000000e+01 5.30000000e+01 4.52348948e+00 5.15092461e+01]
#  [5.10000000e+01 5.80000000e+01 5.05262303e+00 5.15295767e+01]
#  [5.10000000e+01 5.20000000e+01 4.64553428e+00 5.15357196e+01]
#  [5.10000000e+01 5.40000000e+01 4.47473526e+00 5.15438637e+01]
#  [5.10000000e+01 5.70000000e+01 4.62260795e+00 5.15632207e+01]
#  [5.10000000e+01 5.10000000e+01 5.99921322e+00 5.15833567e+01]
#  [5.20000000e+01 5.40000000e+01 5.12952232e+00 5.15903848e+01]
#  [5.10000000e+01 5.50000000e+01 5.67815948e+00 5.15912513e+01]
#  [5.20000000e+01 5.90000000e+01 5.27874589e+00 5.16229399e+01]
#  [5.20000000e+01 5.30000000e+01 5.09038663e+00 5.16623581e+01]
#  [5.20000000e+01 5.80000000e+01 4.73616195e+00 5.17425186e+01]
#  [5.20000000e+01 5.50000000e+01 5.28312850e+00 5.18184344e+01]
#  [5.20000000e+01 5.20000000e+01 4.55930114e+00 5.19271072e+01]
#  [5.20000000e+01 5.60000000e+01 4.47955084e+00 5.19676703e+01]
#  [4.70000000e+01 5.50000000e+01 4.62569499e+00 5.23010425e+01]
#  [4.70000000e+01 5.20000000e+01 4.53109550e+00 5.23146893e+01]
#  [4.70000000e+01 5.90000000e+01 4.97635245e+00 5.23541910e+01]
#  [4.70000000e+01 4.90000000e+01 4.99973893e+00 5.23800221e+01]
#  [4.70000000e+01 5.60000000e+01 4.47850871e+00 5.23850452e+01]
#  [4.70000000e+01 4.80000000e+01 5.78375649e+00 5.23871338e+01]
#  [4.70000000e+01 5.80000000e+01 4.63563085e+00 5.24101002e+01]
#  [4.70000000e+01 5.10000000e+01 4.90474486e+00 5.24400331e+01]
#  [4.70000000e+01 5.40000000e+01 4.56294441e+00 5.24473755e+01]
#  [4.90000000e+01 5.40000000e+01 4.52960515e+00 5.24479741e+01]
#  [4.70000000e+01 5.70000000e+01 4.59201860e+00 5.24655490e+01]
#  [4.70000000e+01 5.00000000e+01 4.66697907e+00 5.24691715e+01]
#  [4.90000000e+01 5.70000000e+01 4.53091359e+00 5.24712192e+01]
#  [4.70000000e+01 5.30000000e+01 4.67852402e+00 5.24738650e+01]
#  [4.70000000e+01 4.70000000e+01 4.77673936e+00 5.24839093e+01]
#  [4.90000000e+01 5.10000000e+01 4.53230858e+00 5.25098693e+01]
#  [4.90000000e+01 5.00000000e+01 4.40441084e+00 5.25408643e+01]
#  [4.90000000e+01 5.80000000e+01 4.75858355e+00 5.25591523e+01]
#  [4.90000000e+01 5.60000000e+01 5.65039229e+00 5.25907072e+01]
#  [4.90000000e+01 5.20000000e+01 5.13893867e+00 5.25977989e+01]
#  [4.90000000e+01 5.30000000e+01 4.54740191e+00 5.26095192e+01]
#  [4.90000000e+01 5.90000000e+01 5.20533037e+00 5.26338626e+01]
#  [4.90000000e+01 5.50000000e+01 5.27649260e+00 5.26407405e+01]
#  [4.90000000e+01 4.90000000e+01 4.60119939e+00 5.26470366e+01]
#  [4.80000000e+01 5.60000000e+01 4.48846412e+00 5.34792270e+01]
#  [4.80000000e+01 5.30000000e+01 4.55148649e+00 5.34798884e+01]
#  [4.80000000e+01 5.00000000e+01 5.04382801e+00 5.35402861e+01]
#  [4.80000000e+01 4.90000000e+01 5.40027881e+00 5.35477970e+01]
#  [4.80000000e+01 5.70000000e+01 4.57453108e+00 5.35658163e+01]
#  [4.80000000e+01 5.90000000e+01 4.80908966e+00 5.35985045e+01]
#  [4.80000000e+01 5.20000000e+01 7.26757360e+00 5.36101526e+01]
#  [4.80000000e+01 5.50000000e+01 6.25358605e+00 5.36196722e+01]
#  [4.80000000e+01 5.10000000e+01 4.51700902e+00 5.36343922e+01]
#  [4.80000000e+01 5.80000000e+01 4.66966605e+00 5.36501776e+01]
#  [4.80000000e+01 5.40000000e+01 4.90661454e+00 5.36527648e+01]
#  [4.80000000e+01 4.80000000e+01 4.37953615e+00 5.36569345e+01]
#  [4.40000000e+01 4.60000000e+01 5.47290206e+00 5.61645075e+01]
#  [4.40000000e+01 4.50000000e+01 4.57766294e+00 5.61751131e+01]
#  [4.40000000e+01 4.80000000e+01 4.43583560e+00 5.62440038e+01]
#  [4.40000000e+01 4.90000000e+01 4.89036512e+00 5.62472237e+01]
#  [4.40000000e+01 4.40000000e+01 5.01481390e+00 5.62499765e+01]
#  [4.60000000e+01 5.10000000e+01 4.51749158e+00 5.62552099e+01]
#  [4.60000000e+01 5.40000000e+01 4.63812733e+00 5.62565942e+01]
#  [4.60000000e+01 4.80000000e+01 4.43299317e+00 5.62578762e+01]
#  [4.40000000e+01 4.70000000e+01 5.17065287e+00 5.62595852e+01]
#  [4.40000000e+01 5.20000000e+01 5.27957678e+00 5.62596474e+01]
#  [4.60000000e+01 4.70000000e+01 4.49321342e+00 5.62755076e+01]
#  [4.40000000e+01 5.30000000e+01 4.67877579e+00 5.62978405e+01]
#  [4.40000000e+01 5.00000000e+01 5.35926771e+00 5.63047199e+01]
#  [4.50000000e+01 4.70000000e+01 4.45300961e+00 5.63062668e+01]
#  [4.50000000e+01 4.60000000e+01 4.63936639e+00 5.63175316e+01]
#  [4.40000000e+01 5.10000000e+01 8.80771971e+00 5.63240973e+01]
#  [4.40000000e+01 5.60000000e+01 4.75202632e+00 5.63281613e+01]
#  [4.40000000e+01 5.40000000e+01 5.82798243e+00 5.63465268e+01]
#  [4.40000000e+01 5.50000000e+01 4.63515496e+00 5.63611684e+01]
#  [4.60000000e+01 4.60000000e+01 4.35779977e+00 5.63653278e+01]
#  [4.60000000e+01 5.00000000e+01 4.55431008e+00 5.63747873e+01]
#  [4.50000000e+01 4.90000000e+01 4.38206601e+00 5.63804015e+01]
#  [4.60000000e+01 4.90000000e+01 4.37174058e+00 5.63852365e+01]
#  [4.50000000e+01 5.00000000e+01 4.42471242e+00 5.63864948e+01]
#  [4.50000000e+01 4.50000000e+01 4.40353227e+00 5.63877999e+01]
#  [4.50000000e+01 5.30000000e+01 4.60696483e+00 5.63951628e+01]
#  [4.50000000e+01 4.80000000e+01 4.57301068e+00 5.63974554e+01]
#  [4.60000000e+01 5.50000000e+01 4.68620467e+00 5.64115963e+01]
#  [4.60000000e+01 5.20000000e+01 4.59282851e+00 5.64179711e+01]
#  [4.60000000e+01 5.60000000e+01 4.50173450e+00 5.64200687e+01]
#  [4.60000000e+01 5.80000000e+01 5.72340417e+00 5.64236759e+01]
#  [4.50000000e+01 5.40000000e+01 1.12079875e+01 5.64345078e+01]
#  [4.50000000e+01 5.10000000e+01 4.42839742e+00 5.64420972e+01]
#  [4.60000000e+01 5.30000000e+01 4.65440369e+00 5.64519020e+01]
#  [4.50000000e+01 5.20000000e+01 5.85726762e+00 5.64569635e+01]
#  [4.50000000e+01 5.70000000e+01 4.58391786e+00 5.64756316e+01]
#  [4.60000000e+01 5.70000000e+01 4.63244772e+00 5.64803082e+01]
#  [4.50000000e+01 5.50000000e+01 4.84917974e+00 5.64857521e+01]
#  [4.50000000e+01 5.60000000e+01 5.75046158e+00 5.65019015e+01]
#  [4.20000000e+01 4.40000000e+01 7.18396091e+00 5.65024296e+01]
#  [4.20000000e+01 4.30000000e+01 5.04258537e+00 5.65227597e+01]
#  [4.20000000e+01 5.00000000e+01 5.53910828e+00 5.65918863e+01]
#  [4.20000000e+01 4.60000000e+01 4.44193769e+00 5.65920139e+01]
#  [4.30000000e+01 4.50000000e+01 4.47875786e+00 5.65993797e+01]
#  [4.20000000e+01 4.50000000e+01 5.30521774e+00 5.66089870e+01]
#  [4.20000000e+01 4.70000000e+01 5.28252935e+00 5.66120205e+01]
#  [4.20000000e+01 5.10000000e+01 6.09347558e+00 5.66394950e+01]
#  [4.20000000e+01 5.40000000e+01 4.96926785e+00 5.66415408e+01]
#  [4.30000000e+01 4.40000000e+01 4.68257141e+00 5.66426974e+01]
#  [4.20000000e+01 4.20000000e+01 5.15299821e+00 5.66430796e+01]
#  [4.20000000e+01 5.20000000e+01 6.42498159e+00 5.66693666e+01]
#  [4.20000000e+01 5.30000000e+01 4.70410776e+00 5.66742519e+01]
#  [4.20000000e+01 4.90000000e+01 5.31717658e+00 5.66846345e+01]
#  [4.20000000e+01 4.80000000e+01 5.26470089e+00 5.66894881e+01]
#  [4.30000000e+01 4.70000000e+01 4.52745676e+00 5.67297020e+01]
#  [4.30000000e+01 4.60000000e+01 4.45293570e+00 5.67319109e+01]
#  [4.30000000e+01 5.10000000e+01 4.61923552e+00 5.68059838e+01]
#  [4.30000000e+01 4.80000000e+01 4.70023203e+00 5.68068479e+01]
#  [4.30000000e+01 4.30000000e+01 4.29936147e+00 5.68153711e+01]
#  [4.30000000e+01 5.20000000e+01 4.82312322e+00 5.68469179e+01]
#  [4.30000000e+01 5.30000000e+01 4.54801893e+00 5.68703848e+01]
#  [4.30000000e+01 5.40000000e+01 7.96035957e+00 5.68768154e+01]
#  [4.30000000e+01 5.50000000e+01 4.68930817e+00 5.68797189e+01]
#  [4.30000000e+01 5.00000000e+01 5.07610250e+00 5.68957106e+01]
#  [4.30000000e+01 4.90000000e+01 4.41550374e+00 5.69078592e+01]
#  [4.10000000e+01 4.30000000e+01 4.78961420e+00 5.75706437e+01]
#  [4.10000000e+01 4.20000000e+01 4.35306525e+00 5.75893063e+01]
#  [4.10000000e+01 4.50000000e+01 4.63644075e+00 5.76139191e+01]
#  [4.10000000e+01 4.40000000e+01 4.36213183e+00 5.76366297e+01]
#  [4.10000000e+01 4.60000000e+01 5.65226030e+00 5.76659782e+01]
#  [4.10000000e+01 4.90000000e+01 5.68349218e+00 5.76686153e+01]
#  [4.10000000e+01 4.10000000e+01 5.93964052e+00 5.76925304e+01]
#  [4.10000000e+01 5.30000000e+01 4.48548603e+00 5.77031504e+01]
#  [4.10000000e+01 5.00000000e+01 5.43636894e+00 5.77052778e+01]
#  [4.10000000e+01 4.80000000e+01 4.57140064e+00 5.77081850e+01]
#  [4.10000000e+01 5.20000000e+01 4.62753201e+00 5.77233006e+01]
#  [4.10000000e+01 4.70000000e+01 4.72455525e+00 5.77384742e+01]
#  [4.10000000e+01 5.10000000e+01 4.59021473e+00 5.77456279e+01]
#  [4.00000000e+01 4.20000000e+01 5.42779684e+00 6.08416485e+01]
#  [4.00000000e+01 4.10000000e+01 4.30456114e+00 6.08705403e+01]
#  [4.00000000e+01 4.40000000e+01 5.08932209e+00 6.09258780e+01]
#  [4.00000000e+01 4.30000000e+01 5.91222143e+00 6.09486142e+01]
#  [4.00000000e+01 4.80000000e+01 4.38764930e+00 6.09532341e+01]
#  [4.00000000e+01 4.50000000e+01 5.06062984e+00 6.09742911e+01]
#  [4.00000000e+01 5.20000000e+01 4.76559329e+00 6.09796372e+01]
#  [4.00000000e+01 4.70000000e+01 4.50920415e+00 6.09984460e+01]
#  [4.00000000e+01 4.00000000e+01 5.54597521e+00 6.10228601e+01]
#  [4.00000000e+01 4.90000000e+01 4.54717135e+00 6.10236446e+01]
#  [4.00000000e+01 5.10000000e+01 4.46628928e+00 6.10530632e+01]
#  [4.00000000e+01 4.60000000e+01 4.34609842e+00 6.10620234e+01]
#  [4.00000000e+01 5.00000000e+01 5.78340507e+00 6.10931800e+01]
#  [4.40000000e+01 5.90000000e+01 5.68311000e+00 1.64609041e+02]
#  [4.40000000e+01 5.80000000e+01 4.62641883e+00 1.67321826e+02]
#  [4.50000000e+01 5.90000000e+01 4.71673918e+00 1.71240899e+02]
#  [4.40000000e+01 5.70000000e+01 4.72777557e+00 2.10743588e+02]
#  [4.60000000e+01 5.90000000e+01 6.71485853e+00 2.20627052e+02]
#  [4.50000000e+01 5.80000000e+01 4.72595811e+00 2.31368355e+02]
#  [4.00000000e+01 5.80000000e+01 5.89664245e+00 9.90483775e+02]
#  [4.00000000e+01 5.50000000e+01 5.03645134e+00 1.03217097e+03]
#  [4.00000000e+01 5.90000000e+01 6.15006161e+00 1.65153065e+03]
#  [4.00000000e+01 5.30000000e+01 5.75969100e+00 1.69363697e+03]
#  [4.00000000e+01 5.70000000e+01 6.13506794e+00 2.12675077e+03]
#  [4.10000000e+01 5.60000000e+01 5.91195369e+00 2.21871759e+03]
#  [4.10000000e+01 5.90000000e+01 5.85930586e+00 2.38889466e+03]
#  [4.00000000e+01 5.40000000e+01 5.65097785e+00 2.44719342e+03]
#  [4.30000000e+01 5.80000000e+01 5.40389276e+00 2.52019650e+03]
#  [4.10000000e+01 5.40000000e+01 5.06436777e+00 2.53921955e+03]
#  [4.20000000e+01 5.70000000e+01 5.01536751e+00 2.79354034e+03]
#  [4.10000000e+01 5.80000000e+01 5.87949467e+00 3.43005420e+03]
#  [4.20000000e+01 5.50000000e+01 6.17444277e+00 4.00055834e+03]
#  [4.10000000e+01 5.50000000e+01 5.21186614e+00 4.18739459e+03]
#  [4.00000000e+01 5.60000000e+01 8.54847026e+00 4.39460825e+03]
#  [4.20000000e+01 5.90000000e+01 9.38873625e+00 4.48117836e+03]
#  [4.30000000e+01 5.60000000e+01 5.24712777e+00 4.65507720e+03]
#  [4.10000000e+01 5.70000000e+01 5.79387355e+00 4.77109459e+03]
#  [4.30000000e+01 5.70000000e+01 5.32639837e+00 4.87101018e+03]
#  [4.20000000e+01 5.60000000e+01 5.65143251e+00 5.05226039e+03]
#  [4.30000000e+01 5.90000000e+01 6.82729816e+00 5.16726579e+03]
#  [4.20000000e+01 5.80000000e+01 7.17206597e+00 5.39667891e+03]]

# %%
# choose # of DEIM basis and DEIM samples
DEIM_basis=int(test_results[np.argsort(test_results[:,-1])[0]][0])
DEIM_samples=int(test_results[np.argsort(test_results[:,-1])[0]][1])
print('# of residual basis: {}'.format(DEIM_basis))
print('# of residual sampes: {}'.format(DEIM_samples))

phi_theta_u=U_theta_u[:,:DEIM_basis]
phi_theta_v=U_theta_v[:,:DEIM_basis]

# precompute
z_theta_u=DEIM(phi_theta_u,DEIM_samples)
z_theta_v=DEIM(phi_theta_v,DEIM_samples)

P_u=phi_theta_u.dot(np.linalg.pinv(phi_theta_u[z_theta_u]))
P_v=phi_theta_v.dot(np.linalg.pinv(phi_theta_v[z_theta_v]))

P_uT=P_u.T
P_vT=P_v.T

P_uTphi_u=P_uT.dot(phi_u)
P_uTP_u=P_uT.dot(P_u)

P_vTphi_v=P_vT.dot(phi_v)
P_vTP_v=P_vT.dot(P_v)

A2TP_u_cur=A2T_cur.dot(P_u)
B2TP_v_cur=B2T_cur.dot(P_v)

A3TP_u_cur=A3T_cur.dot(P_u)
B3TP_v_cur=B3T_cur.dot(P_v)

P_uTa1_cur=P_uT.dot(a1_cur)
P_uTA2_cur=P_uT.dot(A2_cur)
P_uTA3_cur=P_uT.dot(A3_cur)

P_vTb1_cur=P_vT.dot(b1_cur)
P_vTB2_cur=P_vT.dot(B2_cur)
P_vTB3_cur=P_vT.dot(B3_cur)

def ZTtheta_u(u_hat,v_hat):
    return -1/dx*phi_u[z_theta_u].dot(u_hat)*Mphi_u[z_theta_u].dot(u_hat)-1/dy*phi_v[z_theta_u].dot(v_hat)*Nphi_u[z_theta_u].dot(u_hat)

def ZTtheta_v(u_hat,v_hat):
    return -1/dx*phi_u[z_theta_v].dot(u_hat)*Mphi_v[z_theta_v].dot(v_hat)-1/dy*phi_v[z_theta_v].dot(v_hat)*Nphi_v[z_theta_v].dot(v_hat)

def dZTtheta_udu_hat(u_hat,v_hat):
    return -1/dx*(np.diag(Mphi_u[z_theta_u].dot(u_hat)).dot(phi_u[z_theta_u])+np.diag(phi_u[z_theta_u].dot(u_hat)).dot(Mphi_u[z_theta_u])) \
-1/dy*(np.diag(phi_v[z_theta_u].dot(v_hat)).dot(Nphi_u[z_theta_u]))

def dZTtheta_udv_hat(u_hat,v_hat):
    return -1/dy*(np.diag(Nphi_u[z_theta_u].dot(u_hat)).dot(phi_v[z_theta_u]))

def dZTtheta_vdu_hat(u_hat,v_hat):
    return -1/dx*(np.diag(Mphi_v[z_theta_v].dot(v_hat)).dot(phi_u[z_theta_v]))

def dZTtheta_vdv_hat(u_hat,v_hat):
    return -1/dx*(np.diag(phi_u[z_theta_v].dot(u_hat)).dot(Mphi_v[z_theta_v])) \
-1/dy*(np.diag(Nphi_v[z_theta_v].dot(v_hat)).dot(phi_v[z_theta_v])+np.diag(phi_v[z_theta_v].dot(v_hat)).dot(Nphi_v[z_theta_v]))

def dtheta_udu_hatTZ(u_hat,v_hat):
    return -1/dx*(Mphi_u[z_theta_u].dot(u_hat)*phi_uT[:,z_theta_u]+phi_u[z_theta_u].dot(u_hat)*Mphi_uT[:,z_theta_u]) \
-1/dy*(phi_v[z_theta_u].dot(v_hat)*Nphi_uT[:,z_theta_u])

def dtheta_udv_hatTZ(u_hat,v_hat):
    return -1/dy*(Nphi_u[z_theta_u].dot(u_hat)*phi_vT[:,z_theta_u])

def dtheta_vdu_hatTZ(u_hat,v_hat):
    return -1/dx*(Mphi_v[z_theta_v].dot(v_hat)*phi_uT[:,z_theta_v])

def dtheta_vdv_hatTZ(u_hat,v_hat):
    return -1/dx*(phi_u[z_theta_v].dot(u_hat)*Mphi_vT[:,z_theta_v]) \
-1/dy*(Nphi_v[z_theta_v].dot(v_hat)*phi_vT[:,z_theta_v]+phi_v[z_theta_v].dot(v_hat)*Nphi_vT[:,z_theta_v])

def r_hat_DEIM(u_hat,v_hat,u_hat_prev,v_hat_prev,A4_cur,A5_cur,a6_cur,A7_cur,A8_cur,B4_cur,B5_cur,b6_cur,B7_cur,B8_cur,\
               A2TP_u_cur,A3TP_u_cur,B2TP_v_cur,B3TP_v_cur,\
               P_uTa1_cur,P_uTA2_cur,P_uTA3_cur,P_vTb1_cur,P_vTB2_cur,P_vTB3_cur):

    r_u_hat=A4_cur.dot(u_hat_prev)+A5_cur.dot(v_hat_prev)+a6_cur+A7_cur.dot(u_hat)+A8_cur.dot(v_hat) \
    -dt*A2TP_u_cur.dot(ZTtheta_u(u_hat,v_hat))-dt*B2TP_v_cur.dot(ZTtheta_v(u_hat,v_hat)) \
    -dt*dtheta_udu_hatTZ(u_hat,v_hat).dot(-P_uTphi_u.dot(u_hat_prev)+P_uTa1_cur+P_uTA2_cur.dot(u_hat)+P_uTA3_cur.dot(v_hat)-dt*P_uTP_u.dot(ZTtheta_u(u_hat,v_hat))) \
    -dt*dtheta_vdu_hatTZ(u_hat,v_hat).dot(-P_vTphi_v.dot(v_hat_prev)+P_vTb1_cur+P_vTB2_cur.dot(u_hat)+P_vTB3_cur.dot(v_hat)-dt*P_vTP_v.dot(ZTtheta_v(u_hat,v_hat)))

    r_v_hat=B4_cur.dot(u_hat_prev)+B5_cur.dot(v_hat_prev)+b6_cur+B7_cur.dot(u_hat)+B8_cur.dot(v_hat) \
    -dt*A3TP_u_cur.dot(ZTtheta_u(u_hat,v_hat))-dt*B3TP_v_cur.dot(ZTtheta_v(u_hat,v_hat)) \
    -dt*dtheta_udv_hatTZ(u_hat,v_hat).dot(-P_uTphi_u.dot(u_hat_prev)+P_uTa1_cur+P_uTA2_cur.dot(u_hat)+P_uTA3_cur.dot(v_hat)-dt*P_uTP_u.dot(ZTtheta_u(u_hat,v_hat))) \
    -dt*dtheta_vdv_hatTZ(u_hat,v_hat).dot(-P_vTphi_v.dot(v_hat_prev)+P_vTb1_cur+P_vTB2_cur.dot(u_hat)+P_vTB3_cur.dot(v_hat)-dt*P_vTP_v.dot(ZTtheta_v(u_hat,v_hat)))

    return np.concatenate((r_u_hat,r_v_hat))

def J_hat_DEIM(u_hat,v_hat,P_uTA2_cur,A2TP_u_cur,P_uTA3_cur,A3TP_u_cur,A7_cur,A8_cur,\
               P_vTB2_cur,B2TP_v_cur,P_vTB3_cur,B3TP_v_cur,B7_cur,B8_cur):

    J_hat11=A7_cur-dt*A2TP_u_cur.dot(dZTtheta_udu_hat(u_hat,v_hat))-dt*B2TP_v_cur.dot(dZTtheta_vdu_hat(u_hat,v_hat)) \
    -dt*dtheta_udu_hatTZ(u_hat,v_hat).dot(P_uTA2_cur-dt*P_uTP_u.dot(dZTtheta_udu_hat(u_hat,v_hat))) \
    -dt*dtheta_vdu_hatTZ(u_hat,v_hat).dot(P_vTB2_cur-dt*P_vTP_v.dot(dZTtheta_vdu_hat(u_hat,v_hat)))

    J_hat12=A8_cur-dt*A2TP_u_cur.dot(dZTtheta_udv_hat(u_hat,v_hat))-dt*B2TP_v_cur.dot(dZTtheta_vdv_hat(u_hat,v_hat)) \
    -dt*dtheta_udu_hatTZ(u_hat,v_hat).dot(P_uTA3_cur-dt*P_uTP_u.dot(dZTtheta_udv_hat(u_hat,v_hat))) \
    -dt*dtheta_vdu_hatTZ(u_hat,v_hat).dot(P_vTB3_cur-dt*P_vTP_v.dot(dZTtheta_vdv_hat(u_hat,v_hat)))

    J_hat21=B7_cur-dt*A3TP_u_cur.dot(dZTtheta_udu_hat(u_hat,v_hat))-dt*B3TP_v_cur.dot(dZTtheta_vdu_hat(u_hat,v_hat)) \
    -dt*dtheta_udv_hatTZ(u_hat,v_hat).dot(P_uTA2_cur-dt*P_uTP_u.dot(dZTtheta_udu_hat(u_hat,v_hat))) \
    -dt*dtheta_vdv_hatTZ(u_hat,v_hat).dot(P_vTB2_cur-dt*P_vTP_v.dot(dZTtheta_vdu_hat(u_hat,v_hat)))

    J_hat22=B8_cur-dt*A3TP_u_cur.dot(dZTtheta_udv_hat(u_hat,v_hat))-dt*B3TP_v_cur.dot(dZTtheta_vdv_hat(u_hat,v_hat)) \
    -dt*dtheta_udv_hatTZ(u_hat,v_hat).dot(P_uTA3_cur-dt*P_uTP_u.dot(dZTtheta_udv_hat(u_hat,v_hat))) \
    -dt*dtheta_vdv_hatTZ(u_hat,v_hat).dot(P_vTB3_cur-dt*P_vTP_v.dot(dZTtheta_vdv_hat(u_hat,v_hat)))

    return np.block([[J_hat11,J_hat12],[J_hat21,J_hat22]])

# run LS-ROM
t_start_pg_DEIM=time.time()

# solution
u_rom_pg_DEIM=np.zeros((nt+1,ny*nx))
v_rom_pg_DEIM=np.zeros((nt+1,ny*nx))
u_reduced=np.zeros((nt+1,POD_basis))
v_reduced=np.zeros((nt+1,POD_basis))

# IC
u_hat0=np.zeros(POD_basis)
v_hat0=np.zeros(POD_basis)
u_rom_pg_DEIM[0]=np.copy(u0)
v_rom_pg_DEIM[0]=np.copy(v0)

for k in range(nt):
#     print("")
#     print(k,"th time step:")

    u_hat_prev=np.copy(u_reduced[k])
    v_hat_prev=np.copy(v_reduced[k])

    u_hat=np.copy(u_reduced[k])
    v_hat=np.copy(v_reduced[k])

    residual_hat=r_hat_DEIM(u_hat,v_hat,u_hat_prev,v_hat_prev,A4_cur,A5_cur,a6_cur,A7_cur,A8_cur,B4_cur,B5_cur,b6_cur,B7_cur,B8_cur,\
                            A2TP_u_cur,A3TP_u_cur,B2TP_v_cur,B3TP_v_cur,\
                            P_uTa1_cur,P_uTA2_cur,P_uTA3_cur,P_vTb1_cur,P_vTB2_cur,P_vTB3_cur)

    for itr in range(maxitr):
        Jacobian_hat=J_hat_DEIM(u_hat,v_hat,P_uTA2_cur,A2TP_u_cur,P_uTA3_cur,A3TP_u_cur,A7_cur,A8_cur,\
                                P_vTB2_cur,B2TP_v_cur,P_vTB3_cur,B3TP_v_cur,B7_cur,B8_cur)

        delta_reduced=np.linalg.solve(Jacobian_hat,-residual_hat)

        u_hat+=delta_reduced[:POD_basis]
        v_hat+=delta_reduced[POD_basis:]

        residual_hat=r_hat_DEIM(u_hat,v_hat,u_hat_prev,v_hat_prev,A4_cur,A5_cur,a6_cur,A7_cur,A8_cur,B4_cur,B5_cur,b6_cur,B7_cur,B8_cur,\
                                A2TP_u_cur,A3TP_u_cur,B2TP_v_cur,B3TP_v_cur,\
                                P_uTa1_cur,P_uTA2_cur,P_uTA3_cur,P_vTb1_cur,P_vTB2_cur,P_vTB3_cur)

        R=np.linalg.norm(residual_hat)
#         print(itr,"th Newton iteration", "R:", R)

        if R<tol:
            u_reduced[k+1]=u_hat.copy()
            v_reduced[k+1]=v_hat.copy()
            u_rom_pg_DEIM[k+1,free_raveled_indicies]=u_ref+phi_u.dot(u_hat)
            v_rom_pg_DEIM[k+1,free_raveled_indicies]=v_ref+phi_v.dot(v_hat)
            # BC from exact solution
            u_rom_pg_DEIM[k+1,fixed_raveled_indicies]=u0[fixed_raveled_indicies].copy()
            v_rom_pg_DEIM[k+1,fixed_raveled_indicies]=v0[fixed_raveled_indicies].copy()
            break

    if R>=tol:
        print("\n non converged after {}th iteration".format(maxitr))
        break  

#     u_reduced[k+1]=u_hat.copy()
#     v_reduced[k+1]=v_hat.copy()
#     u_rom_g_DEIM[k+1,free_raveled_indicies]=u_ref+phi_u.dot(u_hat)
#     v_rom_g_DEIM[k+1,free_raveled_indicies]=v_ref+phi_v.dot(v_hat)
#     # BC from exact solution
#     u_rom_g_DEIM[k+1,fixed_raveled_indicies]=u0[fixed_raveled_indicies].copy()
#     v_rom_g_DEIM[k+1,fixed_raveled_indicies]=v0[fixed_raveled_indicies].copy()

t_elapsed_pg_DEIM=time.time()-t_start_pg_DEIM
print()
print('Time elapsed: {} sec'.format(t_elapsed_pg_DEIM))

# compute errors
u_rel_err=np.linalg.norm(u_full-u_rom_pg_DEIM,ord=2,axis=1)/np.linalg.norm(u_full,ord=2,axis=1)*100
v_rel_err=np.linalg.norm(v_full-v_rom_pg_DEIM,ord=2,axis=1)/np.linalg.norm(v_full,ord=2,axis=1)*100
plt.plot(dt*np.arange(nt+1),u_rel_err,dt*np.arange(nt+1),v_rel_err)
plt.xlabel('Time (sec)')
plt.ylabel('Relative Error (%)')
plt.legend(('u','v'))
plt.show()

u_avg_rel_err=np.sqrt(np.sum(np.linalg.norm(u_full-u_rom_pg_DEIM,ord=2,axis=1)**2))/np.sqrt(np.sum(np.linalg.norm(u_full,ord=2,axis=1)**2))*100
v_avg_rel_err=np.sqrt(np.sum(np.linalg.norm(v_full-v_rom_pg_DEIM,ord=2,axis=1)**2))/np.sqrt(np.sum(np.linalg.norm(v_full,ord=2,axis=1)**2))*100

print("average relative error of u: {}%".format(u_avg_rel_err))
print("average relative error of v: {}%".format(v_avg_rel_err))

max_rel_err = np.max([u_rel_err,v_rel_err])
print()
print("maximum relative error: {}%".format(max_rel_err))
print('-'*72)
# Out:
# # of residual basis: 59
# # of residual sampes: 59
#
# Time elapsed: 4.669660568237305 sec
# average relative error of u: 19.682570732373026%
# average relative error of v: 19.873067084603367%
#
# maximum relative error: 34.377501067874014%
# ------------------------------------------------------------------------
